# %% [markdown]
# # Classification of lesions in medical physics
#
# The aim of this exercise is to create and train a simple convolutional neural network (CNN) for deep-learning based classification of normal tissue vs. tissue cointaining microcalcification clusters in mammograms.
#
# In this exercise you will learn how to:
#
# *   Load and explore image data.
# *   Define the CNN model.
# *   Compile and train the CNN model on the training data.
# *   Predict the labels of the test data and calculate the classification accuracy.
# *   Create the ROC curve and calculate the AUC.
#
# Moreover if you want, you will learn how to perform data augmentation.
#
# ## Description of the dataset
#
# The dataset we will use contains many image portions (60x60 pixels) extracted from real mammograms converted to 8-bit grayscale images. These images can either contain microcalcification clusters (label=1) or  normal breast tissue (label=0).
#
#
# The available images are already partitioned in a train and a test sets, containing, respectively:
# - Train set (70% of the whole sample): 289 images with normal tissue and 267 images with microcalcification clusters;
# - Test set (30% of the whole sample): 125 images with normal tissue and 116 images with microcalcification clusters.
#
# The test set should always be left apart from the training procedure and used as an independent set to evaluate the classifier performance.
#
#
# ## Remark
# The architecture of the CNN you will develop in this exercise can be trained on different kind of 2D images (with 1 color channel) even outside the medical imaging domain.

# %% [markdown]
# ![Fig_micro.png](data:image/png;base64,...)

# %% [markdown]
# ![Fig_no_micro.png](data:image/png;base64,...)

# %% [markdown]
# #Importing the dataset from Google Drive

# %% [markdown]
# This is the link to data folder: https://drive.google.com/drive/folders/1bru5aQX9u6cECmrGHd723WhiIjD_InK9?usp=sharing
#
#
#
# To begin with, we need to mount our google drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Using the special ```!``` charcter we can execute shell commands. For example we can show all file and folders in a certain path with ```ls```.

# %%
# !ls /content/gdrive/My\ Drive/Mammography_micro/
# Out:
# README_micro.rtf  Test	Train

# %% [markdown]
# Each folder should have mammogram images containing microcalcifications (label=1) or normal breast tissue (label=0) put in different subfolders.

# %%
# !ls /content/gdrive/My\ Drive/Mammography_micro/{Test,Train}
# Out:
# '/content/gdrive/My Drive/Mammography_micro/Test':
# 0  1
#
# '/content/gdrive/My Drive/Mammography_micro/Train':
# 0  1

# %% [markdown]
# The number of images for each folder should be as it follows:
# ```
# Train 0 files: 289
# Train 1 files: 267
# Test 0 files: 125
# Test 1 files: 116
# ```

# %%
# !echo -n "Train 0 files: "; ls /content/gdrive/My\ Drive/Mammography_micro/Train/0 | wc -l;
# !echo -n "Train 1 files: "; ls /content/gdrive/My\ Drive/Mammography_micro/Train/1 | wc -l;
# !echo -n "Test 0 files: "; ls /content/gdrive/My\ Drive/Mammography_micro/Test/0 | wc -l;
# !echo -n "Test 1 files: "; ls /content/gdrive/My\ Drive/Mammography_micro/Test/1 | wc -l;
# Out:
# Train 0 files: 289
# Train 1 files: 267
# Test 0 files: 125
# Test 1 files: 116

# %% [markdown]
# Print the filename structure inside a folder.

# %%
# !ls /content/gdrive/My\ Drive/Mammography_micro/Train/1/ | tail -n 3
# Out:
# 0312u1_1_1_1.pgm_5.pgm
# 0313u1_1_1_1.pgm_5.pgm
# 0313u1_1_2_1.pgm_5.pgm

# %% [markdown]
# # Reading the images

# %% [markdown]
# Importing python packages

# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import os
import glob
import numpy as np

# %% [markdown]
# Let's try to read an image with ```imread``` [[doc](https://scikit-image.org/docs/dev/api/skimage.io.html#skimage.io.imread)]. The output is a 2D array (since the image is in grayscale).
# We can view the image through the package ```imshow``` of matplotlib [[doc](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html)].

# %%
# !ls /content/gdrive/MyDrive/Mammography_micro/Train
# Out:
# 0  1

# %%
sample_img = imread('/content/gdrive/MyDrive/Mammography_micro/Train/1/0006s1_1_1_1.pgm_1.pgm')
print("Shape of array:", np.shape(sample_img))
plt.imshow(sample_img, cmap='gray')
# Out:
# Shape of array: (60, 60)

# %% [markdown]
# We define a function to read images from a certain ```dataset_path``` and ```classes``` that match the subfolders containing labeled images.
#
# The function uses the ```glob``` functions that finds all the pathnames that match a given pattern [[doc](https://docs.python.org/3/library/glob.html)].
# The images are read though the package ```imread``` [[doc](https://scikit-image.org/docs/dev/api/skimage.io.html#skimage.io.imread)]. This list of read images is populated with list comprehensions [[doc](https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions)].
#
# The last line converts the ```tmp``` list into a numpy array storing float32 data, adding an extra dimension with ```np.newaxis``` [[doc](https://numpy.org/doc/stable/reference/constants.html#numpy.newaxis)] (the three dots ```...``` are a special indexing symbol called ellipsis [[doc](https://docs.python.org/dev/library/constants.html#Ellipsis)])

# %%
def read_imgs(dataset_path, classes):
  tmp = []
  labels = []
  for cls in classes:
    # Returns all the images filenames contained in a certain folder
    fnames = glob.glob(os.path.join(dataset_path, str(cls), '*.pgm'))
    # Read, with a list comprehension, all the images listed before
    tmp += [ imread(fname) for fname in fnames ]
    # Populate the labels list with the label of the read image
    labels += len(fnames)*[cls]
 
  return np.array(tmp, dtype='float32')[..., np.newaxis]/255, np.array(labels)

# %%
train_dataset_path = '/content/gdrive/MyDrive/Mammography_micro/Train'
x_train, y_train = read_imgs(train_dataset_path, [0, 1])

test_dataset_path = '/content/gdrive/MyDrive/Mammography_micro/Test'
x_test, y_test = read_imgs(test_dataset_path, [0, 1])

# %% [markdown]
# It's always a good idea to print the shape of the array in use. In our case the first dimension is the number of read images, the second and the third are the dimension of the images, and the last one is the auxiliary axis we created.

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (556, 60, 60, 1) (556,)
# (241, 60, 60, 1) (241,)

# %%
#plot the first image in the dataset
img_1 = x_train[0].reshape(60,60)
plt.imshow(img_1, cmap='gray')

# %% [markdown]
# # Defining a CNN model

# %% [markdown]
# Convolutional neural networks (CNN) are a class of neural network usually used to classify images.
# [Ref1](https://www.asimovinstitute.org/neural-network-zoo/)
# [Ref2](https://www.freecodecamp.org/news/an-intuitive-guide-to-convolutional-neural-networks-260c2de0a050/)
#
# ![dobVrh3SGyqQraM2ogi-P3VK2K-LFsBm7RLO.png](data:image/png;base64,...)
#
# [Ref3](https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5)

# %% [markdown]
# - In CNN, the convolutional layers nodes are not connected to all the nodes of previous layer. This is due to the high dimesionality of image data. For this reason we connect each node only to a local region of the input.
#
# - The nodes are called neurons or filter or kernel. The nodes/filters are convolved to the network layers and they slide through the whole image in order to cover all pixels.
#
# ![1*0R11RGqX9mM-YdxNgZ0V6A.jpeg](data:image/jpeg;base64,...)
#
# - Pooling layers. Pooling is a way to downsample the image: a common pooling technique is the "max pooling". A max pooling layer takes, for example, a 2x2 submatrix and returns the pixel with the maximum value.

# %% [markdown]
# The Keras library in Python makes it pretty simple to build a CNN.
# - Sequential is the easiest way to build a model in Keras. It allows you to build a model layer by layer.
#
# - Convolution layer
# > - The first layer takes in an input shape. This is the shape of each input image. In this case, it is (60,60,1).
# > - Number of nodes in each layer (8,16,32)
# > - Kernel size is the size of the filter matrix for our convolution. So a kernel size of 3 means we will have a 3x3 filter matrix.
# > - What is the effect of using "padding = same"?
# > - Activation is the activation function for the layer. (ReLU or Rectified Linear Activation has been proven to work well in neural networks)
#
# - 'Batch normalization' adds a ‘normalization layer’ after each convolutional layer. This allows the model to converge much faster in training and to generalize better.
#
# - ‘Dense’ is the layer we will use just before the output layer. It is a fully connected layer typical of a Multi Layer Perceptrons model.
#
# - The last layer contains 1 node and a different activation function called "sigmoid". The sigmoid returns a probability distribution in the range of 0 to 1 (it is not the only one!!!). Why is there just 1 node? Is it possible to use another number of nodes?
#
# ---
# To prevent over-fitting we will use dropout layers.
# Overfitting happens when your model fits too well to the training set. It then becomes difficult for the model to generalize.
# Dropout works by stochastically removing, or “dropping out,” some nodes.

# %%
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dense, Flatten, InputLayer, Activation, Dropout
from keras.models import Sequential

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(x_train, y_train, test_size=0.1)
print(np.shape(X_train), np.shape(Y_train))
print(np.shape(X_val), np.shape(Y_val))
# Out:
# (500, 60, 60, 1) (500,)
# (56, 60, 60, 1) (56,)

# %%
#modello 1
def make_model(shape=(60, 60, 1)):
  model = Sequential([
      
      Conv2D(8, (3,3), padding='same', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Conv2D(16, (3,3), padding='same'),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Conv2D(32, (3,3), padding='same'),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Flatten(),    #Flatten serves as a connection between the convolution and dense layers.

      Dense(10, activation='relu'),
      Dropout(0.2),
      Dense(1, activation='sigmoid')
     
  ])
  return model

# %%
'''
#VGG
def vgg(shape=(60, 60, 1)):
  model = Sequential([
      Conv2D(8, (3,3), padding='same', input_shape=shape),
      Activation('relu'),
      Conv2D(8, (3,3), padding='same'),
      Activation('relu'),               

      MaxPool2D((2,2), strides=2),

      Conv2D(16, (3,3), padding='same'),
      Activation('relu'),    
      Conv2D(16, (3,3), padding='same'),
      Activation('relu'),    

      MaxPool2D((2,2), strides=2),

      Conv2D(32, (3,3), padding='same'),
      Activation('relu'),    
      Conv2D(32, (3,3), padding='same'),
      Activation('relu'),    

      MaxPool2D((2,2), strides=2),

      Flatten(),
      Dense(10, activation='relu'),
      Dense(1, activation='softmax')
  ])
  return model
  '''
# Out:
# "\n#VGG\ndef vgg(shape=(60, 60, 1)):\n  model = Sequential([\n      Conv2D(8, (3,3), padding='same', input_shape=shape),\n      Activation('relu'),\n      Conv2D(8, (3,3), padding='same'),\n      Activation('relu'),               \n\n      MaxPool2D((2,2), strides=2),\n\n      Conv2D(16, (3,3), padding='same'),\n      Activation('relu'),    \n      Conv2D(16, (3,3), padding='same'),\n      Activation('relu'),    \n\n      MaxPool2D((2,2), strides=2),\n\n      Conv2D(32, (3,3), padding='same'),\n      Activation('relu'),    \n      Conv2D(32, (3,3), padding='same'),\n      Activation('relu'),    \n\n      MaxPool2D((2,2), strides=2),\n\n      Flatten(),\n      Dense(10, activation='relu'),\n      Dense(1, activation='softmax')\n  ])\n  return model\n  "

# %% [markdown]
# The output of each Conv2D and MaxPooling2D layer is a 3D shape tensor (height, width, channels). The size of width and height tends to decrease. The number of output channels for each Conv2D layer is controlled by the first argument (32 or 64).

# %%
model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 60, 60, 8)         80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 60, 8)         32
# _________________________________________________________________
# activation (Activation)      (None, 60, 60, 8)         0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 16)        1168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 32)        128
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                15690
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 21,813
# Trainable params: 21,701
# Non-trainable params: 112
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Next, we need to compile our model. Compiling the model takes three parameters: optimizer, loss and metrics.
# - The loss function ‘binary_crossentropy’ is the most common choice for classification and represents the function we want to minimize.
# - The optimizer is the algorithm procedure for minimizing the loss. A pivotal parameter of the optimizer is the learning rate which is the step size made by the loss function towards its minimum.
#
# - We will use the ‘accuracy’ metric to measure the model classification performance on both the validation set (during training) and the test set.

# %%
from keras.optimizers import SGD #stochastic gradient descent
epochs=500
learning_rate = 0.001
model.compile(optimizer=SGD(lr=learning_rate, momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc).
# [doc](https://keras.io/api/callbacks/)

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
checkpoint = ModelCheckpoint(
    "model-{epoch:02d}-{val_accuracy:.2f}.hdf5", 
    monitor='val_accuracy', 
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='auto', save_freq='epoch')

reduce_on_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=10,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0)

# %% [markdown]
# To train the model, we will use the ‘fit()’ function with the following parameters: training data (x_tain), target data (y_train), validation data, and the number of epochs.

# %%
batch_size = 32
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    steps_per_epoch = np.shape(X_train)[0]/batch_size,
                    verbose=1,
                    validation_data=(X_val, Y_val),
                    validation_steps=np.shape(X_val)[0]/batch_size,
                    callbacks=[checkpoint,reduce_on_plateau])
# Out:
# Epoch 1/500
# 15/15 [==============================] - 31s 58ms/step - loss: 0.7793 - accuracy: 0.5148 - val_loss: 0.6684 - val_accuracy: 0.7143
#
# Epoch 00001: val_accuracy improved from -inf to 0.71429, saving model to model-01-0.71.hdf5
# Epoch 2/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5543 - accuracy: 0.7158 - val_loss: 0.6696 - val_accuracy: 0.7679
#
# Epoch 00002: val_accuracy improved from 0.71429 to 0.76786, saving model to model-02-0.77.hdf5
# Epoch 3/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4957 - accuracy: 0.7373 - val_loss: 0.6765 - val_accuracy: 0.7143
#
# Epoch 00003: val_accuracy did not improve from 0.76786
# Epoch 4/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5282 - accuracy: 0.7092 - val_loss: 0.6809 - val_accuracy: 0.6786
#
# Epoch 00004: val_accuracy did not improve from 0.76786
# Epoch 5/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5003 - accuracy: 0.7557 - val_loss: 0.6813 - val_accuracy: 0.5714
#
# Epoch 00005: val_accuracy did not improve from 0.76786
# Epoch 6/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4872 - accuracy: 0.7355 - val_loss: 0.6760 - val_accuracy: 0.7321
#
# Epoch 00006: val_accuracy did not improve from 0.76786
# Epoch 7/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4807 - accuracy: 0.7454 - val_loss: 0.6737 - val_accuracy: 0.7143
#
# Epoch 00007: val_accuracy did not improve from 0.76786
# Epoch 8/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4546 - accuracy: 0.7787 - val_loss: 0.6793 - val_accuracy: 0.5000
#
# Epoch 00008: val_accuracy did not improve from 0.76786
# Epoch 9/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4344 - accuracy: 0.7996 - val_loss: 0.6659 - val_accuracy: 0.6786
#
# Epoch 00009: val_accuracy did not improve from 0.76786
# Epoch 10/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4486 - accuracy: 0.7524 - val_loss: 0.6771 - val_accuracy: 0.5357
#
# Epoch 00010: val_accuracy did not improve from 0.76786
# Epoch 11/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3899 - accuracy: 0.8346 - val_loss: 0.6734 - val_accuracy: 0.5179
#
# Epoch 00011: val_accuracy did not improve from 0.76786
# Epoch 12/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4078 - accuracy: 0.8331 - val_loss: 0.6626 - val_accuracy: 0.6071
#
# Epoch 00012: val_accuracy did not improve from 0.76786
# Epoch 13/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3794 - accuracy: 0.8241 - val_loss: 0.6898 - val_accuracy: 0.5000
#
# Epoch 00013: val_accuracy did not improve from 0.76786
# Epoch 14/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3711 - accuracy: 0.7833 - val_loss: 0.6847 - val_accuracy: 0.5536
#
# Epoch 00014: val_accuracy did not improve from 0.76786
# Epoch 15/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3353 - accuracy: 0.8415 - val_loss: 0.7346 - val_accuracy: 0.5000
#
# Epoch 00015: val_accuracy did not improve from 0.76786
# Epoch 16/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3164 - accuracy: 0.8727 - val_loss: 0.7401 - val_accuracy: 0.5000
#
# Epoch 00016: val_accuracy did not improve from 0.76786
# Epoch 17/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3576 - accuracy: 0.8341 - val_loss: 0.7059 - val_accuracy: 0.6071
#
# Epoch 00017: val_accuracy did not improve from 0.76786
# Epoch 18/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3659 - accuracy: 0.8353 - val_loss: 0.7500 - val_accuracy: 0.5536
#
# Epoch 00018: val_accuracy did not improve from 0.76786
# Epoch 19/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3068 - accuracy: 0.8618 - val_loss: 0.6634 - val_accuracy: 0.6429
#
# Epoch 00019: val_accuracy did not improve from 0.76786
# Epoch 20/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2955 - accuracy: 0.8771 - val_loss: 0.6889 - val_accuracy: 0.6250
#
# Epoch 00020: val_accuracy did not improve from 0.76786
# Epoch 21/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2906 - accuracy: 0.8657 - val_loss: 0.6493 - val_accuracy: 0.6429
#
# Epoch 00021: val_accuracy did not improve from 0.76786
# Epoch 22/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2981 - accuracy: 0.8673 - val_loss: 0.5908 - val_accuracy: 0.7321
#
# Epoch 00022: val_accuracy did not improve from 0.76786
# Epoch 23/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3009 - accuracy: 0.8715 - val_loss: 0.6486 - val_accuracy: 0.6607
#
# Epoch 00023: val_accuracy did not improve from 0.76786
# Epoch 24/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2921 - accuracy: 0.8727 - val_loss: 0.6667 - val_accuracy: 0.6964
#
# Epoch 00024: val_accuracy did not improve from 0.76786
# Epoch 25/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2560 - accuracy: 0.8971 - val_loss: 0.6865 - val_accuracy: 0.6786
#
# Epoch 00025: val_accuracy did not improve from 0.76786
# Epoch 26/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3199 - accuracy: 0.8636 - val_loss: 0.5628 - val_accuracy: 0.7679
#
# Epoch 00026: val_accuracy did not improve from 0.76786
# Epoch 27/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2426 - accuracy: 0.9020 - val_loss: 0.5324 - val_accuracy: 0.7321
#
# Epoch 00027: val_accuracy did not improve from 0.76786
# Epoch 28/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2910 - accuracy: 0.8777 - val_loss: 0.5329 - val_accuracy: 0.6964
#
# Epoch 00028: val_accuracy did not improve from 0.76786
# Epoch 29/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2412 - accuracy: 0.8937 - val_loss: 0.6806 - val_accuracy: 0.6964
#
# Epoch 00029: val_accuracy did not improve from 0.76786
# Epoch 30/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2818 - accuracy: 0.8701 - val_loss: 0.4552 - val_accuracy: 0.7500
#
# Epoch 00030: val_accuracy did not improve from 0.76786
# Epoch 31/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2240 - accuracy: 0.9240 - val_loss: 0.4740 - val_accuracy: 0.7321
#
# Epoch 00031: val_accuracy did not improve from 0.76786
# Epoch 32/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2133 - accuracy: 0.9138 - val_loss: 0.4998 - val_accuracy: 0.7500
#
# Epoch 00032: val_accuracy did not improve from 0.76786
# Epoch 33/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2129 - accuracy: 0.9068 - val_loss: 0.4889 - val_accuracy: 0.7500
#
# Epoch 00033: val_accuracy did not improve from 0.76786
# Epoch 34/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1973 - accuracy: 0.9329 - val_loss: 0.3075 - val_accuracy: 0.8750
#
# Epoch 00034: val_accuracy improved from 0.76786 to 0.87500, saving model to model-34-0.88.hdf5
# Epoch 35/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2292 - accuracy: 0.9171 - val_loss: 0.3894 - val_accuracy: 0.8750
#
# Epoch 00035: val_accuracy did not improve from 0.87500
# Epoch 36/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2102 - accuracy: 0.9081 - val_loss: 0.3991 - val_accuracy: 0.8393
#
# Epoch 00036: val_accuracy did not improve from 0.87500
# Epoch 37/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2584 - accuracy: 0.8871 - val_loss: 0.3886 - val_accuracy: 0.8750
#
# Epoch 00037: val_accuracy did not improve from 0.87500
# Epoch 38/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2454 - accuracy: 0.9051 - val_loss: 0.5155 - val_accuracy: 0.8393
#
# Epoch 00038: val_accuracy did not improve from 0.87500
# Epoch 39/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1514 - accuracy: 0.9439 - val_loss: 0.2891 - val_accuracy: 0.8750
#
# Epoch 00039: val_accuracy did not improve from 0.87500
# Epoch 40/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1500 - accuracy: 0.9650 - val_loss: 0.2306 - val_accuracy: 0.9286
#
# Epoch 00040: val_accuracy improved from 0.87500 to 0.92857, saving model to model-40-0.93.hdf5
# Epoch 41/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1696 - accuracy: 0.9393 - val_loss: 0.3683 - val_accuracy: 0.7679
#
# Epoch 00041: val_accuracy did not improve from 0.92857
# Epoch 42/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1954 - accuracy: 0.9287 - val_loss: 0.4230 - val_accuracy: 0.8571
#
# Epoch 00042: val_accuracy did not improve from 0.92857
# Epoch 43/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1755 - accuracy: 0.9293 - val_loss: 0.3709 - val_accuracy: 0.8036
#
# Epoch 00043: val_accuracy did not improve from 0.92857
# Epoch 44/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1784 - accuracy: 0.9102 - val_loss: 0.4906 - val_accuracy: 0.7679
#
# Epoch 00044: val_accuracy did not improve from 0.92857
# Epoch 45/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1765 - accuracy: 0.9267 - val_loss: 1.0806 - val_accuracy: 0.7679
#
# Epoch 00045: val_accuracy did not improve from 0.92857
# Epoch 46/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1655 - accuracy: 0.9356 - val_loss: 0.6624 - val_accuracy: 0.9107
#
# Epoch 00046: val_accuracy did not improve from 0.92857
# Epoch 47/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1699 - accuracy: 0.9238 - val_loss: 0.4166 - val_accuracy: 0.7857
#
# Epoch 00047: val_accuracy did not improve from 0.92857
# Epoch 48/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1404 - accuracy: 0.9619 - val_loss: 0.4038 - val_accuracy: 0.8929
#
# Epoch 00048: val_accuracy did not improve from 0.92857
# Epoch 49/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1684 - accuracy: 0.9461 - val_loss: 0.5760 - val_accuracy: 0.8929
#
# Epoch 00049: val_accuracy did not improve from 0.92857
# Epoch 50/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2072 - accuracy: 0.9305 - val_loss: 0.2920 - val_accuracy: 0.8929
#
# Epoch 00050: val_accuracy did not improve from 0.92857
# Epoch 51/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1525 - accuracy: 0.9382 - val_loss: 0.3806 - val_accuracy: 0.8393
#
# Epoch 00051: val_accuracy did not improve from 0.92857
# Epoch 52/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1490 - accuracy: 0.9409 - val_loss: 0.4472 - val_accuracy: 0.8036
#
# Epoch 00052: val_accuracy did not improve from 0.92857
# Epoch 53/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1174 - accuracy: 0.9527 - val_loss: 0.3377 - val_accuracy: 0.8571
#
# Epoch 00053: val_accuracy did not improve from 0.92857
# Epoch 54/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1275 - accuracy: 0.9475 - val_loss: 0.2843 - val_accuracy: 0.8929
#
# Epoch 00054: val_accuracy did not improve from 0.92857
# Epoch 55/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1476 - accuracy: 0.9364 - val_loss: 0.2714 - val_accuracy: 0.8929
#
# Epoch 00055: val_accuracy did not improve from 0.92857
# Epoch 56/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1548 - accuracy: 0.9406 - val_loss: 0.2770 - val_accuracy: 0.8929
#
# Epoch 00056: val_accuracy did not improve from 0.92857
# Epoch 57/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1449 - accuracy: 0.9471 - val_loss: 0.2497 - val_accuracy: 0.9107
#
# Epoch 00057: val_accuracy did not improve from 0.92857
# Epoch 58/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1174 - accuracy: 0.9653 - val_loss: 0.2435 - val_accuracy: 0.9107
#
# Epoch 00058: val_accuracy did not improve from 0.92857
# Epoch 59/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1285 - accuracy: 0.9557 - val_loss: 0.3084 - val_accuracy: 0.9107
#
# Epoch 00059: val_accuracy did not improve from 0.92857
# Epoch 60/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1124 - accuracy: 0.9668 - val_loss: 0.2777 - val_accuracy: 0.9107
#
# Epoch 00060: val_accuracy did not improve from 0.92857
# Epoch 61/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1210 - accuracy: 0.9579 - val_loss: 0.2550 - val_accuracy: 0.9107
#
# Epoch 00061: val_accuracy did not improve from 0.92857
# Epoch 62/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1135 - accuracy: 0.9635 - val_loss: 0.2537 - val_accuracy: 0.9107
#
# Epoch 00062: val_accuracy did not improve from 0.92857
# Epoch 63/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1193 - accuracy: 0.9552 - val_loss: 0.2516 - val_accuracy: 0.9107
#
# Epoch 00063: val_accuracy did not improve from 0.92857
# Epoch 64/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1499 - accuracy: 0.9586 - val_loss: 0.2497 - val_accuracy: 0.9107
#
# Epoch 00064: val_accuracy did not improve from 0.92857
# Epoch 65/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1201 - accuracy: 0.9687 - val_loss: 0.2474 - val_accuracy: 0.9107
#
# Epoch 00065: val_accuracy did not improve from 0.92857
# Epoch 66/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1435 - accuracy: 0.9472 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00066: val_accuracy did not improve from 0.92857
# Epoch 67/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1320 - accuracy: 0.9472 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00067: val_accuracy did not improve from 0.92857
# Epoch 68/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1150 - accuracy: 0.9735 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00068: val_accuracy did not improve from 0.92857
# Epoch 69/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1019 - accuracy: 0.9759 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00069: val_accuracy did not improve from 0.92857
# Epoch 70/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1136 - accuracy: 0.9671 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00070: val_accuracy did not improve from 0.92857
# Epoch 71/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1224 - accuracy: 0.9507 - val_loss: 0.2475 - val_accuracy: 0.9107
#
# Epoch 00071: val_accuracy did not improve from 0.92857
# Epoch 72/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1283 - accuracy: 0.9582 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00072: val_accuracy did not improve from 0.92857
# Epoch 73/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1237 - accuracy: 0.9559 - val_loss: 0.2468 - val_accuracy: 0.9107
#
# Epoch 00073: val_accuracy did not improve from 0.92857
# Epoch 74/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1171 - accuracy: 0.9452 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00074: val_accuracy did not improve from 0.92857
# Epoch 75/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0983 - accuracy: 0.9743 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00075: val_accuracy did not improve from 0.92857
# Epoch 76/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1340 - accuracy: 0.9542 - val_loss: 0.2448 - val_accuracy: 0.9107
#
# Epoch 00076: val_accuracy did not improve from 0.92857
# Epoch 77/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1265 - accuracy: 0.9448 - val_loss: 0.2452 - val_accuracy: 0.9107
#
# Epoch 00077: val_accuracy did not improve from 0.92857
# Epoch 78/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1175 - accuracy: 0.9689 - val_loss: 0.2453 - val_accuracy: 0.9107
#
# Epoch 00078: val_accuracy did not improve from 0.92857
# Epoch 79/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1174 - accuracy: 0.9621 - val_loss: 0.2453 - val_accuracy: 0.9107
#
# Epoch 00079: val_accuracy did not improve from 0.92857
# Epoch 80/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1258 - accuracy: 0.9614 - val_loss: 0.2454 - val_accuracy: 0.9107
#
# Epoch 00080: val_accuracy did not improve from 0.92857
# Epoch 81/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1350 - accuracy: 0.9298 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00081: val_accuracy did not improve from 0.92857
# Epoch 82/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1132 - accuracy: 0.9705 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00082: val_accuracy did not improve from 0.92857
# Epoch 83/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1641 - accuracy: 0.9447 - val_loss: 0.2475 - val_accuracy: 0.9107
#
# Epoch 00083: val_accuracy did not improve from 0.92857
# Epoch 84/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1542 - accuracy: 0.9345 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00084: val_accuracy did not improve from 0.92857
# Epoch 85/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1224 - accuracy: 0.9569 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00085: val_accuracy did not improve from 0.92857
# Epoch 86/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1023 - accuracy: 0.9815 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00086: val_accuracy did not improve from 0.92857
# Epoch 87/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1000 - accuracy: 0.9665 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00087: val_accuracy did not improve from 0.92857
# Epoch 88/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1047 - accuracy: 0.9632 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00088: val_accuracy did not improve from 0.92857
# Epoch 89/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1146 - accuracy: 0.9668 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00089: val_accuracy did not improve from 0.92857
# Epoch 90/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1402 - accuracy: 0.9278 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00090: val_accuracy did not improve from 0.92857
# Epoch 91/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0973 - accuracy: 0.9722 - val_loss: 0.2453 - val_accuracy: 0.9107
#
# Epoch 00091: val_accuracy did not improve from 0.92857
# Epoch 92/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1115 - accuracy: 0.9583 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00092: val_accuracy did not improve from 0.92857
# Epoch 93/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0972 - accuracy: 0.9674 - val_loss: 0.2455 - val_accuracy: 0.9107
#
# Epoch 00093: val_accuracy did not improve from 0.92857
# Epoch 94/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1282 - accuracy: 0.9523 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00094: val_accuracy did not improve from 0.92857
# Epoch 95/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1162 - accuracy: 0.9670 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00095: val_accuracy did not improve from 0.92857
# Epoch 96/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1174 - accuracy: 0.9549 - val_loss: 0.2469 - val_accuracy: 0.9107
#
# Epoch 00096: val_accuracy did not improve from 0.92857
# Epoch 97/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1530 - accuracy: 0.9342 - val_loss: 0.2474 - val_accuracy: 0.9107
#
# Epoch 00097: val_accuracy did not improve from 0.92857
# Epoch 98/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1206 - accuracy: 0.9591 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00098: val_accuracy did not improve from 0.92857
# Epoch 99/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1266 - accuracy: 0.9548 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00099: val_accuracy did not improve from 0.92857
# Epoch 100/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1106 - accuracy: 0.9558 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00100: val_accuracy did not improve from 0.92857
# Epoch 101/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1049 - accuracy: 0.9764 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00101: val_accuracy did not improve from 0.92857
# Epoch 102/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1266 - accuracy: 0.9488 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00102: val_accuracy did not improve from 0.92857
# Epoch 103/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1279 - accuracy: 0.9504 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00103: val_accuracy did not improve from 0.92857
# Epoch 104/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1330 - accuracy: 0.9547 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00104: val_accuracy did not improve from 0.92857
# Epoch 105/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1312 - accuracy: 0.9467 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00105: val_accuracy did not improve from 0.92857
# Epoch 106/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1132 - accuracy: 0.9663 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00106: val_accuracy did not improve from 0.92857
# Epoch 107/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1402 - accuracy: 0.9377 - val_loss: 0.2451 - val_accuracy: 0.9107
#
# Epoch 00107: val_accuracy did not improve from 0.92857
# Epoch 108/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1248 - accuracy: 0.9622 - val_loss: 0.2453 - val_accuracy: 0.9107
#
# Epoch 00108: val_accuracy did not improve from 0.92857
# Epoch 109/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1302 - accuracy: 0.9519 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00109: val_accuracy did not improve from 0.92857
# Epoch 110/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1276 - accuracy: 0.9523 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00110: val_accuracy did not improve from 0.92857
# Epoch 111/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1100 - accuracy: 0.9644 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00111: val_accuracy did not improve from 0.92857
# Epoch 112/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1317 - accuracy: 0.9595 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00112: val_accuracy did not improve from 0.92857
# Epoch 113/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1331 - accuracy: 0.9641 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00113: val_accuracy did not improve from 0.92857
# Epoch 114/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1862 - accuracy: 0.9426 - val_loss: 0.2468 - val_accuracy: 0.9107
#
# Epoch 00114: val_accuracy did not improve from 0.92857
# Epoch 115/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1238 - accuracy: 0.9575 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00115: val_accuracy did not improve from 0.92857
# Epoch 116/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1337 - accuracy: 0.9496 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00116: val_accuracy did not improve from 0.92857
# Epoch 117/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1322 - accuracy: 0.9539 - val_loss: 0.2472 - val_accuracy: 0.9107
#
# Epoch 00117: val_accuracy did not improve from 0.92857
# Epoch 118/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1018 - accuracy: 0.9703 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00118: val_accuracy did not improve from 0.92857
# Epoch 119/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1023 - accuracy: 0.9727 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00119: val_accuracy did not improve from 0.92857
# Epoch 120/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1051 - accuracy: 0.9704 - val_loss: 0.2469 - val_accuracy: 0.9107
#
# Epoch 00120: val_accuracy did not improve from 0.92857
# Epoch 121/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1325 - accuracy: 0.9621 - val_loss: 0.2491 - val_accuracy: 0.9107
#
# Epoch 00121: val_accuracy did not improve from 0.92857
# Epoch 122/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1076 - accuracy: 0.9651 - val_loss: 0.2495 - val_accuracy: 0.9107
#
# Epoch 00122: val_accuracy did not improve from 0.92857
# Epoch 123/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1001 - accuracy: 0.9608 - val_loss: 0.2488 - val_accuracy: 0.9107
#
# Epoch 00123: val_accuracy did not improve from 0.92857
# Epoch 124/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1047 - accuracy: 0.9735 - val_loss: 0.2480 - val_accuracy: 0.9107
#
# Epoch 00124: val_accuracy did not improve from 0.92857
# Epoch 125/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1326 - accuracy: 0.9568 - val_loss: 0.2469 - val_accuracy: 0.9107
#
# Epoch 00125: val_accuracy did not improve from 0.92857
# Epoch 126/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1203 - accuracy: 0.9573 - val_loss: 0.2479 - val_accuracy: 0.9107
#
# Epoch 00126: val_accuracy did not improve from 0.92857
# Epoch 127/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1083 - accuracy: 0.9670 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00127: val_accuracy did not improve from 0.92857
# Epoch 128/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1185 - accuracy: 0.9637 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00128: val_accuracy did not improve from 0.92857
# Epoch 129/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1045 - accuracy: 0.9545 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00129: val_accuracy did not improve from 0.92857
# Epoch 130/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1058 - accuracy: 0.9654 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00130: val_accuracy did not improve from 0.92857
# Epoch 131/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1072 - accuracy: 0.9667 - val_loss: 0.2472 - val_accuracy: 0.9107
#
# Epoch 00131: val_accuracy did not improve from 0.92857
# Epoch 132/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1063 - accuracy: 0.9680 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00132: val_accuracy did not improve from 0.92857
# Epoch 133/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1138 - accuracy: 0.9743 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00133: val_accuracy did not improve from 0.92857
# Epoch 134/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0946 - accuracy: 0.9776 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00134: val_accuracy did not improve from 0.92857
# Epoch 135/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1268 - accuracy: 0.9485 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00135: val_accuracy did not improve from 0.92857
# Epoch 136/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1055 - accuracy: 0.9717 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00136: val_accuracy did not improve from 0.92857
# Epoch 137/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1067 - accuracy: 0.9564 - val_loss: 0.2468 - val_accuracy: 0.9107
#
# Epoch 00137: val_accuracy did not improve from 0.92857
# Epoch 138/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1306 - accuracy: 0.9424 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00138: val_accuracy did not improve from 0.92857
# Epoch 139/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1304 - accuracy: 0.9576 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00139: val_accuracy did not improve from 0.92857
# Epoch 140/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1157 - accuracy: 0.9475 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00140: val_accuracy did not improve from 0.92857
# Epoch 141/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1072 - accuracy: 0.9624 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00141: val_accuracy did not improve from 0.92857
# Epoch 142/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1263 - accuracy: 0.9553 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00142: val_accuracy did not improve from 0.92857
# Epoch 143/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1060 - accuracy: 0.9647 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00143: val_accuracy did not improve from 0.92857
# Epoch 144/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1628 - accuracy: 0.9350 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00144: val_accuracy did not improve from 0.92857
# Epoch 145/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1140 - accuracy: 0.9732 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00145: val_accuracy did not improve from 0.92857
# Epoch 146/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1063 - accuracy: 0.9613 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00146: val_accuracy did not improve from 0.92857
# Epoch 147/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1439 - accuracy: 0.9455 - val_loss: 0.2469 - val_accuracy: 0.9107
#
# Epoch 00147: val_accuracy did not improve from 0.92857
# Epoch 148/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1511 - accuracy: 0.9339 - val_loss: 0.2485 - val_accuracy: 0.9107
#
# Epoch 00148: val_accuracy did not improve from 0.92857
# Epoch 149/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1185 - accuracy: 0.9576 - val_loss: 0.2478 - val_accuracy: 0.9107
#
# Epoch 00149: val_accuracy did not improve from 0.92857
# Epoch 150/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1209 - accuracy: 0.9565 - val_loss: 0.2480 - val_accuracy: 0.9107
#
# Epoch 00150: val_accuracy did not improve from 0.92857
# Epoch 151/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1347 - accuracy: 0.9506 - val_loss: 0.2482 - val_accuracy: 0.9107
#
# Epoch 00151: val_accuracy did not improve from 0.92857
# Epoch 152/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1197 - accuracy: 0.9670 - val_loss: 0.2487 - val_accuracy: 0.9107
#
# Epoch 00152: val_accuracy did not improve from 0.92857
# Epoch 153/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1094 - accuracy: 0.9686 - val_loss: 0.2482 - val_accuracy: 0.9107
#
# Epoch 00153: val_accuracy did not improve from 0.92857
# Epoch 154/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1164 - accuracy: 0.9612 - val_loss: 0.2486 - val_accuracy: 0.9107
#
# Epoch 00154: val_accuracy did not improve from 0.92857
# Epoch 155/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0893 - accuracy: 0.9693 - val_loss: 0.2476 - val_accuracy: 0.9107
#
# Epoch 00155: val_accuracy did not improve from 0.92857
# Epoch 156/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0931 - accuracy: 0.9729 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00156: val_accuracy did not improve from 0.92857
# Epoch 157/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1522 - accuracy: 0.9412 - val_loss: 0.2468 - val_accuracy: 0.9107
#
# Epoch 00157: val_accuracy did not improve from 0.92857
# Epoch 158/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1210 - accuracy: 0.9622 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00158: val_accuracy did not improve from 0.92857
# Epoch 159/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0889 - accuracy: 0.9812 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00159: val_accuracy did not improve from 0.92857
# Epoch 160/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1040 - accuracy: 0.9768 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00160: val_accuracy did not improve from 0.92857
# Epoch 161/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1123 - accuracy: 0.9626 - val_loss: 0.2454 - val_accuracy: 0.9107
#
# Epoch 00161: val_accuracy did not improve from 0.92857
# Epoch 162/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1187 - accuracy: 0.9631 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00162: val_accuracy did not improve from 0.92857
# Epoch 163/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0956 - accuracy: 0.9749 - val_loss: 0.2454 - val_accuracy: 0.9107
#
# Epoch 00163: val_accuracy did not improve from 0.92857
# Epoch 164/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1130 - accuracy: 0.9612 - val_loss: 0.2455 - val_accuracy: 0.9107
#
# Epoch 00164: val_accuracy did not improve from 0.92857
# Epoch 165/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1321 - accuracy: 0.9472 - val_loss: 0.2455 - val_accuracy: 0.9107
#
# Epoch 00165: val_accuracy did not improve from 0.92857
# Epoch 166/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1062 - accuracy: 0.9767 - val_loss: 0.2451 - val_accuracy: 0.9107
#
# Epoch 00166: val_accuracy did not improve from 0.92857
# Epoch 167/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1260 - accuracy: 0.9588 - val_loss: 0.2449 - val_accuracy: 0.9107
#
# Epoch 00167: val_accuracy did not improve from 0.92857
# Epoch 168/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1437 - accuracy: 0.9453 - val_loss: 0.2443 - val_accuracy: 0.9107
#
# Epoch 00168: val_accuracy did not improve from 0.92857
# Epoch 169/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1088 - accuracy: 0.9618 - val_loss: 0.2442 - val_accuracy: 0.9107
#
# Epoch 00169: val_accuracy did not improve from 0.92857
# Epoch 170/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1073 - accuracy: 0.9567 - val_loss: 0.2442 - val_accuracy: 0.9107
#
# Epoch 00170: val_accuracy did not improve from 0.92857
# Epoch 171/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1149 - accuracy: 0.9686 - val_loss: 0.2454 - val_accuracy: 0.9107
#
# Epoch 00171: val_accuracy did not improve from 0.92857
# Epoch 172/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0967 - accuracy: 0.9727 - val_loss: 0.2449 - val_accuracy: 0.9107
#
# Epoch 00172: val_accuracy did not improve from 0.92857
# Epoch 173/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1039 - accuracy: 0.9747 - val_loss: 0.2449 - val_accuracy: 0.9107
#
# Epoch 00173: val_accuracy did not improve from 0.92857
# Epoch 174/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1246 - accuracy: 0.9537 - val_loss: 0.2447 - val_accuracy: 0.9107
#
# Epoch 00174: val_accuracy did not improve from 0.92857
# Epoch 175/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1045 - accuracy: 0.9719 - val_loss: 0.2453 - val_accuracy: 0.9107
#
# Epoch 00175: val_accuracy did not improve from 0.92857
# Epoch 176/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1300 - accuracy: 0.9557 - val_loss: 0.2450 - val_accuracy: 0.9107
#
# Epoch 00176: val_accuracy did not improve from 0.92857
# Epoch 177/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1210 - accuracy: 0.9701 - val_loss: 0.2446 - val_accuracy: 0.9107
#
# Epoch 00177: val_accuracy did not improve from 0.92857
# Epoch 178/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1199 - accuracy: 0.9549 - val_loss: 0.2451 - val_accuracy: 0.9107
#
# Epoch 00178: val_accuracy did not improve from 0.92857
# Epoch 179/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1015 - accuracy: 0.9680 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00179: val_accuracy did not improve from 0.92857
# Epoch 180/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1190 - accuracy: 0.9624 - val_loss: 0.2452 - val_accuracy: 0.9107
#
# Epoch 00180: val_accuracy did not improve from 0.92857
# Epoch 181/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1079 - accuracy: 0.9688 - val_loss: 0.2449 - val_accuracy: 0.9107
#
# Epoch 00181: val_accuracy did not improve from 0.92857
# Epoch 182/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1061 - accuracy: 0.9679 - val_loss: 0.2447 - val_accuracy: 0.9107
#
# Epoch 00182: val_accuracy did not improve from 0.92857
# Epoch 183/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1324 - accuracy: 0.9460 - val_loss: 0.2448 - val_accuracy: 0.9107
#
# Epoch 00183: val_accuracy did not improve from 0.92857
# Epoch 184/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1119 - accuracy: 0.9645 - val_loss: 0.2444 - val_accuracy: 0.9107
#
# Epoch 00184: val_accuracy did not improve from 0.92857
# Epoch 185/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0931 - accuracy: 0.9749 - val_loss: 0.2441 - val_accuracy: 0.9107
#
# Epoch 00185: val_accuracy did not improve from 0.92857
# Epoch 186/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1290 - accuracy: 0.9445 - val_loss: 0.2436 - val_accuracy: 0.9107
#
# Epoch 00186: val_accuracy did not improve from 0.92857
# Epoch 187/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1349 - accuracy: 0.9468 - val_loss: 0.2439 - val_accuracy: 0.9107
#
# Epoch 00187: val_accuracy did not improve from 0.92857
# Epoch 188/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1008 - accuracy: 0.9626 - val_loss: 0.2448 - val_accuracy: 0.9107
#
# Epoch 00188: val_accuracy did not improve from 0.92857
# Epoch 189/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1247 - accuracy: 0.9468 - val_loss: 0.2450 - val_accuracy: 0.9107
#
# Epoch 00189: val_accuracy did not improve from 0.92857
# Epoch 190/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1177 - accuracy: 0.9618 - val_loss: 0.2449 - val_accuracy: 0.9107
#
# Epoch 00190: val_accuracy did not improve from 0.92857
# Epoch 191/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0887 - accuracy: 0.9710 - val_loss: 0.2447 - val_accuracy: 0.9107
#
# Epoch 00191: val_accuracy did not improve from 0.92857
# Epoch 192/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1812 - accuracy: 0.9167 - val_loss: 0.2451 - val_accuracy: 0.9107
#
# Epoch 00192: val_accuracy did not improve from 0.92857
# Epoch 193/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1277 - accuracy: 0.9532 - val_loss: 0.2445 - val_accuracy: 0.9107
#
# Epoch 00193: val_accuracy did not improve from 0.92857
# Epoch 194/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1062 - accuracy: 0.9657 - val_loss: 0.2444 - val_accuracy: 0.9107
#
# Epoch 00194: val_accuracy did not improve from 0.92857
# Epoch 195/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1257 - accuracy: 0.9639 - val_loss: 0.2450 - val_accuracy: 0.9107
#
# Epoch 00195: val_accuracy did not improve from 0.92857
# Epoch 196/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1134 - accuracy: 0.9602 - val_loss: 0.2452 - val_accuracy: 0.9107
#
# Epoch 00196: val_accuracy did not improve from 0.92857
# Epoch 197/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1218 - accuracy: 0.9528 - val_loss: 0.2448 - val_accuracy: 0.9107
#
# Epoch 00197: val_accuracy did not improve from 0.92857
# Epoch 198/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1059 - accuracy: 0.9691 - val_loss: 0.2442 - val_accuracy: 0.9107
#
# Epoch 00198: val_accuracy did not improve from 0.92857
# Epoch 199/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1029 - accuracy: 0.9604 - val_loss: 0.2442 - val_accuracy: 0.9107
#
# Epoch 00199: val_accuracy did not improve from 0.92857
# Epoch 200/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1354 - accuracy: 0.9569 - val_loss: 0.2449 - val_accuracy: 0.9107
#
# Epoch 00200: val_accuracy did not improve from 0.92857
# Epoch 201/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1231 - accuracy: 0.9488 - val_loss: 0.2445 - val_accuracy: 0.9107
#
# Epoch 00201: val_accuracy did not improve from 0.92857
# Epoch 202/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1418 - accuracy: 0.9609 - val_loss: 0.2441 - val_accuracy: 0.9107
#
# Epoch 00202: val_accuracy did not improve from 0.92857
# Epoch 203/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1262 - accuracy: 0.9476 - val_loss: 0.2446 - val_accuracy: 0.9107
#
# Epoch 00203: val_accuracy did not improve from 0.92857
# Epoch 204/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1287 - accuracy: 0.9534 - val_loss: 0.2445 - val_accuracy: 0.9107
#
# Epoch 00204: val_accuracy did not improve from 0.92857
# Epoch 205/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2077 - accuracy: 0.9429 - val_loss: 0.2455 - val_accuracy: 0.9107
#
# Epoch 00205: val_accuracy did not improve from 0.92857
# Epoch 206/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1054 - accuracy: 0.9742 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00206: val_accuracy did not improve from 0.92857
# Epoch 207/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1557 - accuracy: 0.9517 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00207: val_accuracy did not improve from 0.92857
# Epoch 208/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1210 - accuracy: 0.9570 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00208: val_accuracy did not improve from 0.92857
# Epoch 209/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1341 - accuracy: 0.9560 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00209: val_accuracy did not improve from 0.92857
# Epoch 210/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1076 - accuracy: 0.9600 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00210: val_accuracy did not improve from 0.92857
# Epoch 211/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1199 - accuracy: 0.9633 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00211: val_accuracy did not improve from 0.92857
# Epoch 212/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1249 - accuracy: 0.9568 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00212: val_accuracy did not improve from 0.92857
# Epoch 213/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1134 - accuracy: 0.9658 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00213: val_accuracy did not improve from 0.92857
# Epoch 214/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1227 - accuracy: 0.9682 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00214: val_accuracy did not improve from 0.92857
# Epoch 215/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1271 - accuracy: 0.9514 - val_loss: 0.2469 - val_accuracy: 0.9107
#
# Epoch 00215: val_accuracy did not improve from 0.92857
# Epoch 216/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1109 - accuracy: 0.9663 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00216: val_accuracy did not improve from 0.92857
# Epoch 217/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1163 - accuracy: 0.9681 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00217: val_accuracy did not improve from 0.92857
# Epoch 218/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1698 - accuracy: 0.9274 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00218: val_accuracy did not improve from 0.92857
# Epoch 219/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1314 - accuracy: 0.9580 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00219: val_accuracy did not improve from 0.92857
# Epoch 220/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1130 - accuracy: 0.9724 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00220: val_accuracy did not improve from 0.92857
# Epoch 221/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1062 - accuracy: 0.9709 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00221: val_accuracy did not improve from 0.92857
# Epoch 222/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1274 - accuracy: 0.9557 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00222: val_accuracy did not improve from 0.92857
# Epoch 223/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1249 - accuracy: 0.9628 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00223: val_accuracy did not improve from 0.92857
# Epoch 224/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1046 - accuracy: 0.9693 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00224: val_accuracy did not improve from 0.92857
# Epoch 225/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1024 - accuracy: 0.9560 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00225: val_accuracy did not improve from 0.92857
# Epoch 226/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1375 - accuracy: 0.9608 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00226: val_accuracy did not improve from 0.92857
# Epoch 227/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1164 - accuracy: 0.9594 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00227: val_accuracy did not improve from 0.92857
# Epoch 228/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1278 - accuracy: 0.9438 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00228: val_accuracy did not improve from 0.92857
# Epoch 229/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1223 - accuracy: 0.9569 - val_loss: 0.2473 - val_accuracy: 0.9107
#
# Epoch 00229: val_accuracy did not improve from 0.92857
# Epoch 230/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1626 - accuracy: 0.9264 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00230: val_accuracy did not improve from 0.92857
# Epoch 231/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0950 - accuracy: 0.9650 - val_loss: 0.2477 - val_accuracy: 0.9107
#
# Epoch 00231: val_accuracy did not improve from 0.92857
# Epoch 232/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1102 - accuracy: 0.9535 - val_loss: 0.2481 - val_accuracy: 0.9107
#
# Epoch 00232: val_accuracy did not improve from 0.92857
# Epoch 233/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1201 - accuracy: 0.9556 - val_loss: 0.2473 - val_accuracy: 0.9107
#
# Epoch 00233: val_accuracy did not improve from 0.92857
# Epoch 234/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1273 - accuracy: 0.9455 - val_loss: 0.2479 - val_accuracy: 0.9107
#
# Epoch 00234: val_accuracy did not improve from 0.92857
# Epoch 235/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1152 - accuracy: 0.9629 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00235: val_accuracy did not improve from 0.92857
# Epoch 236/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1357 - accuracy: 0.9400 - val_loss: 0.2474 - val_accuracy: 0.9107
#
# Epoch 00236: val_accuracy did not improve from 0.92857
# Epoch 237/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0909 - accuracy: 0.9800 - val_loss: 0.2478 - val_accuracy: 0.9107
#
# Epoch 00237: val_accuracy did not improve from 0.92857
# Epoch 238/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1494 - accuracy: 0.9275 - val_loss: 0.2474 - val_accuracy: 0.9107
#
# Epoch 00238: val_accuracy did not improve from 0.92857
# Epoch 239/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1947 - accuracy: 0.9292 - val_loss: 0.2476 - val_accuracy: 0.9107
#
# Epoch 00239: val_accuracy did not improve from 0.92857
# Epoch 240/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1133 - accuracy: 0.9714 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# ...
# Epoch 421/500
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1084 - accuracy: 0.9739 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00421: val_accuracy did not improve from 0.92857
# Epoch 422/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1369 - accuracy: 0.9536 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00422: val_accuracy did not improve from 0.92857
# Epoch 423/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1205 - accuracy: 0.9555 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00423: val_accuracy did not improve from 0.92857
# Epoch 424/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1027 - accuracy: 0.9715 - val_loss: 0.2472 - val_accuracy: 0.9107
#
# Epoch 00424: val_accuracy did not improve from 0.92857
# Epoch 425/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1034 - accuracy: 0.9733 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00425: val_accuracy did not improve from 0.92857
# Epoch 426/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1368 - accuracy: 0.9545 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00426: val_accuracy did not improve from 0.92857
# Epoch 427/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1298 - accuracy: 0.9608 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00427: val_accuracy did not improve from 0.92857
# Epoch 428/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1165 - accuracy: 0.9502 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00428: val_accuracy did not improve from 0.92857
# Epoch 429/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1059 - accuracy: 0.9618 - val_loss: 0.2475 - val_accuracy: 0.9107
#
# Epoch 00429: val_accuracy did not improve from 0.92857
# Epoch 430/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1068 - accuracy: 0.9572 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00430: val_accuracy did not improve from 0.92857
# Epoch 431/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0931 - accuracy: 0.9730 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00431: val_accuracy did not improve from 0.92857
# Epoch 432/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1111 - accuracy: 0.9696 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00432: val_accuracy did not improve from 0.92857
# Epoch 433/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1166 - accuracy: 0.9606 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00433: val_accuracy did not improve from 0.92857
# Epoch 434/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1302 - accuracy: 0.9522 - val_loss: 0.2468 - val_accuracy: 0.9107
#
# Epoch 00434: val_accuracy did not improve from 0.92857
# Epoch 435/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1222 - accuracy: 0.9605 - val_loss: 0.2473 - val_accuracy: 0.9107
#
# Epoch 00435: val_accuracy did not improve from 0.92857
# Epoch 436/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1140 - accuracy: 0.9634 - val_loss: 0.2473 - val_accuracy: 0.9107
#
# Epoch 00436: val_accuracy did not improve from 0.92857
# Epoch 437/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1062 - accuracy: 0.9652 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00437: val_accuracy did not improve from 0.92857
# Epoch 438/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1084 - accuracy: 0.9680 - val_loss: 0.2468 - val_accuracy: 0.9107
#
# Epoch 00438: val_accuracy did not improve from 0.92857
# Epoch 439/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1224 - accuracy: 0.9616 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00439: val_accuracy did not improve from 0.92857
# Epoch 440/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1189 - accuracy: 0.9622 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00440: val_accuracy did not improve from 0.92857
# Epoch 441/500
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1339 - accuracy: 0.9565 - val_loss: 0.2455 - val_accuracy: 0.9107
#
# Epoch 00441: val_accuracy did not improve from 0.92857
# Epoch 442/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1037 - accuracy: 0.9675 - val_loss: 0.2453 - val_accuracy: 0.9107
#
# Epoch 00442: val_accuracy did not improve from 0.92857
# Epoch 443/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1091 - accuracy: 0.9683 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00443: val_accuracy did not improve from 0.92857
# Epoch 444/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1155 - accuracy: 0.9675 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00444: val_accuracy did not improve from 0.92857
# Epoch 445/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1243 - accuracy: 0.9587 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00445: val_accuracy did not improve from 0.92857
# Epoch 446/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1128 - accuracy: 0.9661 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00446: val_accuracy did not improve from 0.92857
# Epoch 447/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0924 - accuracy: 0.9758 - val_loss: 0.2448 - val_accuracy: 0.9107
#
# Epoch 00447: val_accuracy did not improve from 0.92857
# Epoch 448/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1242 - accuracy: 0.9614 - val_loss: 0.2451 - val_accuracy: 0.9107
#
# Epoch 00448: val_accuracy did not improve from 0.92857
# Epoch 449/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1232 - accuracy: 0.9564 - val_loss: 0.2445 - val_accuracy: 0.9107
#
# Epoch 00449: val_accuracy did not improve from 0.92857
# Epoch 450/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1067 - accuracy: 0.9538 - val_loss: 0.2450 - val_accuracy: 0.9107
#
# Epoch 00450: val_accuracy did not improve from 0.92857
# Epoch 451/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0919 - accuracy: 0.9712 - val_loss: 0.2448 - val_accuracy: 0.9107
#
# Epoch 00451: val_accuracy did not improve from 0.92857
# Epoch 452/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1382 - accuracy: 0.9488 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00452: val_accuracy did not improve from 0.92857
# Epoch 453/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1419 - accuracy: 0.9401 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00453: val_accuracy did not improve from 0.92857
# Epoch 454/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1320 - accuracy: 0.9482 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00454: val_accuracy did not improve from 0.92857
# Epoch 455/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1292 - accuracy: 0.9523 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00455: val_accuracy did not improve from 0.92857
# Epoch 456/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1301 - accuracy: 0.9526 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00456: val_accuracy did not improve from 0.92857
# Epoch 457/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1114 - accuracy: 0.9597 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00457: val_accuracy did not improve from 0.92857
# Epoch 458/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1132 - accuracy: 0.9680 - val_loss: 0.2477 - val_accuracy: 0.9107
#
# Epoch 00458: val_accuracy did not improve from 0.92857
# Epoch 459/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1529 - accuracy: 0.9361 - val_loss: 0.2472 - val_accuracy: 0.9107
#
# Epoch 00459: val_accuracy did not improve from 0.92857
# Epoch 460/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0969 - accuracy: 0.9729 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00460: val_accuracy did not improve from 0.92857
# Epoch 461/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1221 - accuracy: 0.9667 - val_loss: 0.2459 - val_accuracy: 0.9107
#
# Epoch 00461: val_accuracy did not improve from 0.92857
# Epoch 462/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1318 - accuracy: 0.9606 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00462: val_accuracy did not improve from 0.92857
# Epoch 463/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1300 - accuracy: 0.9569 - val_loss: 0.2463 - val_accuracy: 0.9107
#
# Epoch 00463: val_accuracy did not improve from 0.92857
# Epoch 464/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1139 - accuracy: 0.9657 - val_loss: 0.2451 - val_accuracy: 0.9107
#
# Epoch 00464: val_accuracy did not improve from 0.92857
# Epoch 465/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1286 - accuracy: 0.9586 - val_loss: 0.2454 - val_accuracy: 0.9107
#
# Epoch 00465: val_accuracy did not improve from 0.92857
# Epoch 466/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1023 - accuracy: 0.9701 - val_loss: 0.2460 - val_accuracy: 0.9107
#
# Epoch 00466: val_accuracy did not improve from 0.92857
# Epoch 467/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1741 - accuracy: 0.9283 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00467: val_accuracy did not improve from 0.92857
# Epoch 468/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1379 - accuracy: 0.9400 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00468: val_accuracy did not improve from 0.92857
# Epoch 469/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1214 - accuracy: 0.9585 - val_loss: 0.2462 - val_accuracy: 0.9107
#
# Epoch 00469: val_accuracy did not improve from 0.92857
# Epoch 470/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1154 - accuracy: 0.9673 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00470: val_accuracy did not improve from 0.92857
# Epoch 471/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1203 - accuracy: 0.9609 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00471: val_accuracy did not improve from 0.92857
# Epoch 472/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1446 - accuracy: 0.9427 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00472: val_accuracy did not improve from 0.92857
# Epoch 473/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1132 - accuracy: 0.9659 - val_loss: 0.2461 - val_accuracy: 0.9107
#
# Epoch 00473: val_accuracy did not improve from 0.92857
# Epoch 474/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0971 - accuracy: 0.9708 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00474: val_accuracy did not improve from 0.92857
# Epoch 475/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1301 - accuracy: 0.9416 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00475: val_accuracy did not improve from 0.92857
# Epoch 476/500
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1268 - accuracy: 0.9499 - val_loss: 0.2456 - val_accuracy: 0.9107
#
# Epoch 00476: val_accuracy did not improve from 0.92857
# Epoch 477/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1177 - accuracy: 0.9651 - val_loss: 0.2457 - val_accuracy: 0.9107
#
# Epoch 00477: val_accuracy did not improve from 0.92857
# Epoch 478/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1261 - accuracy: 0.9647 - val_loss: 0.2458 - val_accuracy: 0.9107
#
# Epoch 00478: val_accuracy did not improve from 0.92857
# Epoch 479/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1134 - accuracy: 0.9569 - val_loss: 0.2464 - val_accuracy: 0.9107
#
# Epoch 00479: val_accuracy did not improve from 0.92857
# Epoch 480/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1213 - accuracy: 0.9638 - val_loss: 0.2466 - val_accuracy: 0.9107
#
# Epoch 00480: val_accuracy did not improve from 0.92857
# Epoch 481/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1132 - accuracy: 0.9616 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00481: val_accuracy did not improve from 0.92857
# Epoch 482/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1408 - accuracy: 0.9392 - val_loss: 0.2473 - val_accuracy: 0.9107
#
# Epoch 00482: val_accuracy did not improve from 0.92857
# Epoch 483/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1186 - accuracy: 0.9525 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00483: val_accuracy did not improve from 0.92857
# Epoch 484/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1038 - accuracy: 0.9711 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00484: val_accuracy did not improve from 0.92857
# Epoch 485/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1564 - accuracy: 0.9583 - val_loss: 0.2474 - val_accuracy: 0.9107
#
# Epoch 00485: val_accuracy did not improve from 0.92857
# Epoch 486/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1022 - accuracy: 0.9729 - val_loss: 0.2470 - val_accuracy: 0.9107
#
# Epoch 00486: val_accuracy did not improve from 0.92857
# Epoch 487/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1229 - accuracy: 0.9667 - val_loss: 0.2475 - val_accuracy: 0.9107
#
# Epoch 00487: val_accuracy did not improve from 0.92857
# Epoch 488/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1055 - accuracy: 0.9680 - val_loss: 0.2479 - val_accuracy: 0.9107
#
# Epoch 00488: val_accuracy did not improve from 0.92857
# Epoch 489/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1328 - accuracy: 0.9622 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00489: val_accuracy did not improve from 0.92857
# Epoch 490/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1636 - accuracy: 0.9383 - val_loss: 0.2478 - val_accuracy: 0.9107
#
# Epoch 00490: val_accuracy did not improve from 0.92857
# Epoch 491/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1140 - accuracy: 0.9647 - val_loss: 0.2478 - val_accuracy: 0.9107
#
# Epoch 00491: val_accuracy did not improve from 0.92857
# Epoch 492/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1054 - accuracy: 0.9719 - val_loss: 0.2478 - val_accuracy: 0.9107
#
# Epoch 00492: val_accuracy did not improve from 0.92857
# Epoch 493/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1177 - accuracy: 0.9529 - val_loss: 0.2475 - val_accuracy: 0.9107
#
# Epoch 00493: val_accuracy did not improve from 0.92857
# Epoch 494/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1475 - accuracy: 0.9413 - val_loss: 0.2474 - val_accuracy: 0.9107
#
# Epoch 00494: val_accuracy did not improve from 0.92857
# Epoch 495/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1211 - accuracy: 0.9629 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00495: val_accuracy did not improve from 0.92857
# Epoch 496/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1193 - accuracy: 0.9648 - val_loss: 0.2467 - val_accuracy: 0.9107
#
# Epoch 00496: val_accuracy did not improve from 0.92857
# Epoch 497/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1405 - accuracy: 0.9568 - val_loss: 0.2469 - val_accuracy: 0.9107
#
# Epoch 00497: val_accuracy did not improve from 0.92857
# Epoch 498/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1262 - accuracy: 0.9489 - val_loss: 0.2475 - val_accuracy: 0.9107
#
# Epoch 00498: val_accuracy did not improve from 0.92857
# Epoch 499/500
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1373 - accuracy: 0.9396 - val_loss: 0.2471 - val_accuracy: 0.9107
#
# Epoch 00499: val_accuracy did not improve from 0.92857
# Epoch 500/500
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1100 - accuracy: 0.9663 - val_loss: 0.2465 - val_accuracy: 0.9107
#
# Epoch 00500: val_accuracy did not improve from 0.92857

# %% [markdown]
# Evaluate the network performance on train data

# %%
_, train_acc = model.evaluate(x_train, y_train, verbose=0)
print('Train accuracy: %.3f' % (train_acc))
# Out:
# Train accuracy: 0.978

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy 
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss 
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Save the trained model

# %%
model.save('/content/model.hdf5')

# %%
# !ls
# Out:
# gdrive		    model-02-0.77.hdf5	model-40-0.93.hdf5  sample_data
# model-01-0.71.hdf5  model-34-0.88.hdf5	model.hdf5

# %% [markdown]
# Evaluate network performance on test data in term of accuracy.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3142 - accuracy: 0.9129
#
# Test accuracy: 0.9128630757331848

# %% [markdown]
# Create the ROC curve and AUC (compute the false-positive rate and the true-positive rate)

# %%
from sklearn.metrics import roc_curve, auc
preds = model.predict(x_test, verbose=1)

fpr, tpr, _ = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %% [markdown]
# # Data augmentation
# To perform data augmentation with ImageDataGenerator, we need to convert the PGM format to PNG.

# %%
import PIL
import os

# %%
def convert_to_png(fname, dest_folder):
  if not os.path.exists(dest_folder):
    os.makedirs(dest_folder)
  dest_fname = os.path.basename(fname).replace('.pgm', '.png')
  dest_fname = os.path.join(dest_folder, dest_fname)
  PIL.Image.open(fname).convert('L').save(dest_fname)

# %%
for data_path in ['/content/gdrive/MyDrive/Mammography_micro/Train', '/content/gdrive/MyDrive/Mammography_micro/Test']:
  for path, folders, fnames in os.walk(data_path):
    for fname in fnames:
      abs_path = os.path.join(path, fname)
      dest_folder = path.replace('Train', 'Train_png').replace('Test', 'Test_png')
      convert_to_png(abs_path, dest_folder)

# %%
# !ls /content/gdrive/MyDrive/Mammography_micro/Test_png/
# Out:
# 0  1

# %% [markdown]
# Data augmentation is a process of artificially creating new training data from the existing one. This is particularly useful in medical physics since data is usually scarce. Data augmentation relies on the ImageDataGenerator class of keras
# [[doc](https://keras.io/api/preprocessing/image/)]

# %%
import matplotlib.pyplot as plt

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dataset_path = '/content/gdrive/MyDrive/Mammography_micro/Train_png'
img_width, img_height = (60, 60)

train_datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.1,
        height_shift_range=0.1,
        #rescale=1./255,
        #shear_range=0.2,
        #zoom_range=0.18,
        horizontal_flip=True,
        #vertical_flip=True,
        fill_mode='reflect', #  nearest?
        validation_split=0.3)
        
train_gen = train_datagen.flow_from_directory(
    train_dataset_path,
    target_size=(img_width, img_height),
    color_mode='grayscale', 
    class_mode='binary',
    subset='training')

val_gen = train_datagen.flow_from_directory(
    train_dataset_path,
    target_size=(img_width, img_height),
    color_mode='grayscale',
    class_mode='binary',
    subset='validation')
# Out:
# Found 390 images belonging to 2 classes.
# Found 166 images belonging to 2 classes.

# %%
train_gen.next()[0].shape
# Out:
# (32, 60, 60, 1)

# %%
plt.imshow(train_gen.next()[0][1].squeeze(), cmap='gray')

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    "model_augmented.{epoch:02d}-{val_accuracy:.2f}.h5", 
    monitor='val_accuracy', 
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='auto', save_freq='epoch')

# %%
model = make_model()
epochs=500
learning_rate = 0.001
decay_rate = learning_rate / epochs
model.compile(optimizer=SGD(lr=learning_rate, momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %%
batch_size = 32
history = model.fit(train_gen,
                    batch_size=batch_size,
                    epochs=epochs,
                    steps_per_epoch = 278//batch_size,
                    verbose=1,
                    validation_data=val_gen,
                    validation_steps=118//batch_size,
                    callbacks=[checkpoint, reduce_on_plateau])
# Out:
# Epoch 1/500
# 8/8 [==============================] - 2s 176ms/step - loss: 1.0515 - accuracy: 0.4638 - val_loss: 0.7336 - val_accuracy: 0.4688
#
# Epoch 00001: val_accuracy improved from -inf to 0.46875, saving model to model_augmented.01-0.47.h5
# Epoch 2/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6888 - accuracy: 0.5247 - val_loss: 0.7019 - val_accuracy: 0.4896
#
# Epoch 00002: val_accuracy improved from 0.46875 to 0.48958, saving model to model_augmented.02-0.49.h5
# Epoch 3/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.6564 - accuracy: 0.6936 - val_loss: 0.6547 - val_accuracy: 0.5521
#
# Epoch 00003: val_accuracy improved from 0.48958 to 0.55208, saving model to model_augmented.03-0.55.h5
# Epoch 4/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.6283 - accuracy: 0.6603 - val_loss: 0.8106 - val_accuracy: 0.5208
#
# Epoch 00004: val_accuracy did not improve from 0.55208
# Epoch 5/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.5959 - accuracy: 0.7266 - val_loss: 0.8307 - val_accuracy: 0.6250
#
# Epoch 00005: val_accuracy improved from 0.55208 to 0.62500, saving model to model_augmented.05-0.62.h5
# Epoch 6/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.5899 - accuracy: 0.7596 - val_loss: 0.6151 - val_accuracy: 0.6979
#
# Epoch 00006: val_accuracy improved from 0.62500 to 0.69792, saving model to model_augmented.06-0.70.h5
# Epoch 7/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.6205 - accuracy: 0.6844 - val_loss: 0.5252 - val_accuracy: 0.7917
#
# Epoch 00007: val_accuracy improved from 0.69792 to 0.79167, saving model to model_augmented.07-0.79.h5
# Epoch 8/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.5697 - accuracy: 0.7913 - val_loss: 0.6858 - val_accuracy: 0.6562
#
# Epoch 00008: val_accuracy did not improve from 0.79167
# Epoch 9/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.5864 - accuracy: 0.6812 - val_loss: 0.5233 - val_accuracy: 0.7917
#
# Epoch 00009: val_accuracy did not improve from 0.79167
# Epoch 10/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.6092 - accuracy: 0.6482 - val_loss: 0.5401 - val_accuracy: 0.7812
#
# Epoch 00010: val_accuracy did not improve from 0.79167
# Epoch 11/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.5983 - accuracy: 0.6773 - val_loss: 0.5258 - val_accuracy: 0.7604
#
# Epoch 00011: val_accuracy did not improve from 0.79167
# Epoch 12/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.5461 - accuracy: 0.7426 - val_loss: 0.5960 - val_accuracy: 0.7188
#
# Epoch 00012: val_accuracy did not improve from 0.79167
# Epoch 13/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.5637 - accuracy: 0.7227 - val_loss: 0.4700 - val_accuracy: 0.8125
#
# Epoch 00013: val_accuracy improved from 0.79167 to 0.81250, saving model to model_augmented.13-0.81.h5
# Epoch 14/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.4859 - accuracy: 0.7619 - val_loss: 0.4623 - val_accuracy: 0.7917
#
# Epoch 00014: val_accuracy did not improve from 0.81250
# Epoch 15/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.4867 - accuracy: 0.7522 - val_loss: 0.5107 - val_accuracy: 0.8438
#
# Epoch 00015: val_accuracy improved from 0.81250 to 0.84375, saving model to model_augmented.15-0.84.h5
# Epoch 16/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.5245 - accuracy: 0.7105 - val_loss: 0.5119 - val_accuracy: 0.8021
#
# Epoch 00016: val_accuracy did not improve from 0.84375
# Epoch 17/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.4776 - accuracy: 0.7952 - val_loss: 0.4850 - val_accuracy: 0.8333
#
# Epoch 00017: val_accuracy did not improve from 0.84375
# Epoch 18/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.4864 - accuracy: 0.7638 - val_loss: 0.4394 - val_accuracy: 0.8646
#
# Epoch 00018: val_accuracy improved from 0.84375 to 0.86458, saving model to model_augmented.18-0.86.h5
# Epoch 19/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4930 - accuracy: 0.7274 - val_loss: 0.4877 - val_accuracy: 0.8438
#
# Epoch 00019: val_accuracy did not improve from 0.86458
# Epoch 20/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.5431 - accuracy: 0.6868 - val_loss: 0.4568 - val_accuracy: 0.8229
#
# Epoch 00020: val_accuracy did not improve from 0.86458
# Epoch 21/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.4992 - accuracy: 0.7122 - val_loss: 0.4264 - val_accuracy: 0.8646
#
# Epoch 00021: val_accuracy did not improve from 0.86458
# Epoch 22/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4985 - accuracy: 0.7346 - val_loss: 0.3744 - val_accuracy: 0.8750
#
# Epoch 00022: val_accuracy improved from 0.86458 to 0.87500, saving model to model_augmented.22-0.88.h5
# Epoch 23/500
# 8/8 [==============================] - 1s 116ms/step - loss: 0.4780 - accuracy: 0.7536 - val_loss: 0.3539 - val_accuracy: 0.8750
#
# Epoch 00023: val_accuracy did not improve from 0.87500
# Epoch 24/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.4805 - accuracy: 0.7634 - val_loss: 0.4359 - val_accuracy: 0.8021
#
# Epoch 00024: val_accuracy did not improve from 0.87500
# Epoch 25/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.4442 - accuracy: 0.8048 - val_loss: 0.4178 - val_accuracy: 0.8958
#
# Epoch 00025: val_accuracy improved from 0.87500 to 0.89583, saving model to model_augmented.25-0.90.h5
# Epoch 26/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.5267 - accuracy: 0.7817 - val_loss: 0.3918 - val_accuracy: 0.8854
#
# Epoch 00026: val_accuracy did not improve from 0.89583
# Epoch 27/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4860 - accuracy: 0.7607 - val_loss: 0.4412 - val_accuracy: 0.8021
#
# Epoch 00027: val_accuracy did not improve from 0.89583
# Epoch 28/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.4394 - accuracy: 0.8401 - val_loss: 0.3994 - val_accuracy: 0.8438
#
# Epoch 00028: val_accuracy did not improve from 0.89583
# Epoch 29/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4248 - accuracy: 0.8119 - val_loss: 0.4359 - val_accuracy: 0.7812
#
# Epoch 00029: val_accuracy did not improve from 0.89583
# Epoch 30/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.4153 - accuracy: 0.8261 - val_loss: 0.3857 - val_accuracy: 0.8438
#
# Epoch 00030: val_accuracy did not improve from 0.89583
# Epoch 31/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.5383 - accuracy: 0.7514 - val_loss: 0.3705 - val_accuracy: 0.8542
#
# Epoch 00031: val_accuracy did not improve from 0.89583
# Epoch 32/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.4773 - accuracy: 0.7609 - val_loss: 0.4284 - val_accuracy: 0.8021
#
# Epoch 00032: val_accuracy did not improve from 0.89583
# Epoch 33/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.5192 - accuracy: 0.7436 - val_loss: 0.3847 - val_accuracy: 0.8125
#
# Epoch 00033: val_accuracy did not improve from 0.89583
# Epoch 34/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3808 - accuracy: 0.8139 - val_loss: 0.4564 - val_accuracy: 0.8125
#
# Epoch 00034: val_accuracy did not improve from 0.89583
# Epoch 35/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.4678 - accuracy: 0.7997 - val_loss: 0.4018 - val_accuracy: 0.8854
#
# Epoch 00035: val_accuracy did not improve from 0.89583
# Epoch 36/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3672 - accuracy: 0.8717 - val_loss: 0.4866 - val_accuracy: 0.8021
#
# Epoch 00036: val_accuracy did not improve from 0.89583
# Epoch 37/500
# 8/8 [==============================] - 1s 116ms/step - loss: 0.3619 - accuracy: 0.8679 - val_loss: 0.5290 - val_accuracy: 0.7708
#
# Epoch 00037: val_accuracy did not improve from 0.89583
# Epoch 38/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.4647 - accuracy: 0.8015 - val_loss: 0.4930 - val_accuracy: 0.7708
#
# Epoch 00038: val_accuracy did not improve from 0.89583
# Epoch 39/500
# 8/8 [==============================] - 1s 116ms/step - loss: 0.4888 - accuracy: 0.7964 - val_loss: 0.4215 - val_accuracy: 0.8229
#
# Epoch 00039: val_accuracy did not improve from 0.89583
# Epoch 40/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3579 - accuracy: 0.8514 - val_loss: 0.3582 - val_accuracy: 0.8333
#
# Epoch 00040: val_accuracy did not improve from 0.89583
# Epoch 41/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4398 - accuracy: 0.8456 - val_loss: 0.3272 - val_accuracy: 0.8646
#
# Epoch 00041: val_accuracy did not improve from 0.89583
# Epoch 42/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3822 - accuracy: 0.8436 - val_loss: 0.2904 - val_accuracy: 0.8646
#
# Epoch 00042: val_accuracy did not improve from 0.89583
# Epoch 43/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3445 - accuracy: 0.8833 - val_loss: 0.3102 - val_accuracy: 0.8750
#
# Epoch 00043: val_accuracy did not improve from 0.89583
# Epoch 44/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3716 - accuracy: 0.8742 - val_loss: 0.3479 - val_accuracy: 0.8438
#
# Epoch 00044: val_accuracy did not improve from 0.89583
# Epoch 45/500
# 8/8 [==============================] - 1s 117ms/step - loss: 0.3710 - accuracy: 0.8734 - val_loss: 0.3375 - val_accuracy: 0.8542
#
# Epoch 00045: val_accuracy did not improve from 0.89583
# Epoch 46/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3771 - accuracy: 0.8836 - val_loss: 0.3097 - val_accuracy: 0.8854
#
# Epoch 00046: val_accuracy did not improve from 0.89583
# Epoch 47/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3613 - accuracy: 0.8578 - val_loss: 0.2835 - val_accuracy: 0.8958
#
# Epoch 00047: val_accuracy did not improve from 0.89583
# Epoch 48/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3515 - accuracy: 0.9057 - val_loss: 0.3342 - val_accuracy: 0.8646
#
# Epoch 00048: val_accuracy did not improve from 0.89583
# Epoch 49/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3889 - accuracy: 0.8647 - val_loss: 0.3029 - val_accuracy: 0.9062
#
# Epoch 00049: val_accuracy improved from 0.89583 to 0.90625, saving model to model_augmented.49-0.91.h5
# Epoch 50/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.4065 - accuracy: 0.8379 - val_loss: 0.2856 - val_accuracy: 0.8750
#
# Epoch 00050: val_accuracy did not improve from 0.90625
# Epoch 51/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3604 - accuracy: 0.9010 - val_loss: 0.3500 - val_accuracy: 0.8542
#
# Epoch 00051: val_accuracy did not improve from 0.90625
# Epoch 52/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3929 - accuracy: 0.8316 - val_loss: 0.2614 - val_accuracy: 0.9167
#
# Epoch 00052: val_accuracy improved from 0.90625 to 0.91667, saving model to model_augmented.52-0.92.h5
# Epoch 53/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3872 - accuracy: 0.8690 - val_loss: 0.3121 - val_accuracy: 0.8646
#
# Epoch 00053: val_accuracy did not improve from 0.91667
# Epoch 54/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3259 - accuracy: 0.8400 - val_loss: 0.3051 - val_accuracy: 0.8542
#
# Epoch 00054: val_accuracy did not improve from 0.91667
# Epoch 55/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3198 - accuracy: 0.8812 - val_loss: 0.2492 - val_accuracy: 0.9375
#
# Epoch 00055: val_accuracy improved from 0.91667 to 0.93750, saving model to model_augmented.55-0.94.h5
# Epoch 56/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.4188 - accuracy: 0.8271 - val_loss: 0.3228 - val_accuracy: 0.8854
#
# Epoch 00056: val_accuracy did not improve from 0.93750
# Epoch 57/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3585 - accuracy: 0.8628 - val_loss: 0.2565 - val_accuracy: 0.9062
#
# Epoch 00057: val_accuracy did not improve from 0.93750
# Epoch 58/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.4423 - accuracy: 0.8189 - val_loss: 0.2431 - val_accuracy: 0.9167
#
# Epoch 00058: val_accuracy did not improve from 0.93750
# Epoch 59/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3468 - accuracy: 0.9022 - val_loss: 0.2642 - val_accuracy: 0.9062
#
# Epoch 00059: val_accuracy did not improve from 0.93750
# Epoch 60/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3430 - accuracy: 0.8779 - val_loss: 0.2610 - val_accuracy: 0.9271
#
# Epoch 00060: val_accuracy did not improve from 0.93750
# Epoch 61/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3581 - accuracy: 0.8619 - val_loss: 0.2672 - val_accuracy: 0.9167
#
# Epoch 00061: val_accuracy did not improve from 0.93750
# Epoch 62/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3367 - accuracy: 0.8780 - val_loss: 0.2556 - val_accuracy: 0.8854
#
# Epoch 00062: val_accuracy did not improve from 0.93750
# Epoch 63/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3876 - accuracy: 0.8528 - val_loss: 0.2888 - val_accuracy: 0.9062
#
# Epoch 00063: val_accuracy did not improve from 0.93750
# Epoch 64/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3357 - accuracy: 0.8459 - val_loss: 0.2688 - val_accuracy: 0.9062
#
# Epoch 00064: val_accuracy did not improve from 0.93750
# Epoch 65/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.4308 - accuracy: 0.7996 - val_loss: 0.2587 - val_accuracy: 0.9062
#
# Epoch 00065: val_accuracy did not improve from 0.93750
# Epoch 66/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3583 - accuracy: 0.8600 - val_loss: 0.2520 - val_accuracy: 0.9062
#
# Epoch 00066: val_accuracy did not improve from 0.93750
# Epoch 67/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3136 - accuracy: 0.8882 - val_loss: 0.2402 - val_accuracy: 0.9167
#
# Epoch 00067: val_accuracy did not improve from 0.93750
# Epoch 68/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3812 - accuracy: 0.8505 - val_loss: 0.2797 - val_accuracy: 0.8958
#
# Epoch 00068: val_accuracy did not improve from 0.93750
# Epoch 69/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3793 - accuracy: 0.8287 - val_loss: 0.2534 - val_accuracy: 0.9062
#
# Epoch 00069: val_accuracy did not improve from 0.93750
# Epoch 70/500
# 8/8 [==============================] - 1s 117ms/step - loss: 0.3444 - accuracy: 0.8499 - val_loss: 0.2814 - val_accuracy: 0.8958
#
# Epoch 00070: val_accuracy did not improve from 0.93750
# Epoch 71/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3335 - accuracy: 0.8855 - val_loss: 0.2816 - val_accuracy: 0.8958
#
# Epoch 00071: val_accuracy did not improve from 0.93750
# Epoch 72/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3533 - accuracy: 0.8408 - val_loss: 0.2709 - val_accuracy: 0.8750
#
# Epoch 00072: val_accuracy did not improve from 0.93750
# Epoch 73/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3797 - accuracy: 0.8354 - val_loss: 0.2408 - val_accuracy: 0.8958
#
# Epoch 00073: val_accuracy did not improve from 0.93750
# Epoch 74/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3810 - accuracy: 0.8233 - val_loss: 0.2760 - val_accuracy: 0.8958
#
# Epoch 00074: val_accuracy did not improve from 0.93750
# Epoch 75/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3554 - accuracy: 0.8368 - val_loss: 0.2785 - val_accuracy: 0.9062
#
# Epoch 00075: val_accuracy did not improve from 0.93750
# Epoch 76/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3577 - accuracy: 0.8428 - val_loss: 0.2647 - val_accuracy: 0.8854
#
# Epoch 00076: val_accuracy did not improve from 0.93750
# Epoch 77/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3602 - accuracy: 0.8440 - val_loss: 0.2946 - val_accuracy: 0.8854
#
# Epoch 00077: val_accuracy did not improve from 0.93750
# Epoch 78/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3575 - accuracy: 0.8187 - val_loss: 0.2889 - val_accuracy: 0.9062
#
# Epoch 00078: val_accuracy did not improve from 0.93750
# Epoch 79/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3977 - accuracy: 0.8168 - val_loss: 0.2900 - val_accuracy: 0.8854
#
# Epoch 00079: val_accuracy did not improve from 0.93750
# Epoch 80/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3330 - accuracy: 0.8845 - val_loss: 0.2295 - val_accuracy: 0.8958
#
# Epoch 00080: val_accuracy did not improve from 0.93750
# Epoch 81/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3214 - accuracy: 0.8368 - val_loss: 0.2698 - val_accuracy: 0.8958
#
# Epoch 00081: val_accuracy did not improve from 0.93750
# Epoch 82/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3488 - accuracy: 0.8695 - val_loss: 0.3160 - val_accuracy: 0.8542
#
# Epoch 00082: val_accuracy did not improve from 0.93750
# Epoch 83/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3169 - accuracy: 0.8768 - val_loss: 0.2403 - val_accuracy: 0.9062
#
# Epoch 00083: val_accuracy did not improve from 0.93750
# Epoch 84/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3333 - accuracy: 0.8468 - val_loss: 0.2946 - val_accuracy: 0.8854
#
# Epoch 00084: val_accuracy did not improve from 0.93750
# Epoch 85/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3767 - accuracy: 0.8654 - val_loss: 0.3114 - val_accuracy: 0.8750
#
# Epoch 00085: val_accuracy did not improve from 0.93750
# Epoch 86/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3097 - accuracy: 0.8997 - val_loss: 0.2594 - val_accuracy: 0.8958
#
# Epoch 00086: val_accuracy did not improve from 0.93750
# Epoch 87/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3365 - accuracy: 0.8517 - val_loss: 0.2647 - val_accuracy: 0.9062
#
# Epoch 00087: val_accuracy did not improve from 0.93750
# Epoch 88/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3210 - accuracy: 0.8663 - val_loss: 0.3225 - val_accuracy: 0.8438
#
# Epoch 00088: val_accuracy did not improve from 0.93750
# Epoch 89/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3448 - accuracy: 0.8482 - val_loss: 0.2638 - val_accuracy: 0.8958
#
# Epoch 00089: val_accuracy did not improve from 0.93750
# Epoch 90/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.2997 - accuracy: 0.8911 - val_loss: 0.2984 - val_accuracy: 0.8750
#
# Epoch 00090: val_accuracy did not improve from 0.93750
# Epoch 91/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3665 - accuracy: 0.8725 - val_loss: 0.2730 - val_accuracy: 0.8958
#
# Epoch 00091: val_accuracy did not improve from 0.93750
# Epoch 92/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3419 - accuracy: 0.8596 - val_loss: 0.2836 - val_accuracy: 0.8854
#
# Epoch 00092: val_accuracy did not improve from 0.93750
# Epoch 93/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3127 - accuracy: 0.8811 - val_loss: 0.2740 - val_accuracy: 0.8854
#
# Epoch 00093: val_accuracy did not improve from 0.93750
# Epoch 94/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3073 - accuracy: 0.8878 - val_loss: 0.3015 - val_accuracy: 0.8854
#
# Epoch 00094: val_accuracy did not improve from 0.93750
# Epoch 95/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3468 - accuracy: 0.8417 - val_loss: 0.2728 - val_accuracy: 0.8750
#
# Epoch 00095: val_accuracy did not improve from 0.93750
# Epoch 96/500
# 8/8 [==============================] - 1s 117ms/step - loss: 0.3152 - accuracy: 0.8845 - val_loss: 0.2802 - val_accuracy: 0.8646
#
# Epoch 00096: val_accuracy did not improve from 0.93750
# Epoch 97/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3513 - accuracy: 0.8324 - val_loss: 0.2177 - val_accuracy: 0.9271
#
# Epoch 00097: val_accuracy did not improve from 0.93750
# Epoch 98/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3735 - accuracy: 0.8761 - val_loss: 0.2636 - val_accuracy: 0.9062
#
# Epoch 00098: val_accuracy did not improve from 0.93750
# Epoch 99/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3515 - accuracy: 0.8701 - val_loss: 0.2663 - val_accuracy: 0.8854
#
# Epoch 00099: val_accuracy did not improve from 0.93750
# Epoch 100/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3998 - accuracy: 0.8439 - val_loss: 0.2356 - val_accuracy: 0.9062
#
# Epoch 00100: val_accuracy did not improve from 0.93750
# Epoch 101/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3500 - accuracy: 0.8409 - val_loss: 0.2757 - val_accuracy: 0.9062
#
# Epoch 00101: val_accuracy did not improve from 0.93750
# Epoch 102/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3856 - accuracy: 0.8350 - val_loss: 0.2784 - val_accuracy: 0.9062
#
# Epoch 00102: val_accuracy did not improve from 0.93750
# Epoch 103/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.2661 - accuracy: 0.9097 - val_loss: 0.2739 - val_accuracy: 0.8542
#
# Epoch 00103: val_accuracy did not improve from 0.93750
# Epoch 104/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3816 - accuracy: 0.8054 - val_loss: 0.2798 - val_accuracy: 0.8958
#
# Epoch 00104: val_accuracy did not improve from 0.93750
# Epoch 105/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3532 - accuracy: 0.8531 - val_loss: 0.2216 - val_accuracy: 0.9167
#
# Epoch 00105: val_accuracy did not improve from 0.93750
# Epoch 106/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3889 - accuracy: 0.8363 - val_loss: 0.2849 - val_accuracy: 0.8854
#
# Epoch 00106: val_accuracy did not improve from 0.93750
# Epoch 107/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3223 - accuracy: 0.8675 - val_loss: 0.2281 - val_accuracy: 0.9271
#
# Epoch 00107: val_accuracy did not improve from 0.93750
# Epoch 108/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3812 - accuracy: 0.8134 - val_loss: 0.3039 - val_accuracy: 0.8750
#
# Epoch 00108: val_accuracy did not improve from 0.93750
# Epoch 109/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3516 - accuracy: 0.8238 - val_loss: 0.1967 - val_accuracy: 0.9271
#
# Epoch 00109: val_accuracy did not improve from 0.93750
# Epoch 110/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3502 - accuracy: 0.8479 - val_loss: 0.2684 - val_accuracy: 0.9062
#
# Epoch 00110: val_accuracy did not improve from 0.93750
# Epoch 111/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.4305 - accuracy: 0.8152 - val_loss: 0.2282 - val_accuracy: 0.9271
#
# Epoch 00111: val_accuracy did not improve from 0.93750
# Epoch 112/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3839 - accuracy: 0.8179 - val_loss: 0.3256 - val_accuracy: 0.8438
#
# Epoch 00112: val_accuracy did not improve from 0.93750
# Epoch 113/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3481 - accuracy: 0.8917 - val_loss: 0.3071 - val_accuracy: 0.8542
#
# Epoch 00113: val_accuracy did not improve from 0.93750
# Epoch 114/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3800 - accuracy: 0.8479 - val_loss: 0.2847 - val_accuracy: 0.8854
#
# Epoch 00114: val_accuracy did not improve from 0.93750
# Epoch 115/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3303 - accuracy: 0.8824 - val_loss: 0.2996 - val_accuracy: 0.8958
#
# Epoch 00115: val_accuracy did not improve from 0.93750
# Epoch 116/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3676 - accuracy: 0.8788 - val_loss: 0.2660 - val_accuracy: 0.9062
#
# Epoch 00116: val_accuracy did not improve from 0.93750
# Epoch 117/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3785 - accuracy: 0.7980 - val_loss: 0.2270 - val_accuracy: 0.9375
#
# Epoch 00117: val_accuracy did not improve from 0.93750
# Epoch 118/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3333 - accuracy: 0.8557 - val_loss: 0.2309 - val_accuracy: 0.9167
#
# Epoch 00118: val_accuracy did not improve from 0.93750
# Epoch 119/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3866 - accuracy: 0.8315 - val_loss: 0.2782 - val_accuracy: 0.8854
#
# Epoch 00119: val_accuracy did not improve from 0.93750
# Epoch 120/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3537 - accuracy: 0.8393 - val_loss: 0.2716 - val_accuracy: 0.9062
#
# Epoch 00120: val_accuracy did not improve from 0.93750
# Epoch 121/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3652 - accuracy: 0.8705 - val_loss: 0.2387 - val_accuracy: 0.9062
#
# Epoch 00121: val_accuracy did not improve from 0.93750
# Epoch 122/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3367 - accuracy: 0.8570 - val_loss: 0.2525 - val_accuracy: 0.9167
#
# Epoch 00122: val_accuracy did not improve from 0.93750
# Epoch 123/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3820 - accuracy: 0.8489 - val_loss: 0.2812 - val_accuracy: 0.8854
#
# Epoch 00123: val_accuracy did not improve from 0.93750
# Epoch 124/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3347 - accuracy: 0.8742 - val_loss: 0.2817 - val_accuracy: 0.8750
#
# Epoch 00124: val_accuracy did not improve from 0.93750
# Epoch 125/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3359 - accuracy: 0.8762 - val_loss: 0.2568 - val_accuracy: 0.8750
#
# Epoch 00125: val_accuracy did not improve from 0.93750
# Epoch 126/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3504 - accuracy: 0.8459 - val_loss: 0.2985 - val_accuracy: 0.8854
#
# Epoch 00126: val_accuracy did not improve from 0.93750
# Epoch 127/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3776 - accuracy: 0.8384 - val_loss: 0.2497 - val_accuracy: 0.9062
#
# Epoch 00127: val_accuracy did not improve from 0.93750
# Epoch 128/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.2705 - accuracy: 0.9190 - val_loss: 0.3221 - val_accuracy: 0.8333
#
# Epoch 00128: val_accuracy did not improve from 0.93750
# Epoch 129/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3566 - accuracy: 0.8148 - val_loss: 0.2452 - val_accuracy: 0.9167
#
# Epoch 00129: val_accuracy did not improve from 0.93750
# Epoch 130/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3740 - accuracy: 0.8456 - val_loss: 0.2781 - val_accuracy: 0.8646
#
# Epoch 00130: val_accuracy did not improve from 0.93750
# Epoch 131/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3581 - accuracy: 0.8404 - val_loss: 0.2672 - val_accuracy: 0.8854
#
# Epoch 00131: val_accuracy did not improve from 0.93750
# Epoch 132/500
# 8/8 [==============================] - 1s 116ms/step - loss: 0.3662 - accuracy: 0.8177 - val_loss: 0.2587 - val_accuracy: 0.8958
#
# Epoch 00132: val_accuracy did not improve from 0.93750
# Epoch 133/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3951 - accuracy: 0.7980 - val_loss: 0.2817 - val_accuracy: 0.8958
#
# Epoch 00133: val_accuracy did not improve from 0.93750
# Epoch 134/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3024 - accuracy: 0.9007 - val_loss: 0.3192 - val_accuracy: 0.8542
#
# Epoch 00134: val_accuracy did not improve from 0.93750
# Epoch 135/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3423 - accuracy: 0.8175 - val_loss: 0.2714 - val_accuracy: 0.8646
#
# Epoch 00135: val_accuracy did not improve from 0.93750
# Epoch 136/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.2866 - accuracy: 0.8929 - val_loss: 0.2364 - val_accuracy: 0.9271
#
# Epoch 00136: val_accuracy did not improve from 0.93750
# Epoch 137/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3353 - accuracy: 0.8798 - val_loss: 0.2347 - val_accuracy: 0.9062
#
# Epoch 00137: val_accuracy did not improve from 0.93750
# Epoch 138/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3708 - accuracy: 0.8409 - val_loss: 0.2646 - val_accuracy: 0.9062
#
# Epoch 00138: val_accuracy did not improve from 0.93750
# Epoch 139/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3677 - accuracy: 0.8488 - val_loss: 0.2759 - val_accuracy: 0.8854
#
# Epoch 00139: val_accuracy did not improve from 0.93750
# Epoch 140/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3564 - accuracy: 0.8418 - val_loss: 0.2720 - val_accuracy: 0.9062
#
# Epoch 00140: val_accuracy did not improve from 0.93750
# Epoch 141/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3143 - accuracy: 0.8816 - val_loss: 0.2701 - val_accuracy: 0.8958
#
# Epoch 00141: val_accuracy did not improve from 0.93750
# Epoch 142/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3851 - accuracy: 0.8118 - val_loss: 0.2487 - val_accuracy: 0.9062
#
# Epoch 00142: val_accuracy did not improve from 0.93750
# Epoch 143/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3371 - accuracy: 0.8872 - val_loss: 0.2767 - val_accuracy: 0.8958
#
# Epoch 00143: val_accuracy did not improve from 0.93750
# Epoch 144/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.2908 - accuracy: 0.9040 - val_loss: 0.2201 - val_accuracy: 0.9167
#
# Epoch 00144: val_accuracy did not improve from 0.93750
# Epoch 145/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3781 - accuracy: 0.8159 - val_loss: 0.2652 - val_accuracy: 0.8958
#
# Epoch 00145: val_accuracy did not improve from 0.93750
# Epoch 146/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.2945 - accuracy: 0.9142 - val_loss: 0.2685 - val_accuracy: 0.8854
#
# Epoch 00146: val_accuracy did not improve from 0.93750
# Epoch 147/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3517 - accuracy: 0.8268 - val_loss: 0.2395 - val_accuracy: 0.8958
#
# Epoch 00147: val_accuracy did not improve from 0.93750
# Epoch 148/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3201 - accuracy: 0.8899 - val_loss: 0.3194 - val_accuracy: 0.8542
#
# Epoch 00148: val_accuracy did not improve from 0.93750
# Epoch 149/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.4078 - accuracy: 0.8172 - val_loss: 0.2835 - val_accuracy: 0.8854
#
# Epoch 00149: val_accuracy did not improve from 0.93750
# Epoch 150/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3914 - accuracy: 0.8236 - val_loss: 0.2888 - val_accuracy: 0.8958
#
# Epoch 00150: val_accuracy did not improve from 0.93750
# Epoch 151/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3155 - accuracy: 0.9007 - val_loss: 0.2634 - val_accuracy: 0.9062
#
# Epoch 00151: val_accuracy did not improve from 0.93750
# Epoch 152/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3198 - accuracy: 0.8789 - val_loss: 0.3049 - val_accuracy: 0.8646
#
# Epoch 00152: val_accuracy did not improve from 0.93750
# Epoch 153/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3770 - accuracy: 0.8327 - val_loss: 0.2757 - val_accuracy: 0.8854
#
# Epoch 00153: val_accuracy did not improve from 0.93750
# Epoch 154/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3473 - accuracy: 0.8482 - val_loss: 0.2444 - val_accuracy: 0.8854
#
# Epoch 00154: val_accuracy did not improve from 0.93750
# Epoch 155/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3057 - accuracy: 0.8670 - val_loss: 0.2582 - val_accuracy: 0.8854
#
# Epoch 00155: val_accuracy did not improve from 0.93750
# Epoch 156/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3580 - accuracy: 0.8436 - val_loss: 0.2814 - val_accuracy: 0.8646
#
# Epoch 00156: val_accuracy did not improve from 0.93750
# Epoch 157/500
# 8/8 [==============================] - 1s 114ms/step - loss: 0.3560 - accuracy: 0.8194 - val_loss: 0.2920 - val_accuracy: 0.8854
#
# Epoch 00157: val_accuracy did not improve from 0.93750
# Epoch 158/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3854 - accuracy: 0.8375 - val_loss: 0.3271 - val_accuracy: 0.8438
#
# Epoch 00158: val_accuracy did not improve from 0.93750
# Epoch 159/500
# 8/8 [==============================] - 1s 116ms/step - loss: 0.3332 - accuracy: 0.8761 - val_loss: 0.2542 - val_accuracy: 0.8958
#
# Epoch 00159: val_accuracy did not improve from 0.93750
# Epoch 160/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3798 - accuracy: 0.8137 - val_loss: 0.2878 - val_accuracy: 0.8854
#
# Epoch 00160: val_accuracy did not improve from 0.93750
# Epoch 161/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3650 - accuracy: 0.8259 - val_loss: 0.2635 - val_accuracy: 0.9062
#
# Epoch 00161: val_accuracy did not improve from 0.93750
# Epoch 162/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3709 - accuracy: 0.7878 - val_loss: 0.2628 - val_accuracy: 0.8854
#
# Epoch 00162: val_accuracy did not improve from 0.93750
# Epoch 163/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3559 - accuracy: 0.8678 - val_loss: 0.2973 - val_accuracy: 0.8646
#
# Epoch 00163: val_accuracy did not improve from 0.93750
# Epoch 164/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.4442 - accuracy: 0.7751 - val_loss: 0.2508 - val_accuracy: 0.8854
#
# Epoch 00164: val_accuracy did not improve from 0.93750
# Epoch 165/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3338 - accuracy: 0.8561 - val_loss: 0.3170 - val_accuracy: 0.8542
#
# Epoch 00165: val_accuracy did not improve from 0.93750
# Epoch 166/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4396 - accuracy: 0.8026 - val_loss: 0.2516 - val_accuracy: 0.8958
#
# Epoch 00166: val_accuracy did not improve from 0.93750
# Epoch 167/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3700 - accuracy: 0.8489 - val_loss: 0.2870 - val_accuracy: 0.8854
#
# Epoch 00167: val_accuracy did not improve from 0.93750
# Epoch 168/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3644 - accuracy: 0.8312 - val_loss: 0.2952 - val_accuracy: 0.8750
#
# Epoch 00168: val_accuracy did not improve from 0.93750
# Epoch 169/500
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3418 - accuracy: 0.8754 - val_loss: 0.2915 - val_accuracy: 0.8750
#
# Epoch 00169: val_accuracy did not improve from 0.93750
# Epoch 170/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3674 - accuracy: 0.8192 - val_loss: 0.2411 - val_accuracy: 0.9375
#
# Epoch 00170: val_accuracy did not improve from 0.93750
# Epoch 171/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3497 - accuracy: 0.8380 - val_loss: 0.2758 - val_accuracy: 0.8750
#
# Epoch 00171: val_accuracy did not improve from 0.93750
# Epoch 172/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3530 - accuracy: 0.8552 - val_loss: 0.3101 - val_accuracy: 0.8646
#
# Epoch 00172: val_accuracy did not improve from 0.93750
# Epoch 173/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3096 - accuracy: 0.8709 - val_loss: 0.2983 - val_accuracy: 0.8854
#
# Epoch 00173: val_accuracy did not improve from 0.93750
# Epoch 174/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3436 - accuracy: 0.8652 - val_loss: 0.2474 - val_accuracy: 0.9167
#
# Epoch 00174: val_accuracy did not improve from 0.93750
# Epoch 175/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3273 - accuracy: 0.8607 - val_loss: 0.2882 - val_accuracy: 0.8854
#
# Epoch 00175: val_accuracy did not improve from 0.93750
# Epoch 176/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3651 - accuracy: 0.8668 - val_loss: 0.2803 - val_accuracy: 0.8958
#
# Epoch 00176: val_accuracy did not improve from 0.93750
# Epoch 177/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3516 - accuracy: 0.8274 - val_loss: 0.2997 - val_accuracy: 0.8542
#
# Epoch 00177: val_accuracy did not improve from 0.93750
# Epoch 178/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.4084 - accuracy: 0.8233 - val_loss: 0.2249 - val_accuracy: 0.9062
#
# Epoch 00178: val_accuracy did not improve from 0.93750
# Epoch 179/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3232 - accuracy: 0.8751 - val_loss: 0.2258 - val_accuracy: 0.9271
#
# Epoch 00179: val_accuracy did not improve from 0.93750
# Epoch 180/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3765 - accuracy: 0.8429 - val_loss: 0.2791 - val_accuracy: 0.9062
#
# Epoch 00180: val_accuracy did not improve from 0.93750
# Epoch 181/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3504 - accuracy: 0.8328 - val_loss: 0.2877 - val_accuracy: 0.8750
#
# Epoch 00181: val_accuracy did not improve from 0.93750
# Epoch 182/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3156 - accuracy: 0.8990 - val_loss: 0.2765 - val_accuracy: 0.8646
#
# Epoch 00182: val_accuracy did not improve from 0.93750
# Epoch 183/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3654 - accuracy: 0.8634 - val_loss: 0.2297 - val_accuracy: 0.9271
#
# Epoch 00183: val_accuracy did not improve from 0.93750
# Epoch 184/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3824 - accuracy: 0.8169 - val_loss: 0.1978 - val_accuracy: 0.9271
#
# Epoch 00184: val_accuracy did not improve from 0.93750
# Epoch 185/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.2990 - accuracy: 0.9053 - val_loss: 0.2836 - val_accuracy: 0.8646
#
# Epoch 00185: val_accuracy did not improve from 0.93750
# Epoch 186/500
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3011 - accuracy: 0.8764 - val_loss: 0.2342 - val_accuracy: 0.9062
#
# Epoch 00186: val_accuracy did not improve from 0.93750
# Epoch 187/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3383 - accuracy: 0.8475 - val_loss: 0.2821 - val_accuracy: 0.8958
#
# Epoch 00187: val_accuracy did not improve from 0.93750
# Epoch 188/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3584 - accuracy: 0.8599 - val_loss: 0.2595 - val_accuracy: 0.8854
#
# Epoch 00188: val_accuracy did not improve from 0.93750
# Epoch 189/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3404 - accuracy: 0.8726 - val_loss: 0.2722 - val_accuracy: 0.8958
#
# Epoch 00189: val_accuracy did not improve from 0.93750
# Epoch 190/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3259 - accuracy: 0.8664 - val_loss: 0.2767 - val_accuracy: 0.8854
#
# Epoch 00190: val_accuracy did not improve from 0.93750
# Epoch 191/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3320 - accuracy: 0.8927 - val_loss: 0.3216 - val_accuracy: 0.8542
#
# Epoch 00191: val_accuracy did not improve from 0.93750
# Epoch 192/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3060 - accuracy: 0.8872 - val_loss: 0.2844 - val_accuracy: 0.8854
#
# Epoch 00192: val_accuracy did not improve from 0.93750
# Epoch 193/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3902 - accuracy: 0.8424 - val_loss: 0.2518 - val_accuracy: 0.9167
#
# Epoch 00193: val_accuracy did not improve from 0.93750
# Epoch 194/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3604 - accuracy: 0.8740 - val_loss: 0.2937 - val_accuracy: 0.8646
#
# Epoch 00194: val_accuracy did not improve from 0.93750
# Epoch 195/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3803 - accuracy: 0.8382 - val_loss: 0.2897 - val_accuracy: 0.8958
#
# Epoch 00195: val_accuracy did not improve from 0.93750
# Epoch 196/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3697 - accuracy: 0.8497 - val_loss: 0.2605 - val_accuracy: 0.8854
#
# Epoch 00196: val_accuracy did not improve from 0.93750
# Epoch 197/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3899 - accuracy: 0.8429 - val_loss: 0.2702 - val_accuracy: 0.8750
#
# Epoch 00197: val_accuracy did not improve from 0.93750
# Epoch 198/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3545 - accuracy: 0.8294 - val_loss: 0.2825 - val_accuracy: 0.8958
#
# Epoch 00198: val_accuracy did not improve from 0.93750
# Epoch 199/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3481 - accuracy: 0.8295 - val_loss: 0.2990 - val_accuracy: 0.8646
#
# Epoch 00199: val_accuracy did not improve from 0.93750
# Epoch 200/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3399 - accuracy: 0.8718 - val_loss: 0.2622 - val_accuracy: 0.9062
#
# Epoch 00200: val_accuracy did not improve from 0.93750
# Epoch 201/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3514 - accuracy: 0.8175 - val_loss: 0.2387 - val_accuracy: 0.9062
#
# Epoch 00201: val_accuracy did not improve from 0.93750
# Epoch 202/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3735 - accuracy: 0.8187 - val_loss: 0.2648 - val_accuracy: 0.9062
#
# Epoch 00202: val_accuracy did not improve from 0.93750
# Epoch 203/500
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3966 - accuracy: 0.8313 - val_loss: 0.3122 - val_accuracy: 0.8542
#
# Epoch 00203: val_accuracy did not improve from 0.93750
# Epoch 204/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3573 - accuracy: 0.8338 - val_loss: 0.2140 - val_accuracy: 0.9271
#
# Epoch 00204: val_accuracy did not improve from 0.93750
# Epoch 205/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3559 - accuracy: 0.8372 - val_loss: 0.2822 - val_accuracy: 0.9062
#
# Epoch 00205: val_accuracy did not improve from 0.93750
# Epoch 206/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.4087 - accuracy: 0.7926 - val_loss: 0.2653 - val_accuracy: 0.8854
#
# Epoch 00206: val_accuracy did not improve from 0.93750
# Epoch 207/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3366 - accuracy: 0.8650 - val_loss: 0.3001 - val_accuracy: 0.8646
#
# Epoch 00207: val_accuracy did not improve from 0.93750
# Epoch 208/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3838 - accuracy: 0.8190 - val_loss: 0.2232 - val_accuracy: 0.9062
#
# Epoch 00208: val_accuracy did not improve from 0.93750
# Epoch 209/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3404 - accuracy: 0.8466 - val_loss: 0.2183 - val_accuracy: 0.9375
#
# Epoch 00209: val_accuracy did not improve from 0.93750
# Epoch 210/500
# 8/8 [==============================] - 1s 162ms/step - loss: 0.3635 - accuracy: 0.8305 - val_loss: 0.2292 - val_accuracy: 0.9167
#
# Epoch 00210: val_accuracy did not improve from 0.93750
# Epoch 211/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3154 - accuracy: 0.8768 - val_loss: 0.2530 - val_accuracy: 0.9062
#
# Epoch 00211: val_accuracy did not improve from 0.93750
# Epoch 212/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3106 - accuracy: 0.8789 - val_loss: 0.3100 - val_accuracy: 0.8854
#
# Epoch 00212: val_accuracy did not improve from 0.93750
# Epoch 213/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3755 - accuracy: 0.8418 - val_loss: 0.2596 - val_accuracy: 0.9167
#
# Epoch 00213: val_accuracy did not improve from 0.93750
# Epoch 214/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3826 - accuracy: 0.8147 - val_loss: 0.2839 - val_accuracy: 0.9062
#
# Epoch 00214: val_accuracy did not improve from 0.93750
# Epoch 215/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3663 - accuracy: 0.8447 - val_loss: 0.3149 - val_accuracy: 0.8854
#
# Epoch 00215: val_accuracy did not improve from 0.93750
# Epoch 216/500
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3988 - accuracy: 0.8175 - val_loss: 0.2632 - val_accuracy: 0.9062
#
# Epoch 00216: val_accuracy did not improve from 0.93750
# Epoch 217/500
# 8/8 [==============================] - 1s 139ms/step - loss: 0.4155 - accuracy: 0.8450 - val_loss: 0.3124 - val_accuracy: 0.8542
#
# Epoch 00217: val_accuracy did not improve from 0.93750
# Epoch 218/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3367 - accuracy: 0.8590 - val_loss: 0.2909 - val_accuracy: 0.8646
#
# Epoch 00218: val_accuracy did not improve from 0.93750
# Epoch 219/500
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3587 - accuracy: 0.8225 - val_loss: 0.2711 - val_accuracy: 0.9062
#
# Epoch 00219: val_accuracy did not improve from 0.93750
# Epoch 220/500
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3357 - accuracy: 0.8674 - val_loss: 0.2081 - val_accuracy: 0.9479
#
# Epoch 00220: val_accuracy improved from 0.93750 to 0.94792, saving model to model_augmented.220-0.95.h5
# Epoch 221/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3790 - accuracy: 0.8164 - val_loss: 0.2655 - val_accuracy: 0.8854
#
# Epoch 00221: val_accuracy did not improve from 0.94792
# Epoch 222/500
# 8/8 [==============================] - 1s 140ms/step - loss: 0.3101 - accuracy: 0.8843 - val_loss: 0.2458 - val_accuracy: 0.9062
#
# Epoch 00222: val_accuracy did not improve from 0.94792
# Epoch 223/500
# 8/8 [==============================] - 1s 146ms/step - loss: 0.3800 - accuracy: 0.8738 - val_loss: 0.2799 - val_accuracy: 0.8854
#
# Epoch 00223: val_accuracy did not improve from 0.94792
# Epoch 224/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3677 - accuracy: 0.8301 - val_loss: 0.2612 - val_accuracy: 0.8854
#
# Epoch 00224: val_accuracy did not improve from 0.94792
# Epoch 225/500
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2988 - accuracy: 0.8978 - val_loss: 0.1914 - val_accuracy: 0.9583
#
# Epoch 00225: val_accuracy improved from 0.94792 to 0.95833, saving model to model_augmented.225-0.96.h5
# Epoch 226/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3218 - accuracy: 0.8564 - val_loss: 0.2717 - val_accuracy: 0.8958
#
# Epoch 00226: val_accuracy did not improve from 0.95833
# Epoch 227/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3510 - accuracy: 0.8509 - val_loss: 0.2549 - val_accuracy: 0.8958
#
# Epoch 00227: val_accuracy did not improve from 0.95833
# Epoch 228/500
# 8/8 [==============================] - 1s 138ms/step - loss: 0.4162 - accuracy: 0.8214 - val_loss: 0.2547 - val_accuracy: 0.9167
#
# Epoch 00228: val_accuracy did not improve from 0.95833
# Epoch 229/500
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3283 - accuracy: 0.8655 - val_loss: 0.2791 - val_accuracy: 0.8958
#
# Epoch 00229: val_accuracy did not improve from 0.95833
# Epoch 230/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3996 - accuracy: 0.8487 - val_loss: 0.2981 - val_accuracy: 0.8646
#
# Epoch 00230: val_accuracy did not improve from 0.95833
# Epoch 231/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3820 - accuracy: 0.8281 - val_loss: 0.2490 - val_accuracy: 0.8854
#
# Epoch 00231: val_accuracy did not improve from 0.95833
# Epoch 232/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3201 - accuracy: 0.8737 - val_loss: 0.2714 - val_accuracy: 0.8854
#
# Epoch 00232: val_accuracy did not improve from 0.95833
# Epoch 233/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3607 - accuracy: 0.8759 - val_loss: 0.2234 - val_accuracy: 0.9167
#
# Epoch 00233: val_accuracy did not improve from 0.95833
# Epoch 234/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3316 - accuracy: 0.8917 - val_loss: 0.2892 - val_accuracy: 0.8854
#
# Epoch 00234: val_accuracy did not improve from 0.95833
# Epoch 235/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3778 - accuracy: 0.8032 - val_loss: 0.2621 - val_accuracy: 0.8958
#
# Epoch 00235: val_accuracy did not improve from 0.95833
# Epoch 236/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3378 - accuracy: 0.8777 - val_loss: 0.2746 - val_accuracy: 0.8646
#
# Epoch 00236: val_accuracy did not improve from 0.95833
# Epoch 237/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3360 - accuracy: 0.8291 - val_loss: 0.2975 - val_accuracy: 0.8958
#
# Epoch 00237: val_accuracy did not improve from 0.95833
# Epoch 238/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.2882 - accuracy: 0.8885 - val_loss: 0.2013 - val_accuracy: 0.9479
#
# ...
#
# Epoch 00420: val_accuracy did not improve from 0.95833
# Epoch 421/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3214 - accuracy: 0.8822 - val_loss: 0.2664 - val_accuracy: 0.8750
#
# Epoch 00421: val_accuracy did not improve from 0.95833
# Epoch 422/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3872 - accuracy: 0.8315 - val_loss: 0.2427 - val_accuracy: 0.8958
#
# Epoch 00422: val_accuracy did not improve from 0.95833
# Epoch 423/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3639 - accuracy: 0.8272 - val_loss: 0.2415 - val_accuracy: 0.9167
#
# Epoch 00423: val_accuracy did not improve from 0.95833
# Epoch 424/500
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3753 - accuracy: 0.8373 - val_loss: 0.2339 - val_accuracy: 0.9062
#
# Epoch 00424: val_accuracy did not improve from 0.95833
# Epoch 425/500
# 8/8 [==============================] - 1s 141ms/step - loss: 0.3293 - accuracy: 0.8734 - val_loss: 0.2196 - val_accuracy: 0.9271
#
# Epoch 00425: val_accuracy did not improve from 0.95833
# Epoch 426/500
# 8/8 [==============================] - 1s 149ms/step - loss: 0.3247 - accuracy: 0.8681 - val_loss: 0.2313 - val_accuracy: 0.9375
#
# Epoch 00426: val_accuracy did not improve from 0.95833
# Epoch 427/500
# 8/8 [==============================] - 1s 140ms/step - loss: 0.3496 - accuracy: 0.8408 - val_loss: 0.2885 - val_accuracy: 0.8958
#
# Epoch 00427: val_accuracy did not improve from 0.95833
# Epoch 428/500
# 8/8 [==============================] - 1s 140ms/step - loss: 0.3384 - accuracy: 0.8497 - val_loss: 0.2034 - val_accuracy: 0.9479
#
# Epoch 00428: val_accuracy did not improve from 0.95833
# Epoch 429/500
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3344 - accuracy: 0.8296 - val_loss: 0.2826 - val_accuracy: 0.8958
#
# Epoch 00429: val_accuracy did not improve from 0.95833
# Epoch 430/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3379 - accuracy: 0.8474 - val_loss: 0.2337 - val_accuracy: 0.9167
#
# Epoch 00430: val_accuracy did not improve from 0.95833
# Epoch 431/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3603 - accuracy: 0.8366 - val_loss: 0.2898 - val_accuracy: 0.8750
#
# Epoch 00431: val_accuracy did not improve from 0.95833
# Epoch 432/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.3140 - accuracy: 0.8807 - val_loss: 0.2617 - val_accuracy: 0.9062
#
# Epoch 00432: val_accuracy did not improve from 0.95833
# Epoch 433/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3148 - accuracy: 0.8959 - val_loss: 0.2995 - val_accuracy: 0.8854
#
# Epoch 00433: val_accuracy did not improve from 0.95833
# Epoch 434/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3429 - accuracy: 0.8435 - val_loss: 0.2189 - val_accuracy: 0.9062
#
# Epoch 00434: val_accuracy did not improve from 0.95833
# Epoch 435/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3072 - accuracy: 0.9016 - val_loss: 0.2642 - val_accuracy: 0.8854
#
# Epoch 00435: val_accuracy did not improve from 0.95833
# Epoch 436/500
# 8/8 [==============================] - 1s 138ms/step - loss: 0.3637 - accuracy: 0.8722 - val_loss: 0.3070 - val_accuracy: 0.8438
#
# Epoch 00436: val_accuracy did not improve from 0.95833
# Epoch 437/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3654 - accuracy: 0.8722 - val_loss: 0.2729 - val_accuracy: 0.9062
#
# Epoch 00437: val_accuracy did not improve from 0.95833
# Epoch 438/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3437 - accuracy: 0.8579 - val_loss: 0.1957 - val_accuracy: 0.9479
#
# Epoch 00438: val_accuracy did not improve from 0.95833
# Epoch 439/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3290 - accuracy: 0.8637 - val_loss: 0.2288 - val_accuracy: 0.9167
#
# Epoch 00439: val_accuracy did not improve from 0.95833
# Epoch 440/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3460 - accuracy: 0.8553 - val_loss: 0.2506 - val_accuracy: 0.9062
#
# Epoch 00440: val_accuracy did not improve from 0.95833
# Epoch 441/500
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3781 - accuracy: 0.8277 - val_loss: 0.2273 - val_accuracy: 0.9271
#
# Epoch 00441: val_accuracy did not improve from 0.95833
# Epoch 442/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3975 - accuracy: 0.7961 - val_loss: 0.2134 - val_accuracy: 0.9167
#
# Epoch 00442: val_accuracy did not improve from 0.95833
# Epoch 443/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3013 - accuracy: 0.8727 - val_loss: 0.3075 - val_accuracy: 0.8750
#
# Epoch 00443: val_accuracy did not improve from 0.95833
# Epoch 444/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3771 - accuracy: 0.8474 - val_loss: 0.2759 - val_accuracy: 0.8958
#
# Epoch 00444: val_accuracy did not improve from 0.95833
# Epoch 445/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3294 - accuracy: 0.8838 - val_loss: 0.3157 - val_accuracy: 0.8542
#
# Epoch 00445: val_accuracy did not improve from 0.95833
# Epoch 446/500
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3721 - accuracy: 0.8410 - val_loss: 0.2590 - val_accuracy: 0.8958
#
# Epoch 00446: val_accuracy did not improve from 0.95833
# Epoch 447/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3489 - accuracy: 0.8387 - val_loss: 0.2474 - val_accuracy: 0.9271
#
# Epoch 00447: val_accuracy did not improve from 0.95833
# Epoch 448/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3194 - accuracy: 0.8755 - val_loss: 0.2945 - val_accuracy: 0.8438
#
# Epoch 00448: val_accuracy did not improve from 0.95833
# Epoch 449/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3067 - accuracy: 0.8962 - val_loss: 0.2774 - val_accuracy: 0.8854
#
# Epoch 00449: val_accuracy did not improve from 0.95833
# Epoch 450/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3788 - accuracy: 0.8219 - val_loss: 0.3049 - val_accuracy: 0.8646
#
# Epoch 00450: val_accuracy did not improve from 0.95833
# Epoch 451/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4607 - accuracy: 0.7831 - val_loss: 0.2744 - val_accuracy: 0.9062
#
# Epoch 00451: val_accuracy did not improve from 0.95833
# Epoch 452/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3661 - accuracy: 0.8691 - val_loss: 0.2700 - val_accuracy: 0.8958
#
# Epoch 00452: val_accuracy did not improve from 0.95833
# Epoch 453/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3811 - accuracy: 0.8487 - val_loss: 0.2831 - val_accuracy: 0.8854
#
# Epoch 00453: val_accuracy did not improve from 0.95833
# Epoch 454/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3796 - accuracy: 0.8214 - val_loss: 0.3340 - val_accuracy: 0.8542
#
# Epoch 00454: val_accuracy did not improve from 0.95833
# Epoch 455/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.4202 - accuracy: 0.8245 - val_loss: 0.3092 - val_accuracy: 0.8646
#
# Epoch 00455: val_accuracy did not improve from 0.95833
# Epoch 456/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3538 - accuracy: 0.8516 - val_loss: 0.2670 - val_accuracy: 0.8854
#
# Epoch 00456: val_accuracy did not improve from 0.95833
# Epoch 457/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3548 - accuracy: 0.8728 - val_loss: 0.2460 - val_accuracy: 0.9167
#
# Epoch 00457: val_accuracy did not improve from 0.95833
# Epoch 458/500
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3969 - accuracy: 0.8251 - val_loss: 0.2481 - val_accuracy: 0.9167
#
# Epoch 00458: val_accuracy did not improve from 0.95833
# Epoch 459/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.4277 - accuracy: 0.8377 - val_loss: 0.2580 - val_accuracy: 0.9062
#
# Epoch 00459: val_accuracy did not improve from 0.95833
# Epoch 460/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3404 - accuracy: 0.8462 - val_loss: 0.2384 - val_accuracy: 0.9167
#
# Epoch 00460: val_accuracy did not improve from 0.95833
# Epoch 461/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3993 - accuracy: 0.7899 - val_loss: 0.2287 - val_accuracy: 0.9271
#
# Epoch 00461: val_accuracy did not improve from 0.95833
# Epoch 462/500
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3392 - accuracy: 0.8431 - val_loss: 0.2911 - val_accuracy: 0.8646
#
# Epoch 00462: val_accuracy did not improve from 0.95833
# Epoch 463/500
# 8/8 [==============================] - 1s 120ms/step - loss: 0.3314 - accuracy: 0.8623 - val_loss: 0.2424 - val_accuracy: 0.9167
#
# Epoch 00463: val_accuracy did not improve from 0.95833
# Epoch 464/500
# 8/8 [==============================] - 1s 122ms/step - loss: 0.3280 - accuracy: 0.8559 - val_loss: 0.2598 - val_accuracy: 0.8958
#
# Epoch 00464: val_accuracy did not improve from 0.95833
# Epoch 465/500
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3780 - accuracy: 0.8379 - val_loss: 0.3263 - val_accuracy: 0.8646
#
# Epoch 00465: val_accuracy did not improve from 0.95833
# Epoch 466/500
# 8/8 [==============================] - 1s 119ms/step - loss: 0.3423 - accuracy: 0.8405 - val_loss: 0.2768 - val_accuracy: 0.8854
#
# Epoch 00466: val_accuracy did not improve from 0.95833
# Epoch 467/500
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3366 - accuracy: 0.8415 - val_loss: 0.2949 - val_accuracy: 0.8750
#
# Epoch 00467: val_accuracy did not improve from 0.95833
# Epoch 468/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3432 - accuracy: 0.8369 - val_loss: 0.2694 - val_accuracy: 0.8750
#
# Epoch 00468: val_accuracy did not improve from 0.95833
# Epoch 469/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3475 - accuracy: 0.8655 - val_loss: 0.2680 - val_accuracy: 0.9167
#
# Epoch 00469: val_accuracy did not improve from 0.95833
# Epoch 470/500
# 8/8 [==============================] - 1s 135ms/step - loss: 0.3712 - accuracy: 0.8766 - val_loss: 0.2725 - val_accuracy: 0.9062
#
# Epoch 00470: val_accuracy did not improve from 0.95833
# Epoch 471/500
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3440 - accuracy: 0.8332 - val_loss: 0.2155 - val_accuracy: 0.9167
#
# Epoch 00471: val_accuracy did not improve from 0.95833
# Epoch 472/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.3119 - accuracy: 0.9151 - val_loss: 0.2930 - val_accuracy: 0.8958
#
# Epoch 00472: val_accuracy did not improve from 0.95833
# Epoch 473/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3266 - accuracy: 0.8692 - val_loss: 0.2782 - val_accuracy: 0.8646
#
# Epoch 00473: val_accuracy did not improve from 0.95833
# Epoch 474/500
# 8/8 [==============================] - 1s 128ms/step - loss: 0.3600 - accuracy: 0.8243 - val_loss: 0.2557 - val_accuracy: 0.8958
#
# Epoch 00474: val_accuracy did not improve from 0.95833
# Epoch 475/500
# 8/8 [==============================] - 1s 138ms/step - loss: 0.3636 - accuracy: 0.8380 - val_loss: 0.2634 - val_accuracy: 0.8750
#
# Epoch 00475: val_accuracy did not improve from 0.95833
# Epoch 476/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3501 - accuracy: 0.8470 - val_loss: 0.2527 - val_accuracy: 0.9062
#
# Epoch 00476: val_accuracy did not improve from 0.95833
# Epoch 477/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3331 - accuracy: 0.8757 - val_loss: 0.2387 - val_accuracy: 0.9167
#
# Epoch 00477: val_accuracy did not improve from 0.95833
# Epoch 478/500
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3986 - accuracy: 0.8379 - val_loss: 0.2607 - val_accuracy: 0.8854
#
# Epoch 00478: val_accuracy did not improve from 0.95833
# Epoch 479/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3833 - accuracy: 0.8433 - val_loss: 0.2928 - val_accuracy: 0.8646
#
# Epoch 00479: val_accuracy did not improve from 0.95833
# Epoch 480/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3194 - accuracy: 0.8862 - val_loss: 0.2144 - val_accuracy: 0.9271
#
# Epoch 00480: val_accuracy did not improve from 0.95833
# Epoch 481/500
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3348 - accuracy: 0.8721 - val_loss: 0.3445 - val_accuracy: 0.8438
#
# Epoch 00481: val_accuracy did not improve from 0.95833
# Epoch 482/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3081 - accuracy: 0.8899 - val_loss: 0.2828 - val_accuracy: 0.8958
#
# Epoch 00482: val_accuracy did not improve from 0.95833
# Epoch 483/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3451 - accuracy: 0.8814 - val_loss: 0.2953 - val_accuracy: 0.8854
#
# Epoch 00483: val_accuracy did not improve from 0.95833
# Epoch 484/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3449 - accuracy: 0.8467 - val_loss: 0.2661 - val_accuracy: 0.8958
#
# Epoch 00484: val_accuracy did not improve from 0.95833
# Epoch 485/500
# 8/8 [==============================] - 1s 134ms/step - loss: 0.3835 - accuracy: 0.8660 - val_loss: 0.2660 - val_accuracy: 0.8750
#
# Epoch 00485: val_accuracy did not improve from 0.95833
# Epoch 486/500
# 8/8 [==============================] - 1s 137ms/step - loss: 0.3546 - accuracy: 0.8474 - val_loss: 0.3030 - val_accuracy: 0.8854
#
# Epoch 00486: val_accuracy did not improve from 0.95833
# Epoch 487/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3231 - accuracy: 0.8797 - val_loss: 0.2587 - val_accuracy: 0.9062
#
# Epoch 00487: val_accuracy did not improve from 0.95833
# Epoch 488/500
# 8/8 [==============================] - 1s 141ms/step - loss: 0.4812 - accuracy: 0.7632 - val_loss: 0.2945 - val_accuracy: 0.8646
#
# Epoch 00488: val_accuracy did not improve from 0.95833
# Epoch 489/500
# 8/8 [==============================] - 1s 125ms/step - loss: 0.2988 - accuracy: 0.9090 - val_loss: 0.3093 - val_accuracy: 0.8646
#
# Epoch 00489: val_accuracy did not improve from 0.95833
# Epoch 490/500
# 8/8 [==============================] - 1s 133ms/step - loss: 0.3095 - accuracy: 0.9038 - val_loss: 0.2734 - val_accuracy: 0.8854
#
# Epoch 00490: val_accuracy did not improve from 0.95833
# Epoch 491/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3491 - accuracy: 0.8658 - val_loss: 0.3079 - val_accuracy: 0.8750
#
# Epoch 00491: val_accuracy did not improve from 0.95833
# Epoch 492/500
# 8/8 [==============================] - 1s 132ms/step - loss: 0.3652 - accuracy: 0.8455 - val_loss: 0.2450 - val_accuracy: 0.9167
#
# Epoch 00492: val_accuracy did not improve from 0.95833
# Epoch 493/500
# 8/8 [==============================] - 1s 124ms/step - loss: 0.3195 - accuracy: 0.8668 - val_loss: 0.2759 - val_accuracy: 0.8958
#
# Epoch 00493: val_accuracy did not improve from 0.95833
# Epoch 494/500
# 8/8 [==============================] - 1s 131ms/step - loss: 0.4205 - accuracy: 0.8632 - val_loss: 0.2618 - val_accuracy: 0.8750
#
# Epoch 00494: val_accuracy did not improve from 0.95833
# Epoch 495/500
# 8/8 [==============================] - 1s 130ms/step - loss: 0.3532 - accuracy: 0.8567 - val_loss: 0.3056 - val_accuracy: 0.8750
#
# Epoch 00495: val_accuracy did not improve from 0.95833
# Epoch 496/500
# 8/8 [==============================] - 1s 126ms/step - loss: 0.3114 - accuracy: 0.8839 - val_loss: 0.3029 - val_accuracy: 0.8750
#
# Epoch 00496: val_accuracy did not improve from 0.95833
# Epoch 497/500
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3681 - accuracy: 0.8748 - val_loss: 0.2686 - val_accuracy: 0.9062
#
# Epoch 00497: val_accuracy did not improve from 0.95833
# Epoch 498/500
# 8/8 [==============================] - 1s 136ms/step - loss: 0.3386 - accuracy: 0.8905 - val_loss: 0.2579 - val_accuracy: 0.9167
#
# Epoch 00498: val_accuracy did not improve from 0.95833
# Epoch 499/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3528 - accuracy: 0.8781 - val_loss: 0.2938 - val_accuracy: 0.8750
#
# Epoch 00499: val_accuracy did not improve from 0.95833
# Epoch 500/500
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3942 - accuracy: 0.8444 - val_loss: 0.3539 - val_accuracy: 0.8229
#
# Epoch 00500: val_accuracy did not improve from 0.95833

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy 
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss 
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Saving the model

# %%
# !ls /content
# Out:
# gdrive			    model_augmented.15-0.84.h5
# model-01-0.71.hdf5	    model_augmented.18-0.86.h5
# model-02-0.77.hdf5	    model_augmented.220-0.95.h5
# model-34-0.88.hdf5	    model_augmented.22-0.88.h5
# model-40-0.93.hdf5	    model_augmented.225-0.96.h5
# model_augmented.01-0.47.h5  model_augmented.25-0.90.h5
# model_augmented.02-0.49.h5  model_augmented.49-0.91.h5
# model_augmented.03-0.55.h5  model_augmented.52-0.92.h5
# model_augmented.05-0.62.h5  model_augmented.55-0.94.h5
# model_augmented.06-0.70.h5  model.hdf5
# model_augmented.07-0.79.h5  sample_data
# model_augmented.13-0.81.h5

# %%
model.save('/content/model_augmented.hdf5')

# %%
from keras.models import load_model

# %%
imported_model = load_model('/content/model_augmented.hdf5')

# %%
imported_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 60, 60, 8)         80
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 60, 8)         32
# _________________________________________________________________
# activation_3 (Activation)    (None, 60, 60, 8)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 16)        1168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 16)        64
# _________________________________________________________________
# activation_4 (Activation)    (None, 30, 30, 16)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 15, 15, 32)        4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 15, 32)        128
# _________________________________________________________________
# activation_5 (Activation)    (None, 15, 15, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                15690
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 21,813
# Trainable params: 21,701
# Non-trainable params: 112
# _________________________________________________________________

# %% [markdown]
# # Evaluate the performances of the two models

# %%
noaug_model = load_model('/content/model.hdf5')
aug_model = load_model('/content/model_augmented.hdf5')

# %%
x_test, y_test = read_imgs('/content/gdrive/MyDrive/Mammography_micro/Test', [0,1])

# %%
test_loss_noaug, test_acc_noaug = noaug_model.evaluate(x_test, y_test)
print('\nTest accuracy noaug_model:', test_acc_noaug)
# Out:
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3142 - accuracy: 0.9129
#
# Test accuracy noaug_model: 0.9128630757331848

# %%
test_loss_aug, test_acc_aug = aug_model.evaluate(train_gen)
print('\nTest accuracy aug_model:', test_acc_aug)
# Out:
# 13/13 [==============================] - 1s 69ms/step - loss: 0.2994 - accuracy: 0.8897
#
# Test accuracy aug_model: 0.8897435665130615
