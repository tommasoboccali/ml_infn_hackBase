# %% [markdown]
# <a href="https://colab.research.google.com/github/tommasoboccali/ml_infn_hackBase/blob/main/lucio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Enhancing $\psi(2S)$ signal with a simple DNN
#
# In the previous notebooks we have discussed the basics of `numpy`, `pandas` and `matplotlib` which provide the minimal toolset for data analysis in Python.
# Then we introduced `keras` to define and train deep neural networks.
#
# In this notebook we discuss a first application of keras to *Particle Physics* to enhance the signal of the $\psi(2S)$ resonance by rejecting background combining kinematic variables.

# %% [markdown]
# ## Loading libraries and datasets
#
# As a first step, let's load the libraries of our toolset

# %%
## numpy for arrays and numerical operations 
import numpy as np 

## pandas for data handling 
import pandas as pd 

## pyplot for data visualization 
import matplotlib.pyplot as plt

## keras for deep learning
import keras as K
import tensorflow as tf

# %% [markdown]
# Then we obtain the dataset from the CERN Open Data portal ed elenchiamo le variabili presenti nel dataset.

# %%
df = pd.read_csv ("https://opendata.cern.ch/record/5201/files/Dimuon_DoubleMu.csv")

print ("\n".join (df.columns))
# Out:
# Run
# Event
# type1
# E1
# px1
# py1
# pz1
# pt1
# eta1
# phi1
# Q1
# type2
# E2
# px2
# py2
# pz2
# pt2
# eta2
# phi2
# Q2
# M

# %% [markdown]
# ## Explorative analysis and Feature engineering
# With the exception of the mass $M$, all variables are relative to either the positive or the negative muon combined into a charmonium decay candidate.
# We compute the momentum and the polar angle of the combination.

# %%
df['p'] = df.eval("sqrt((px1 + px2)**2 + (py1 + py2)**2 + (pz1 + pz2)**2)")
df['pT'] = df.eval("sqrt((px1 + px2)**2 + (py1 + py2)**2)")
df['theta'] = df.eval(f"arcsin (pT/p) * 180 / {np.pi}")

# %% [markdown]
# Now that we have engineered some useful feature in our dataset let's consider the mass distribution in the charmonium region.

# %%
boundaries = np.linspace ( 2.6, 4.2, 161)
plt.hist (df['M'], bins=boundaries)
plt.xlabel ("Invariant dimuon mass [GeV/$c^2$]")
plt.ylabel ("Number of candidates")
plt.show()

# %% [markdown]
# We define now a background region, a control region and a signal region.
# The background region is assumed to represent reliably the residual background in the signal and in the control region.
# While the signal region offers a dataset with abundant and relatively pure decay candidates that represents well the signal.
# > **Note!** This is possible because the production mechanism of $J/\psi$ and $\psi(2S)$ is similar with differences mainly due to the small mass difference.

# %%
df_bkg = df.query ("(M > 2.6 and M < 2.95) or (M > 3.22 and M < 3.5) or (M > 3.9 and M < 4.2)").copy()
df_ctrl = df.query ("M > 3.0 and M < 3.18").copy()
df_sig = df.query ("M > 3.5 and M < 3.9").copy()
boundaries = np.linspace ( 2.6, 4.2, 161)

plt.hist (df['M'], bins=boundaries, histtype = 'step')

plt.hist (df_sig['M'], bins=boundaries, color = 'red', label = "Signal region")
plt.hist (df_bkg['M'], bins=boundaries, color = 'blue', label = "Background region")
plt.hist (df_ctrl['M'], bins=boundaries, color = 'green', label = "Control region")

plt.xlabel ("Invariant dimuon mass [GeV/$c^2$]")
plt.ylabel ("Number of candidates")
plt.legend()
plt.show()

# %% [markdown]
# We will try to distinguish the control sample from the combinatorial background by applying selection requirements on the kinematic variables that we engineered above: the mass and the momentum of the dimuon combination.
# Let's have a look to how the three categories are distributed on the $p \perp \theta$ plane.

# %%
plt.plot (df_sig['p'], df_sig['theta'], '.', alpha=0.4, markersize=2, color='red', label="Signal region")
plt.plot (df_bkg['p'], df_bkg['theta'], '.', alpha=0.4,  markersize=2, color='blue', label="Background")
plt.plot (df_ctrl['p'], df_ctrl['theta'], '.', alpha=0.3,  markersize=2, color='green', label="Control region")
plt.legend()
plt.xscale('log')
plt.xlabel ("Dimuon momentum [GeV/$c$]")
plt.ylabel ("Polar angle [°]")
plt.show()

# %% [markdown]
# ## Preprocessing
#
# Instead of using directly the momentum and the angle, we may *preprocess* them in order to make it easier for the minimization procedure to reach the minimum.
# We define two variables `prep_p` and `prep_theta` obtained as a bijective transformation of `p` and `theta` that maps the two variables to distributions "not too different" from a standard Gaussian ($\frac{1}{\sqrt{2\pi}}\exp(-0.5 x^2)$).
#
# Standardization is a common *preprocessing* procedure:
# $$
# x' = \frac{x - E(x)}{\sqrt{E^2(x) - E(x)^2}}
# $$
# where $E$ represents the expectation value (`np.mean`) and the denominator is the standard deviation of the dataset (`np.std`).
#
# For the momentum, the very long tail at high momentum my be difficult to treat even if preprocessed with a linear transform. Hence, we transform the momentum $p$ to $\log (p)$ and then we *standardize* $\log (p)$.
#
# In Python,

# %%
p = df['p']
th = df['theta']

df['prep_p'] = (np.log(p) - np.log(p.mean()))/(np.log(np.std(p)))
df['prep_theta'] = (th - th.mean())/(np.std(th))

# %% [markdown]
# Let's plot the standardized variables.

# %%
plt.figure (figsize = (12,6), dpi = 100)
plt.subplot(221)
plt.hist (df['prep_p'], bins = 100)
plt.xlabel ("Preprocessed momentum")
plt.subplot(222)

plt.hist (df['prep_theta'], bins = 100)
plt.xlabel ("Preprocessed polar angle")
plt.show()

# %% [markdown]
# Finally, we propagate these variables to the dataset obtained through queries to the original dataset, in order to ensure a consistent transoformation of the variables in all the datasets.

# %%
df_bkg = df.query ("(M > 2.6 and M < 2.95) or (M > 3.22 and M < 3.5) or (M > 3.85 and M < 4.2)").copy()
df_ctrl = df.query ("M > 3.0 and M < 3.18").copy()
df_sig = df.query ("M > 3.5 and M < 3.9").copy()

# %% [markdown]
# ## Logistic regression as a special neural network
#
# Let's define a function to instanciate a keras model as discussed in the previous lecture.
# We will take as arguments the number of layers and the number of nodes per layer, assuming all layers share the same number of nodes.
#
# We will use `tanh` as activation function for the hidden layers which is better suited for small and shallow neural networks, all the other settings are quite standard:
#  * Adam optimizer
#  * Binary cross-entropy as loss function for binary classification problems

# %%
def create_model (n_layers=1, n_nodes=32):
    inputs = K.layers.Input(shape=(2))
    layers = [inputs]
    for iLayer in range(n_layers): 
        layers.append(K.layers.Dense(n_nodes, activation='tanh') (layers[-1]))

    outputs = K.layers.Dense(1, activation = 'sigmoid')(layers[-1])

    model = K.models.Model (inputs=inputs, outputs=outputs)
    model.compile(loss='binary_crossentropy', optimizer='adam')

    return model

# %% [markdown]
# Before diving into the depth of the neural network, let's focus on the case
# `n_layers=0`. The resulting algorithm is known as logistic regression.
# Note that since there are no non-linear elements (with the exception of the `sigmoid` which is only applied to the output layer) this is considered as a linear classification algorithm.
#
# The prediction $\hat y$ is defined by
# $$
# \hat y = \mathrm{sigmoid} ( a p + b \theta + c)
# $$
# where $a$, $b$ and $c$ are parameters to be optimized during the training, $p$ and $\theta$ are the preprocessed versions of the momentum and polar angle of our dimuon combination.
#
# With `lr.summary()` we obtain confirmation that the total number of parameters defining the model is indeed 3.

# %%
lr = create_model (n_layers=0)
lr.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# 2021-12-06 14:50:53.465023: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: UNKNOWN ERROR (34)
# 2021-12-06 14:50:53.465226: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: fdf298abdc00
# 2021-12-06 14:50:53.465264: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: fdf298abdc00
# 2021-12-06 14:50:53.465651: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: NOT_FOUND: was unable to find libcuda.so DSO loaded into this program
# 2021-12-06 14:50:53.465834: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 495.29.5
# 2021-12-06 14:50:53.466622: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Dataset preparation
# We are now ready to convert the `pandas` dataframe in `numpy` arrays that can transparently be processed by keras.
#
# First of all, we identify the control sample with unit labels, while the background candidates are identified by null labels.
#
# Then we use obtain the arrays from pandas using the `values` property, and finally we shuffle the signal and background events by defining a random permutation of the indices and shuffling variables and labels by the same permutation.

# %%
df_ctrl['label'] = 1
df_bkg['label'] = 0

X = np.concatenate ( [ df_ctrl[['prep_p', 'prep_theta']].values , df_bkg[['prep_p', 'prep_theta']].values ] ) 
y = np.concatenate ( [ df_ctrl['label'].values , df_bkg['label'].values ] ) 

indices = np.random.permutation (len(X))

X = X[indices]
y = y[indices]

# %% [markdown]
# We are finally ready to train the logistic regression on our data.

# %%
history_lr=lr.fit (X, y, validation_split=0.5, epochs=150, verbose=True)
# Out:
# Epoch 1/150
# 152/152 [==============================] - 2s 5ms/step - loss: 0.6431 - val_loss: 0.6239
# Epoch 2/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.6173 - val_loss: 0.6042
# Epoch 3/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.6021 - val_loss: 0.5923
# Epoch 4/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5923 - val_loss: 0.5845
# Epoch 5/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5856 - val_loss: 0.5789
# Epoch 6/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5806 - val_loss: 0.5749
# Epoch 7/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5769 - val_loss: 0.5719
# Epoch 8/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5743 - val_loss: 0.5699
# Epoch 9/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5722 - val_loss: 0.5682
# Epoch 10/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5707 - val_loss: 0.5671
# Epoch 11/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5694 - val_loss: 0.5662
# Epoch 12/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5685 - val_loss: 0.5657
# Epoch 13/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5678 - val_loss: 0.5652
# Epoch 14/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5672 - val_loss: 0.5648
# Epoch 15/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5667 - val_loss: 0.5645
# Epoch 16/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5665 - val_loss: 0.5644
# Epoch 17/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5662 - val_loss: 0.5642
# Epoch 18/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5659 - val_loss: 0.5641
# Epoch 19/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5658 - val_loss: 0.5641
# Epoch 20/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5656 - val_loss: 0.5640
# Epoch 21/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5655 - val_loss: 0.5640
# Epoch 22/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5654 - val_loss: 0.5639
# Epoch 23/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5653 - val_loss: 0.5639
# Epoch 24/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5652 - val_loss: 0.5639
# Epoch 25/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5651 - val_loss: 0.5638
# Epoch 26/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5650 - val_loss: 0.5638
# Epoch 27/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5650 - val_loss: 0.5638
# Epoch 28/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5649 - val_loss: 0.5638
# Epoch 29/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5649 - val_loss: 0.5638
# Epoch 30/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5648 - val_loss: 0.5637
# Epoch 31/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5648 - val_loss: 0.5637
# Epoch 32/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5648 - val_loss: 0.5637
# Epoch 33/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5647 - val_loss: 0.5637
# Epoch 34/150
# 152/152 [==============================] - 0s 3ms/step - loss: 0.5647 - val_loss: 0.5636
# Epoch 35/150
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5646 - val_loss: 0.5636
# Epoch 36/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5646 - val_loss: 0.5637
# Epoch 37/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5646 - val_loss: 0.5637
# Epoch 38/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5645 - val_loss: 0.5637
# Epoch 39/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5645 - val_loss: 0.5637
# Epoch 40/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5645 - val_loss: 0.5637
# Epoch 41/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 42/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 43/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 44/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 45/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 46/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 47/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5644 - val_loss: 0.5637
# Epoch 48/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 49/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 50/150
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 51/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 52/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 53/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 54/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5637
# Epoch 55/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5638
# Epoch 56/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 57/150
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5643 - val_loss: 0.5638
# Epoch 58/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5638
# Epoch 59/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5638
# Epoch 60/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 61/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 62/150
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 63/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 64/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 65/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 66/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 67/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 68/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 69/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 70/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 71/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 72/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 73/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5638
# Epoch 74/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5638
# Epoch 75/150
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 76/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 77/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 78/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 79/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 80/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 81/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 82/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 83/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 84/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 85/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 86/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 87/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 88/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 89/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 90/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 91/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 92/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 93/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 94/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 95/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 96/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 97/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 98/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 99/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 100/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 101/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 102/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 103/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 104/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 105/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 106/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 107/150
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 108/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5640
# Epoch 109/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 110/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 111/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 112/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 113/150
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 114/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 115/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 116/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 117/150
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 118/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 119/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 120/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 121/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 122/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 123/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 124/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 125/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 126/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 127/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 128/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 129/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5643 - val_loss: 0.5640
# Epoch 130/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 131/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 132/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 133/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 134/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 135/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 136/150
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 137/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 138/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 139/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 140/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 141/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 142/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 143/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 144/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 145/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 146/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 147/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 148/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5639
# Epoch 149/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640
# Epoch 150/150
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5642 - val_loss: 0.5640

# %% [markdown]
# Let's plot the evolution of the binary cross-entropy with the epochs.

# %%
plt.plot (history_lr.history['loss'], 'o-', label="Training")
plt.plot (history_lr.history['val_loss'], 'o-', label="Validation")

plt.yscale('log')
plt.xlabel ( "Epoch")
plt.ylabel ( "Binary cross-entropy")

plt.show()

# %% [markdown]
# We observe that the slope at the end of training is basically null, which may indicate that the training procedure reached the minimum of the loss function.
#
# We can then explore the response of the logistic regression.

# %%
X_ctrl = df_ctrl[['prep_p', 'prep_theta']].values
y_ctrl = lr.predict(X_ctrl)

X_bkg = df_bkg[['prep_p', 'prep_theta']].values
y_bkg = lr.predict(X_bkg)

h_ctrl, boundaries, _ = plt.hist (y_ctrl, density=True, bins=100, label="Control sample", histtype='step', linewidth=2)
h_bkg, _, _ = plt.hist (y_bkg, density=True, bins=boundaries, label="Background sample", histtype='step', linewidth=2)
plt.legend()
plt.xlabel ("Neural network prediction")
plt.ylabel ("Number of entries")
plt.show()

# %% [markdown]
# The histogram indicates already the the separation between signal in the control sample and the background is not exciting, but we observe that the histogram representing the control sample is, as expected, slightly at the right of the background.
#
# It is customary to study the hability of the classification algorithm to distinghish signal from noise using the *Receiver Operator Curve (ROC)*: the curve obtained plotting the background rejection versus the signal efficiency for different working points of the binary classification algorithm.
#
# We plot below the ROC of the Logistic Regression algorithm, superposed to the result expected by drawing randomly events from the dataset and calling them signal events.
#
# The area under the ROC (*Area under the curve*) is a metric of how well the algorithm is able to separate signal and background, independently of the threshold chosen to call a candidate *signal* or *background*.

# %%
plt.plot (1.- np.cumsum(h_ctrl)/h_ctrl.sum(), np.cumsum(h_bkg)/h_bkg.sum(), label="Logistic regression" )
auc = np.trapz (1.- np.cumsum(h_ctrl)/h_ctrl.sum(), np.cumsum(h_bkg)/h_bkg.sum() )
plt.plot ([1,0], [0,1], '--', label = "Random selection")
plt.xlabel ("Control-sample efficiency")
plt.ylabel ("Background rejection")
plt.title ( f"Area under the curve (AUC): {auc*100:.1f} %")
plt.legend()
plt.show()

# %% [markdown]
# Keras allows to obtain the *Area Under the Curve* (AUC) directly as metric for each step of the training, for both training and validation samples.
#
# Let's modify the function `create_model` to include the AUC as metric and let's verify it appears in the training `history`.

# %%
def create_model (n_layers=1, n_nodes=32):
    inputs = K.layers.Input(shape=(2))
    layers = [inputs]
    for iLayer in range(n_layers): 
        layers.append(K.layers.Dense(n_nodes, activation='tanh') (layers[-1]))
  
    outputs = K.layers.Dense(1, activation = 'sigmoid')(layers[-1])
   
    model = K.models.Model (inputs=inputs, outputs=outputs)
    model.compile(loss='binary_crossentropy', optimizer="adam", metrics=['AUC'])

    return model


lr_with_auc = create_model (n_layers=0, n_nodes=4)
history_lr=lr_with_auc.fit (X, y, validation_split=0.5, epochs=50, verbose=True)
history_lr.history.keys()
# Out:
# Epoch 1/50
# 152/152 [==============================] - 1s 7ms/step - loss: 1.0759 - auc: 0.4299 - val_loss: 1.0184 - val_auc: 0.4228
# Epoch 2/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.9629 - auc: 0.4307 - val_loss: 0.9126 - val_auc: 0.4234
# Epoch 3/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.8667 - auc: 0.4315 - val_loss: 0.8248 - val_auc: 0.4240
# Epoch 4/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.7881 - auc: 0.4309 - val_loss: 0.7546 - val_auc: 0.4250
# Epoch 5/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.7261 - auc: 0.4326 - val_loss: 0.7002 - val_auc: 0.4263
# Epoch 6/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.6792 - auc: 0.4339 - val_loss: 0.6599 - val_auc: 0.4282
# Epoch 7/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.6449 - auc: 0.4357 - val_loss: 0.6309 - val_auc: 0.4310
# Epoch 8/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.6210 - auc: 0.4363 - val_loss: 0.6108 - val_auc: 0.4344
# Epoch 9/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.6049 - auc: 0.4376 - val_loss: 0.5974 - val_auc: 0.4389
# Epoch 10/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5935 - auc: 0.4408 - val_loss: 0.5880 - val_auc: 0.4450
# Epoch 11/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5858 - auc: 0.4463 - val_loss: 0.5816 - val_auc: 0.4529
# Epoch 12/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5808 - auc: 0.4515 - val_loss: 0.5773 - val_auc: 0.4631
# Epoch 13/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5772 - auc: 0.4608 - val_loss: 0.5743 - val_auc: 0.4745
# Epoch 14/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5748 - auc: 0.4714 - val_loss: 0.5723 - val_auc: 0.4872
# Epoch 15/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5732 - auc: 0.4818 - val_loss: 0.5709 - val_auc: 0.5011
# Epoch 16/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5720 - auc: 0.4935 - val_loss: 0.5699 - val_auc: 0.5139
# Epoch 17/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5711 - auc: 0.5061 - val_loss: 0.5690 - val_auc: 0.5281
# Epoch 18/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5704 - auc: 0.5183 - val_loss: 0.5683 - val_auc: 0.5380
# Epoch 19/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5697 - auc: 0.5276 - val_loss: 0.5677 - val_auc: 0.5458
# Epoch 20/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5692 - auc: 0.5338 - val_loss: 0.5672 - val_auc: 0.5507
# Epoch 21/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5687 - auc: 0.5408 - val_loss: 0.5668 - val_auc: 0.5556
# Epoch 22/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5683 - auc: 0.5432 - val_loss: 0.5664 - val_auc: 0.5590
# Epoch 23/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5679 - auc: 0.5481 - val_loss: 0.5660 - val_auc: 0.5628
# Epoch 24/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5676 - auc: 0.5510 - val_loss: 0.5657 - val_auc: 0.5661
# Epoch 25/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.5673 - auc: 0.5541 - val_loss: 0.5655 - val_auc: 0.5681
# Epoch 26/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5670 - auc: 0.5577 - val_loss: 0.5653 - val_auc: 0.5710
# Epoch 27/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5668 - auc: 0.5586 - val_loss: 0.5651 - val_auc: 0.5711
# Epoch 28/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5665 - auc: 0.5607 - val_loss: 0.5649 - val_auc: 0.5730
# Epoch 29/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5664 - auc: 0.5622 - val_loss: 0.5647 - val_auc: 0.5738
# Epoch 30/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5662 - auc: 0.5645 - val_loss: 0.5646 - val_auc: 0.5750
# Epoch 31/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5660 - auc: 0.5654 - val_loss: 0.5645 - val_auc: 0.5758
# Epoch 32/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5658 - auc: 0.5664 - val_loss: 0.5644 - val_auc: 0.5760
# Epoch 33/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5657 - auc: 0.5664 - val_loss: 0.5643 - val_auc: 0.5770
# Epoch 34/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5656 - auc: 0.5670 - val_loss: 0.5642 - val_auc: 0.5771
# Epoch 35/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5655 - auc: 0.5678 - val_loss: 0.5641 - val_auc: 0.5778
# Epoch 36/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5654 - auc: 0.5683 - val_loss: 0.5641 - val_auc: 0.5768
# Epoch 37/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5653 - auc: 0.5686 - val_loss: 0.5640 - val_auc: 0.5769
# Epoch 38/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5652 - auc: 0.5686 - val_loss: 0.5640 - val_auc: 0.5773
# Epoch 39/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5651 - auc: 0.5675 - val_loss: 0.5639 - val_auc: 0.5774
# Epoch 40/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5650 - auc: 0.5692 - val_loss: 0.5639 - val_auc: 0.5767
# Epoch 41/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5650 - auc: 0.5691 - val_loss: 0.5638 - val_auc: 0.5772
# Epoch 42/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5649 - auc: 0.5688 - val_loss: 0.5638 - val_auc: 0.5769
# Epoch 43/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5648 - auc: 0.5686 - val_loss: 0.5638 - val_auc: 0.5768
# Epoch 44/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5648 - auc: 0.5688 - val_loss: 0.5638 - val_auc: 0.5762
# Epoch 45/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5648 - auc: 0.5681 - val_loss: 0.5638 - val_auc: 0.5759
# Epoch 46/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5647 - auc: 0.5688 - val_loss: 0.5637 - val_auc: 0.5755
# Epoch 47/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5647 - auc: 0.5684 - val_loss: 0.5637 - val_auc: 0.5757
# Epoch 48/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5646 - auc: 0.5683 - val_loss: 0.5637 - val_auc: 0.5751
# Epoch 49/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5646 - auc: 0.5679 - val_loss: 0.5637 - val_auc: 0.5757
# Epoch 50/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5645 - auc: 0.5680 - val_loss: 0.5637 - val_auc: 0.5750
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])

# %%
plt.plot(history_lr.history['auc'], label = "Training sample")
plt.plot(history_lr.history['val_auc'], label = "Validation sample")
plt.xlabel ("Epoch")
plt.ylabel ("Area under the curve")
plt.legend()
plt.show()

# %% [markdown]
# ## Application
# We are now ready to apply the trained logistic regression to the signal sample.
#
# First we obtain the prediction `y_hat` for each row of the signal dataframe and register it as a new column of this derived datasets.

# %%
X_sig = df_sig[['prep_p', 'prep_theta']].values
y_hat = lr.predict (X_sig).flatten()
df_sig ['y_hat'] = y_hat

# %% [markdown]
# Then we plot the histogram and select some threshold to scan the effect of a cut on the response obtained from the logistic regression on the invariant mass distribution.

# %%
plt.hist (y_hat, bins = 30)
plt.xlabel("Logistic regression response")
plt.ylabel("Number of entries")
plt.show()

# %% [markdown]
# We use the function `quantile` to get a sequence of thresholds that divide the sample in equal parts.
#
# Then we loop over the threshold and draw the histograms obtained by cutting on the logistic regression response.
#
# We note that with the softer cuts we are able to remove background without affecting the signal component.

# %%
thresholds = np.quantile (y_hat, np.linspace(1, 0, 8))
for threshold in thresholds[:-1]:
    plt.hist (df_sig['M'][y_hat < threshold], bins = 25, label = f"LR < {threshold:.3f}")
plt.legend()
plt.xlabel ("Dimuon mass [GeV/$c^2$]")
plt.ylabel ("Dimuon candidates")
plt.show()

# %% [markdown]
# ## Choice of the threshold
# Once the model is trained we need to define a threshold to reject some events as background and retain more signal than background entries.
#
# The choice of the optimal threshold depends on the problem we are trying to solve. For example, for a discovery we try to optimize the [Punzi figure of merit](https://arxiv.org/pdf/physics/0308063.pdf)
# $$
# \frac{\epsilon_S}{\frac32 + \sqrt{B}}
# $$
# where $S$ and $B$ rerpresent the number of signal and background candidates obtained with a certain selection strategy, or choice of the threshold.
#
# Let's try to maximise this metric for our problem.
#
# First, we need to define $S$ and $B$ as a function of the threshold applied.
#
# We identify a pure-background region and a signal box.

# %%
_, boundaries, _ = plt.hist (df_sig['M'], bins = 20, label = "Signal box")
plt.hist (df_sig.query("M<3.6 or M>3.8")['M'], bins = boundaries, label = f"Background")
plt.legend()
plt.xlabel ("Dimuon mass [MeV/$c^2$]")
plt.ylabel ("Candidates")
plt.show()

# %% [markdown]
# Then we obtain the histograms of the logistic regression prediction $\hat y$ for the sample in the signal box and in the pure-background regions.
#
# We can rescale the number of events in the background region to predict the number of events in the signal box based on the length of the two mass intervals.
#
# Once we have the two histograms, we can compute the number of events with $\hat y < \mathrm{threshold}$ as cumulative sum of the bin contents of the histogram.
#
# The events surviving the selection are those with $\hat y > \mathrm{threshold}$ which are nothing but the total number of events minus those with $\hat y < \mathrm{threshold}$ defined above.

# %%
## Compute the histogram of events in the sidebands
bkg_proxy, boundaries = np.histogram(df_sig.query("M<3.6 or M>3.8")['y_hat'], bins = 100)

## Rescale the events in the sidebands to obtain the number of background events in the signal box
nB = bkg_proxy * (3.8-3.6)/(3.6-3.5+3.9-3.8)

## Compute the prediction of the logistic regression for the whole sample
df['y_hat'] = lr.predict(df[['prep_p', 'prep_theta']].values)

## Compute the histogram of events in the signal box (both signal and background) 
nS, _ = np.histogram(df.query("M > 3.0 and M < 3.2")['y_hat'], bins=boundaries)

## Compute the number of events with yhat > threshold
nB = np.sum(nB) - np.cumsum(nB)
effS = (np.sum(nS) - np.cumsum(nS))/np.sum(nS)

## Finally compute the figure of merit effS / ( 1.5 + sqrt (B) ) 
epsilon = 1e-12
fom = effS / (1.5 + np.sqrt(nB + epsilon))

## And determine the best threshold 
xAxis = 0.5 * (boundaries[1:] + boundaries[:-1])
best_threshold = xAxis[np.argmax(fom)]

plt.plot (xAxis, fom, '.')
plt.xlabel("Logistic Regression output")
plt.ylabel("Punzi figure of merit")

plt.title (f"Max. significance for $\hat y > {best_threshold:.3f}$")
plt.plot ([best_threshold, best_threshold], [fom.min(), fom.max()], 'k--')
plt.show()

# %% [markdown]
# Finally we draw the histogram obtained with the optimal selection.
# In this case, the signal is already quite enhanced and the logistic regression not very effective and therefore the two histograms appear very similar.
#
# Nonetheless, note we rejected some background almost without affecting the signal component for free.

# %%
plt.hist (df_sig['M'], bins = np.linspace(3.5, 3.9, 41), histtype='step', label = "Without selection", linewidth=2)

plt.hist (df_sig.query(f'y_hat>{best_threshold}')['M'], bins = np.linspace(3.5, 3.9, 41), label ="With selection")

plt.legend()
plt.show()

# %% [markdown]
# ## Map of the selection
# Since we are using two variables only, we can superpose the decision of the neural network to the distribution of the dataset on the plane $p \perp \theta$.
# From this excercise it should be evident the "linearity" of the logistic regression.
#
# > In short, the algorithm (the logistic regression or the neural network) defines the shape of the *boundaries* with the optimization of the figure of merit we select *which* boundary separates the two classes.

# %%
def make_plot (p, theta, yNN):
    plt.plot (df_sig['p'], df_sig['theta'], '.', alpha=0.4, markersize=2, color='red', label="Signal region")
    plt.plot (df_bkg['p'], df_bkg['theta'], '.', alpha=0.4,  markersize=2, color='blue', label="Background")
    plt.plot (df_ctrl['p'], df_ctrl['theta'], '.', alpha=0.3,  markersize=2, color='green', label="Control region")

    plt.contour (p, theta, yNN.reshape(p.shape), cmap='coolwarm', levels=10, alpha=1, linewidths=3)
  
    plt.legend()
    plt.xscale('log')
    plt.xlabel ("Dimuon momentum [GeV/$c$]")
    plt.ylabel ("Polar angle [°]")
    plt.show()

pAxis = 10**np.linspace (0.5, 2.5, 100)
thetaAxis = np.linspace (0, 90, 100)
p, theta = np.meshgrid (pAxis, thetaAxis)

prep_p = (np.log(p) - np.log(df['p'].mean()))/(np.log(np.std(df['p'])))
prep_theta = (theta - theta.mean()) / np.std(theta)

yNN = lr.predict ((np.stack([prep_p.flatten(), prep_theta.flatten()], axis = -1)))
plt.title (f"AUC: {history_lr.history['val_auc'][-1]:.3f}")
make_plot (p, theta, yNN)

# %% [markdown]
# ## Adding non-linearity: Neural networks
#
# We are ready to add non-linarity to our "fit function" by adding layers to our nerual network.
#
# Let's start with a shallow neural network made of one layer of 16 nodes.

# %%
nn = create_model(n_layers=1, n_nodes = 16)
history_nn = nn.fit (X, y, epochs=50, validation_split=0.5, verbose=True)
# Out:
# Epoch 1/50
# 152/152 [==============================] - 2s 7ms/step - loss: 0.6514 - auc: 0.4881 - val_loss: 0.5713 - val_auc: 0.5779
# Epoch 2/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5657 - auc: 0.5672 - val_loss: 0.5610 - val_auc: 0.5782
# Epoch 3/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5627 - auc: 0.5672 - val_loss: 0.5605 - val_auc: 0.5768
# Epoch 4/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5627 - auc: 0.5652 - val_loss: 0.5604 - val_auc: 0.5749
# Epoch 5/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5620 - auc: 0.5652 - val_loss: 0.5602 - val_auc: 0.5746
# Epoch 6/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5618 - auc: 0.5666 - val_loss: 0.5606 - val_auc: 0.5710
# Epoch 7/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5616 - auc: 0.5629 - val_loss: 0.5601 - val_auc: 0.5721
# Epoch 8/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5616 - auc: 0.5600 - val_loss: 0.5602 - val_auc: 0.5713
# Epoch 9/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5611 - auc: 0.5653 - val_loss: 0.5603 - val_auc: 0.5706
# Epoch 10/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5612 - auc: 0.5624 - val_loss: 0.5597 - val_auc: 0.5715
# Epoch 11/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5609 - auc: 0.5626 - val_loss: 0.5598 - val_auc: 0.5704
# Epoch 12/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5610 - auc: 0.5625 - val_loss: 0.5596 - val_auc: 0.5714
# Epoch 13/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5606 - auc: 0.5673 - val_loss: 0.5598 - val_auc: 0.5707
# Epoch 14/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5610 - auc: 0.5610 - val_loss: 0.5592 - val_auc: 0.5718
# Epoch 15/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5607 - auc: 0.5612 - val_loss: 0.5591 - val_auc: 0.5725
# Epoch 16/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5606 - auc: 0.5626 - val_loss: 0.5592 - val_auc: 0.5721
# Epoch 17/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.5606 - auc: 0.5593 - val_loss: 0.5589 - val_auc: 0.5722
# Epoch 18/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5605 - auc: 0.5616 - val_loss: 0.5588 - val_auc: 0.5738
# Epoch 19/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5604 - auc: 0.5587 - val_loss: 0.5586 - val_auc: 0.5743
# Epoch 20/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5603 - auc: 0.5624 - val_loss: 0.5585 - val_auc: 0.5742
# Epoch 21/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5601 - auc: 0.5631 - val_loss: 0.5586 - val_auc: 0.5736
# Epoch 22/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5602 - auc: 0.5619 - val_loss: 0.5583 - val_auc: 0.5744
# Epoch 23/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5599 - auc: 0.5620 - val_loss: 0.5583 - val_auc: 0.5739
# Epoch 24/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5599 - auc: 0.5614 - val_loss: 0.5584 - val_auc: 0.5750
# Epoch 25/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5599 - auc: 0.5608 - val_loss: 0.5582 - val_auc: 0.5755
# Epoch 26/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5599 - auc: 0.5611 - val_loss: 0.5581 - val_auc: 0.5754
# Epoch 27/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5600 - auc: 0.5660 - val_loss: 0.5577 - val_auc: 0.5761
# Epoch 28/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5596 - auc: 0.5614 - val_loss: 0.5579 - val_auc: 0.5756
# Epoch 29/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.5596 - auc: 0.5628 - val_loss: 0.5577 - val_auc: 0.5763
# Epoch 30/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5595 - auc: 0.5646 - val_loss: 0.5576 - val_auc: 0.5765
# Epoch 31/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5595 - auc: 0.5617 - val_loss: 0.5576 - val_auc: 0.5764
# Epoch 32/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5594 - auc: 0.5638 - val_loss: 0.5581 - val_auc: 0.5757
# Epoch 33/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5593 - auc: 0.5623 - val_loss: 0.5576 - val_auc: 0.5774
# Epoch 34/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5591 - auc: 0.5663 - val_loss: 0.5575 - val_auc: 0.5771
# Epoch 35/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5592 - auc: 0.5638 - val_loss: 0.5573 - val_auc: 0.5770
# Epoch 36/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5594 - auc: 0.5622 - val_loss: 0.5574 - val_auc: 0.5775
# Epoch 37/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5588 - auc: 0.5656 - val_loss: 0.5574 - val_auc: 0.5769
# Epoch 38/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5592 - auc: 0.5615 - val_loss: 0.5573 - val_auc: 0.5776
# Epoch 39/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5590 - auc: 0.5627 - val_loss: 0.5574 - val_auc: 0.5772
# Epoch 40/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5590 - auc: 0.5637 - val_loss: 0.5570 - val_auc: 0.5789
# Epoch 41/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5590 - auc: 0.5636 - val_loss: 0.5573 - val_auc: 0.5782
# Epoch 42/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5589 - auc: 0.5637 - val_loss: 0.5570 - val_auc: 0.5779
# Epoch 43/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5587 - auc: 0.5636 - val_loss: 0.5572 - val_auc: 0.5784
# Epoch 44/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5589 - auc: 0.5603 - val_loss: 0.5571 - val_auc: 0.5783
# Epoch 45/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5585 - auc: 0.5659 - val_loss: 0.5573 - val_auc: 0.5784
# Epoch 46/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5586 - auc: 0.5622 - val_loss: 0.5568 - val_auc: 0.5797
# Epoch 47/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5585 - auc: 0.5651 - val_loss: 0.5568 - val_auc: 0.5798
# Epoch 48/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5584 - auc: 0.5675 - val_loss: 0.5571 - val_auc: 0.5799
# Epoch 49/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5586 - auc: 0.5653 - val_loss: 0.5568 - val_auc: 0.5807
# Epoch 50/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5584 - auc: 0.5618 - val_loss: 0.5569 - val_auc: 0.5780

# %% [markdown]
# We should ensure we are far from over training and that the training is advanced enough by checking the evolution of the loss function of both the validation and training data sets.
#
# We will define a function `plot_loss` to make it faster to plot the loss for the next steps.

# %%
def plot_loss (history, title="Loss"):
    plt.plot (history.history['loss'], '-', label="Training")
    plt.plot (history.history['val_loss'], '-', label="Validation")
    plt.xlabel ("Epoch")
    plt.ylabel ("Binary cross-entropy")
    plt.legend()
    plt.title (title)

plot_loss (history_nn, title = "Shallow neural network training")
plt.show()

# %% [markdown]
# Finally we can check the effect on the plane $p \perp \theta$ and see the effect of the non-linearity in action.

# %%
prep_p = (np.log(p) - np.log(df['p'].mean()))/(np.log(np.std(df['p'])))
prep_theta = (theta - theta.mean()) / np.std(theta)

yNN = nn.predict ((np.stack([prep_p.flatten(), prep_theta.flatten()], axis = -1)))

plt.title (f"AUC: {history_nn.history['val_auc'][-1]:.3f}")
make_plot (p, theta, yNN)

# %% [markdown]
# ## Going deep
# The more the layers and the nodes the more complex the fit function is.
#
# Let's see what happens with 3 layers of 16 nodes each.

# %%
dnn = create_model(n_layers=3, n_nodes = 16)
history_dnn = dnn.fit (X, y, epochs=50, validation_split=0.5, verbose=True)
prep_p = (np.log(p) - np.log(df['p'].mean()))/(np.log(np.std(df['p'])))
prep_theta = (theta - theta.mean()) / np.std(theta)

yNN = dnn.predict ((np.stack([prep_p.flatten(), prep_theta.flatten()], axis = -1)))

plt.title (f"AUC: {history_dnn.history['val_auc'][-1]:.3f}")
make_plot (p, theta, yNN)
# Out:
# Epoch 1/50
# 152/152 [==============================] - 2s 7ms/step - loss: 0.5780 - auc: 0.5565 - val_loss: 0.5627 - val_auc: 0.5708
# Epoch 2/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5608 - auc: 0.5770 - val_loss: 0.5587 - val_auc: 0.5740
# Epoch 3/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5608 - auc: 0.5617 - val_loss: 0.5579 - val_auc: 0.5730
# Epoch 4/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5596 - auc: 0.5739 - val_loss: 0.5607 - val_auc: 0.5718
# Epoch 5/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5597 - auc: 0.5625 - val_loss: 0.5575 - val_auc: 0.5730
# Epoch 6/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5591 - auc: 0.5598 - val_loss: 0.5589 - val_auc: 0.5714
# Epoch 7/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5593 - auc: 0.5578 - val_loss: 0.5582 - val_auc: 0.5720
# Epoch 8/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5589 - auc: 0.5683 - val_loss: 0.5568 - val_auc: 0.5716
# Epoch 9/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5590 - auc: 0.5651 - val_loss: 0.5566 - val_auc: 0.5703
# Epoch 10/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5575 - auc: 0.5759 - val_loss: 0.5591 - val_auc: 0.5731
# Epoch 11/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5588 - auc: 0.5612 - val_loss: 0.5567 - val_auc: 0.5715
# Epoch 12/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5582 - auc: 0.5625 - val_loss: 0.5563 - val_auc: 0.5740
# Epoch 13/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.5579 - auc: 0.5716 - val_loss: 0.5562 - val_auc: 0.5733
# Epoch 14/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5573 - auc: 0.5614 - val_loss: 0.5562 - val_auc: 0.5759
# Epoch 15/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5576 - auc: 0.5588 - val_loss: 0.5566 - val_auc: 0.5744
# Epoch 16/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5570 - auc: 0.5675 - val_loss: 0.5565 - val_auc: 0.5753
# Epoch 17/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5583 - auc: 0.5603 - val_loss: 0.5563 - val_auc: 0.5778
# Epoch 18/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5569 - auc: 0.5757 - val_loss: 0.5566 - val_auc: 0.5690
# Epoch 19/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5572 - auc: 0.5665 - val_loss: 0.5565 - val_auc: 0.5758
# Epoch 20/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5571 - auc: 0.5669 - val_loss: 0.5558 - val_auc: 0.5794
# Epoch 21/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5570 - auc: 0.5618 - val_loss: 0.5559 - val_auc: 0.5799
# Epoch 22/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5569 - auc: 0.5681 - val_loss: 0.5564 - val_auc: 0.5781
# Epoch 23/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.5566 - auc: 0.5747 - val_loss: 0.5576 - val_auc: 0.5815
# Epoch 24/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5569 - auc: 0.5667 - val_loss: 0.5554 - val_auc: 0.5862
# Epoch 25/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5568 - auc: 0.5659 - val_loss: 0.5556 - val_auc: 0.5897
# Epoch 26/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5568 - auc: 0.5697 - val_loss: 0.5554 - val_auc: 0.5886
# Epoch 27/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5564 - auc: 0.5715 - val_loss: 0.5552 - val_auc: 0.5918
# Epoch 28/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5567 - auc: 0.5766 - val_loss: 0.5554 - val_auc: 0.5909
# Epoch 29/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5560 - auc: 0.5737 - val_loss: 0.5574 - val_auc: 0.5923
# Epoch 30/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5566 - auc: 0.5656 - val_loss: 0.5554 - val_auc: 0.5909
# Epoch 31/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5559 - auc: 0.5798 - val_loss: 0.5553 - val_auc: 0.5909
# Epoch 32/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5566 - auc: 0.5667 - val_loss: 0.5550 - val_auc: 0.5920
# Epoch 33/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5566 - auc: 0.5664 - val_loss: 0.5550 - val_auc: 0.5909
# Epoch 34/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5560 - auc: 0.5771 - val_loss: 0.5558 - val_auc: 0.5927
# Epoch 35/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5563 - auc: 0.5712 - val_loss: 0.5554 - val_auc: 0.5941
# Epoch 36/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5557 - auc: 0.5793 - val_loss: 0.5557 - val_auc: 0.5929
# Epoch 37/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5566 - auc: 0.5721 - val_loss: 0.5546 - val_auc: 0.5929
# Epoch 38/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5561 - auc: 0.5726 - val_loss: 0.5552 - val_auc: 0.5919
# Epoch 39/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5559 - auc: 0.5787 - val_loss: 0.5566 - val_auc: 0.5897
# Epoch 40/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5560 - auc: 0.5740 - val_loss: 0.5550 - val_auc: 0.5931
# Epoch 41/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5554 - auc: 0.5810 - val_loss: 0.5556 - val_auc: 0.5939
# Epoch 42/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5559 - auc: 0.5757 - val_loss: 0.5548 - val_auc: 0.5915
# Epoch 43/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5561 - auc: 0.5703 - val_loss: 0.5544 - val_auc: 0.5903
# Epoch 44/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5558 - auc: 0.5738 - val_loss: 0.5549 - val_auc: 0.5915
# Epoch 45/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5563 - auc: 0.5712 - val_loss: 0.5545 - val_auc: 0.5940
# Epoch 46/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5560 - auc: 0.5708 - val_loss: 0.5547 - val_auc: 0.5937
# Epoch 47/50
# 152/152 [==============================] - 1s 6ms/step - loss: 0.5558 - auc: 0.5741 - val_loss: 0.5545 - val_auc: 0.5909
# Epoch 48/50
# 152/152 [==============================] - 1s 5ms/step - loss: 0.5557 - auc: 0.5757 - val_loss: 0.5546 - val_auc: 0.5908
# Epoch 49/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5552 - auc: 0.5759 - val_loss: 0.5551 - val_auc: 0.5902
# Epoch 50/50
# 152/152 [==============================] - 1s 4ms/step - loss: 0.5557 - auc: 0.5730 - val_loss: 0.5543 - val_auc: 0.5912

# %% [markdown]
# The improvement in terms of AUC seems significant but we can easily imagine more complex functions with that many free parameters.
#
# The problem is that most of the network is not used and the local minimum where the training stops is far from the global minimum of the minimization.
#
# When going deep, the initialization of the layer weights may become critical.

# %% [markdown]
# ## Pushing the limit: *hyper-parameter tuning*
#
# The initialization of the layer weights is however only one of the many aspects of the neural network that can be tuned to improve its performance.
#
# In the following we amused ourselves to try to push a bit the neural network training to improve its classification score.
# We redefined the function `create_model` to add a custom initialization of the weights of the layers and modify the learning rate of the Adam optimizer.

# %%
def create_model_advanced (n_layers=1, n_nodes=32):
    inputs = K.layers.Input(shape=(2))
    layers = [inputs]
    for iLayer in range(n_layers): 
      layers.append(K.layers.Dense(n_nodes, activation='tanh', kernel_initializer='he_normal', bias_initializer='zeros') (layers[-1]))

    outputs = K.layers.Dense(1, activation = 'sigmoid')(layers[-1])

    model = K.models.Model (inputs=inputs, outputs=outputs)
    model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(1.5e-3), metrics=['AUC'])

    return model

# %% [markdown]
# Then we define a 2-layer deep neural network with 64 nodes per layer and train it for 100 epochs (these are all hyperparameters).
#
# The resulting segmentation of the $p \perp \theta$ plane is significantly more complicated, but it still generalizes properly to the validation dataset.

# %%
dnn = create_model_advanced(n_layers=2, n_nodes = 64)
history_dnn = dnn.fit (X, y, epochs=100, validation_split=0.5, verbose=True, batch_size=100)
prep_p = (np.log(p) - np.log(df['p'].mean()))/(np.log(np.std(df['p'])))
prep_theta = (theta - theta.mean()) / np.std(theta)

yNN = dnn.predict ((np.stack([prep_p.flatten(), prep_theta.flatten()], axis = -1)))

plt.title (f"AUC: {history_dnn.history['val_auc'][-1]:.3f}")
make_plot (p, theta, yNN)
plt.show()
plot_loss (history_dnn)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.5949 - auc: 0.5633 - val_loss: 0.5662 - val_auc: 0.5437
# Epoch 2/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5608 - auc: 0.5581 - val_loss: 0.5566 - val_auc: 0.5848
# Epoch 3/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5614 - auc: 0.5603 - val_loss: 0.5625 - val_auc: 0.5835
# Epoch 4/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5588 - auc: 0.5796 - val_loss: 0.5602 - val_auc: 0.5564
# Epoch 5/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5574 - auc: 0.5797 - val_loss: 0.5608 - val_auc: 0.5851
# Epoch 6/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5605 - auc: 0.5610 - val_loss: 0.5572 - val_auc: 0.5656
# Epoch 7/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5588 - auc: 0.5662 - val_loss: 0.5560 - val_auc: 0.5842
# Epoch 8/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5590 - auc: 0.5634 - val_loss: 0.5586 - val_auc: 0.5826
# Epoch 9/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5603 - auc: 0.5740 - val_loss: 0.5596 - val_auc: 0.5825
# Epoch 10/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5590 - auc: 0.5670 - val_loss: 0.5579 - val_auc: 0.5808
# Epoch 11/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5594 - auc: 0.5634 - val_loss: 0.5567 - val_auc: 0.5677
# Epoch 12/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5592 - auc: 0.5641 - val_loss: 0.5569 - val_auc: 0.5737
# Epoch 13/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5585 - auc: 0.5747 - val_loss: 0.5612 - val_auc: 0.5842
# Epoch 14/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5598 - auc: 0.5724 - val_loss: 0.5559 - val_auc: 0.5830
# Epoch 15/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5581 - auc: 0.5651 - val_loss: 0.5557 - val_auc: 0.5800
# Epoch 16/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5572 - auc: 0.5752 - val_loss: 0.5625 - val_auc: 0.5855
# Epoch 17/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5585 - auc: 0.5667 - val_loss: 0.5556 - val_auc: 0.5823
# Epoch 18/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5588 - auc: 0.5636 - val_loss: 0.5563 - val_auc: 0.5734
# Epoch 19/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5569 - auc: 0.5676 - val_loss: 0.5574 - val_auc: 0.5856
# Epoch 20/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5571 - auc: 0.5674 - val_loss: 0.5565 - val_auc: 0.5756
# Epoch 21/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5571 - auc: 0.5731 - val_loss: 0.5558 - val_auc: 0.5813
# Epoch 22/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5567 - auc: 0.5745 - val_loss: 0.5587 - val_auc: 0.5616
# Epoch 23/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5574 - auc: 0.5716 - val_loss: 0.5645 - val_auc: 0.5331
# Epoch 24/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5573 - auc: 0.5801 - val_loss: 0.5564 - val_auc: 0.5836
# Epoch 25/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5577 - auc: 0.5664 - val_loss: 0.5563 - val_auc: 0.5822
# Epoch 26/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5568 - auc: 0.5680 - val_loss: 0.5554 - val_auc: 0.5830
# Epoch 27/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5564 - auc: 0.5772 - val_loss: 0.5632 - val_auc: 0.5492
# Epoch 28/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5573 - auc: 0.5748 - val_loss: 0.5567 - val_auc: 0.5729
# Epoch 29/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5583 - auc: 0.5651 - val_loss: 0.5597 - val_auc: 0.5553
# Epoch 30/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5558 - auc: 0.5811 - val_loss: 0.5586 - val_auc: 0.5637
# Epoch 31/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5584 - auc: 0.5766 - val_loss: 0.5562 - val_auc: 0.5803
# Epoch 32/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5569 - auc: 0.5717 - val_loss: 0.5561 - val_auc: 0.5750
# Epoch 33/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5557 - auc: 0.5756 - val_loss: 0.5566 - val_auc: 0.5761
# Epoch 34/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5558 - auc: 0.5817 - val_loss: 0.5589 - val_auc: 0.5836
# Epoch 35/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5560 - auc: 0.5842 - val_loss: 0.5630 - val_auc: 0.5434
# Epoch 36/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5569 - auc: 0.5671 - val_loss: 0.5559 - val_auc: 0.5809
# Epoch 37/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5557 - auc: 0.5734 - val_loss: 0.5565 - val_auc: 0.5729
# Epoch 38/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5555 - auc: 0.5728 - val_loss: 0.5559 - val_auc: 0.5786
# Epoch 39/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5555 - auc: 0.5782 - val_loss: 0.5560 - val_auc: 0.5800
# Epoch 40/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5558 - auc: 0.5781 - val_loss: 0.5582 - val_auc: 0.5673
# Epoch 41/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5553 - auc: 0.5730 - val_loss: 0.5559 - val_auc: 0.5768
# Epoch 42/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5563 - auc: 0.5791 - val_loss: 0.5562 - val_auc: 0.5743
# Epoch 43/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5554 - auc: 0.5765 - val_loss: 0.5560 - val_auc: 0.5785
# Epoch 44/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5558 - auc: 0.5795 - val_loss: 0.5559 - val_auc: 0.5770
# Epoch 45/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5553 - auc: 0.5903 - val_loss: 0.5569 - val_auc: 0.5697
# Epoch 46/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5559 - auc: 0.5715 - val_loss: 0.5587 - val_auc: 0.5779
# Epoch 47/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5556 - auc: 0.5802 - val_loss: 0.5601 - val_auc: 0.5789
# Epoch 48/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5562 - auc: 0.5805 - val_loss: 0.5566 - val_auc: 0.5702
# Epoch 49/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5542 - auc: 0.5907 - val_loss: 0.5586 - val_auc: 0.5784
# Epoch 50/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5544 - auc: 0.5922 - val_loss: 0.5585 - val_auc: 0.5821
# Epoch 51/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5556 - auc: 0.5814 - val_loss: 0.5565 - val_auc: 0.5732
# Epoch 52/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5549 - auc: 0.5807 - val_loss: 0.5556 - val_auc: 0.5786
# Epoch 53/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5546 - auc: 0.5800 - val_loss: 0.5586 - val_auc: 0.5710
# Epoch 54/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5544 - auc: 0.5818 - val_loss: 0.5582 - val_auc: 0.5791
# Epoch 55/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5556 - auc: 0.5789 - val_loss: 0.5571 - val_auc: 0.5742
# Epoch 56/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5553 - auc: 0.5692 - val_loss: 0.5555 - val_auc: 0.5747
# Epoch 57/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5560 - auc: 0.5704 - val_loss: 0.5558 - val_auc: 0.5740
# Epoch 58/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5554 - auc: 0.5797 - val_loss: 0.5565 - val_auc: 0.5738
# Epoch 59/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5544 - auc: 0.5811 - val_loss: 0.5576 - val_auc: 0.5746
# Epoch 60/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5543 - auc: 0.5795 - val_loss: 0.5559 - val_auc: 0.5775
# Epoch 61/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5548 - auc: 0.5802 - val_loss: 0.5568 - val_auc: 0.5767
# Epoch 62/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5561 - auc: 0.5862 - val_loss: 0.5568 - val_auc: 0.5779
# Epoch 63/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5553 - auc: 0.5829 - val_loss: 0.5603 - val_auc: 0.5668
# Epoch 64/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5560 - auc: 0.5732 - val_loss: 0.5583 - val_auc: 0.5717
# Epoch 65/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5549 - auc: 0.5829 - val_loss: 0.5559 - val_auc: 0.5749
# Epoch 66/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5541 - auc: 0.5829 - val_loss: 0.5566 - val_auc: 0.5717
# Epoch 67/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5538 - auc: 0.5856 - val_loss: 0.5562 - val_auc: 0.5756
# Epoch 68/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5547 - auc: 0.5801 - val_loss: 0.5563 - val_auc: 0.5781
# Epoch 69/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5544 - auc: 0.5799 - val_loss: 0.5562 - val_auc: 0.5762
# Epoch 70/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5540 - auc: 0.5839 - val_loss: 0.5573 - val_auc: 0.5740
# Epoch 71/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5537 - auc: 0.5871 - val_loss: 0.5574 - val_auc: 0.5744
# Epoch 72/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5547 - auc: 0.5809 - val_loss: 0.5558 - val_auc: 0.5778
# Epoch 73/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5536 - auc: 0.5845 - val_loss: 0.5558 - val_auc: 0.5769
# Epoch 74/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5534 - auc: 0.5872 - val_loss: 0.5568 - val_auc: 0.5739
# Epoch 75/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5567 - auc: 0.5758 - val_loss: 0.5557 - val_auc: 0.5736
# Epoch 76/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5539 - auc: 0.5859 - val_loss: 0.5570 - val_auc: 0.5746
# Epoch 77/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5533 - auc: 0.5852 - val_loss: 0.5562 - val_auc: 0.5777
# Epoch 78/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5534 - auc: 0.5906 - val_loss: 0.5579 - val_auc: 0.5798
# Epoch 79/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5534 - auc: 0.5893 - val_loss: 0.5567 - val_auc: 0.5774
# Epoch 80/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5543 - auc: 0.5844 - val_loss: 0.5569 - val_auc: 0.5751
# Epoch 81/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5537 - auc: 0.5897 - val_loss: 0.5575 - val_auc: 0.5683
# Epoch 82/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5530 - auc: 0.5860 - val_loss: 0.5566 - val_auc: 0.5719
# Epoch 83/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5533 - auc: 0.5889 - val_loss: 0.5572 - val_auc: 0.5726
# Epoch 84/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5535 - auc: 0.5863 - val_loss: 0.5562 - val_auc: 0.5754
# Epoch 85/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5527 - auc: 0.5914 - val_loss: 0.5583 - val_auc: 0.5765
# Epoch 86/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5545 - auc: 0.5807 - val_loss: 0.5567 - val_auc: 0.5779
# Epoch 87/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5537 - auc: 0.5844 - val_loss: 0.5577 - val_auc: 0.5707
# Epoch 88/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5547 - auc: 0.5788 - val_loss: 0.5566 - val_auc: 0.5741
# Epoch 89/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5526 - auc: 0.5869 - val_loss: 0.5569 - val_auc: 0.5747
# Epoch 90/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5538 - auc: 0.5805 - val_loss: 0.5562 - val_auc: 0.5718
# Epoch 91/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5529 - auc: 0.5859 - val_loss: 0.5572 - val_auc: 0.5751
# Epoch 92/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5530 - auc: 0.5886 - val_loss: 0.5562 - val_auc: 0.5741
# Epoch 93/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5531 - auc: 0.5848 - val_loss: 0.5569 - val_auc: 0.5741
# Epoch 94/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5530 - auc: 0.5863 - val_loss: 0.5572 - val_auc: 0.5714
# Epoch 95/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5533 - auc: 0.5831 - val_loss: 0.5579 - val_auc: 0.5783
# Epoch 96/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5533 - auc: 0.5848 - val_loss: 0.5563 - val_auc: 0.5754
# Epoch 97/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5529 - auc: 0.5896 - val_loss: 0.5578 - val_auc: 0.5710
# Epoch 98/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5526 - auc: 0.5869 - val_loss: 0.5565 - val_auc: 0.5735
# Epoch 99/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5528 - auc: 0.5872 - val_loss: 0.5566 - val_auc: 0.5716
# Epoch 100/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5526 - auc: 0.5863 - val_loss: 0.5565 - val_auc: 0.5734

# %% [markdown]
# ## Breaking the limit: *overtraining*
#
# While tuning the hyperparameters it may happen that the function becomes so complicated that it can fit the single signal and background entries in the training sample, loosing any generalization power on the validation sample.
# In this case we talk of *overtraining*.
#
# Overtraining is often seen as bad thing in machine learning.
# However, reaching overtraining and then fighting against it is a good strategy when designing a neural network because a poorly designed neural network or a choice of hyperparameters too far from optimum will result in **undertraining** even if a large number of free parameters is used (as in the example of the 3-layer deep neural network above).
#
# Clearly, you should **never rely on the efficiency and rejection evaluated on the training sample**.

# %%
dnn = create_model_advanced(n_layers=5, n_nodes = 64)
history_dnn = dnn.fit (X, y, epochs=150, validation_split=0.5, verbose=True, batch_size=100)
prep_p = (np.log(p) - np.log(df['p'].mean()))/(np.log(np.std(df['p'])))
prep_theta = (theta - theta.mean()) / np.std(theta)

yNN = dnn.predict ((np.stack([prep_p.flatten(), prep_theta.flatten()], axis = -1)))

plt.title (f"AUC: {history_dnn.history['val_auc'][-1]:.3f}")
make_plot (p, theta, yNN)
plot_loss (history_dnn)
# Out:
# Epoch 1/150
# 49/49 [==============================] - 1s 9ms/step - loss: 0.5767 - auc: 0.5560 - val_loss: 0.5603 - val_auc: 0.5742
# Epoch 2/150
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5636 - auc: 0.5664 - val_loss: 0.5578 - val_auc: 0.5657
# Epoch 3/150
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5678 - auc: 0.5568 - val_loss: 0.5633 - val_auc: 0.5297
# Epoch 4/150
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5634 - auc: 0.5630 - val_loss: 0.5635 - val_auc: 0.5451
# Epoch 5/150
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5594 - auc: 0.5745 - val_loss: 0.5576 - val_auc: 0.5837
# Epoch 6/150
# 49/49 [==============================] - 0s 6ms/step - loss: 0.5594 - auc: 0.5693 - val_loss: 0.5647 - val_auc: 0.5784
# Epoch 7/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5570 - auc: 0.5796 - val_loss: 0.5572 - val_auc: 0.5802
# Epoch 8/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5598 - auc: 0.5712 - val_loss: 0.5588 - val_auc: 0.5740
# Epoch 9/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5584 - auc: 0.5638 - val_loss: 0.5603 - val_auc: 0.5794
# Epoch 10/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5580 - auc: 0.5770 - val_loss: 0.5568 - val_auc: 0.5732
# Epoch 11/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5586 - auc: 0.5712 - val_loss: 0.5588 - val_auc: 0.5716
# Epoch 12/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5559 - auc: 0.5640 - val_loss: 0.5592 - val_auc: 0.5669
# Epoch 13/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5558 - auc: 0.5833 - val_loss: 0.5583 - val_auc: 0.5731
# Epoch 14/150
# 49/49 [==============================] - 0s 10ms/step - loss: 0.5562 - auc: 0.5746 - val_loss: 0.5613 - val_auc: 0.5712
# Epoch 15/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5561 - auc: 0.5723 - val_loss: 0.5564 - val_auc: 0.5749
# Epoch 16/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5572 - auc: 0.5727 - val_loss: 0.5619 - val_auc: 0.5537
# Epoch 17/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5567 - auc: 0.5753 - val_loss: 0.5591 - val_auc: 0.5701
# Epoch 18/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5568 - auc: 0.5678 - val_loss: 0.5591 - val_auc: 0.5711
# Epoch 19/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5556 - auc: 0.5864 - val_loss: 0.5627 - val_auc: 0.5670
# Epoch 20/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5603 - auc: 0.5662 - val_loss: 0.5572 - val_auc: 0.5718
# Epoch 21/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5563 - auc: 0.5827 - val_loss: 0.5577 - val_auc: 0.5750
# Epoch 22/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5558 - auc: 0.5763 - val_loss: 0.5578 - val_auc: 0.5709
# Epoch 23/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5558 - auc: 0.5719 - val_loss: 0.5590 - val_auc: 0.5699
# Epoch 24/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5587 - auc: 0.5505 - val_loss: 0.5563 - val_auc: 0.5742
# Epoch 25/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5546 - auc: 0.5704 - val_loss: 0.5608 - val_auc: 0.5656
# Epoch 26/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5564 - auc: 0.5760 - val_loss: 0.5590 - val_auc: 0.5660
# Epoch 27/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5578 - auc: 0.5762 - val_loss: 0.5584 - val_auc: 0.5740
# Epoch 28/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5553 - auc: 0.5807 - val_loss: 0.5588 - val_auc: 0.5859
# Epoch 29/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5559 - auc: 0.5829 - val_loss: 0.5583 - val_auc: 0.5730
# Epoch 30/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5559 - auc: 0.5779 - val_loss: 0.5570 - val_auc: 0.5804
# Epoch 31/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5538 - auc: 0.5828 - val_loss: 0.5575 - val_auc: 0.5722
# Epoch 32/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5537 - auc: 0.5773 - val_loss: 0.5570 - val_auc: 0.5769
# Epoch 33/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5526 - auc: 0.5814 - val_loss: 0.5602 - val_auc: 0.5736
# Epoch 34/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5557 - auc: 0.5841 - val_loss: 0.5555 - val_auc: 0.5758
# Epoch 35/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5540 - auc: 0.5728 - val_loss: 0.5565 - val_auc: 0.5709
# Epoch 36/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5544 - auc: 0.5791 - val_loss: 0.5571 - val_auc: 0.5704
# Epoch 37/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5547 - auc: 0.5780 - val_loss: 0.5659 - val_auc: 0.5433
# Epoch 38/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5551 - auc: 0.5809 - val_loss: 0.5575 - val_auc: 0.5707
# Epoch 39/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5541 - auc: 0.5786 - val_loss: 0.5595 - val_auc: 0.5734
# Epoch 40/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5534 - auc: 0.5813 - val_loss: 0.5568 - val_auc: 0.5721
# Epoch 41/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5549 - auc: 0.5767 - val_loss: 0.5574 - val_auc: 0.5648
# Epoch 42/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5520 - auc: 0.5909 - val_loss: 0.5587 - val_auc: 0.5740
# Epoch 43/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5531 - auc: 0.5852 - val_loss: 0.5580 - val_auc: 0.5721
# Epoch 44/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5529 - auc: 0.5816 - val_loss: 0.5569 - val_auc: 0.5715
# Epoch 45/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5522 - auc: 0.5843 - val_loss: 0.5586 - val_auc: 0.5750
# Epoch 46/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5539 - auc: 0.5897 - val_loss: 0.5579 - val_auc: 0.5668
# Epoch 47/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5524 - auc: 0.5870 - val_loss: 0.5588 - val_auc: 0.5689
# Epoch 48/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5525 - auc: 0.5855 - val_loss: 0.5592 - val_auc: 0.5703
# Epoch 49/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5544 - auc: 0.5707 - val_loss: 0.5571 - val_auc: 0.5744
# Epoch 50/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5533 - auc: 0.5765 - val_loss: 0.5566 - val_auc: 0.5731
# Epoch 51/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5523 - auc: 0.5874 - val_loss: 0.5577 - val_auc: 0.5707
# Epoch 52/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5538 - auc: 0.5827 - val_loss: 0.5572 - val_auc: 0.5755
# Epoch 53/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5530 - auc: 0.5772 - val_loss: 0.5577 - val_auc: 0.5719
# Epoch 54/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5520 - auc: 0.5863 - val_loss: 0.5577 - val_auc: 0.5672
# Epoch 55/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5521 - auc: 0.5849 - val_loss: 0.5589 - val_auc: 0.5707
# Epoch 56/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5514 - auc: 0.5862 - val_loss: 0.5580 - val_auc: 0.5722
# Epoch 57/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5509 - auc: 0.5899 - val_loss: 0.5578 - val_auc: 0.5742
# Epoch 58/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5518 - auc: 0.5907 - val_loss: 0.5596 - val_auc: 0.5634
# Epoch 59/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5512 - auc: 0.5854 - val_loss: 0.5606 - val_auc: 0.5690
# Epoch 60/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5517 - auc: 0.5898 - val_loss: 0.5582 - val_auc: 0.5680
# Epoch 61/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5517 - auc: 0.5933 - val_loss: 0.5583 - val_auc: 0.5678
# Epoch 62/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5522 - auc: 0.5851 - val_loss: 0.5581 - val_auc: 0.5723
# Epoch 63/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5525 - auc: 0.5888 - val_loss: 0.5631 - val_auc: 0.5572
# Epoch 64/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5523 - auc: 0.5746 - val_loss: 0.5570 - val_auc: 0.5709
# Epoch 65/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5511 - auc: 0.5919 - val_loss: 0.5593 - val_auc: 0.5701
# Epoch 66/150
# 49/49 [==============================] - 0s 7ms/step - loss: 0.5546 - auc: 0.5809 - val_loss: 0.5578 - val_auc: 0.5631
# Epoch 67/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5507 - auc: 0.5902 - val_loss: 0.5596 - val_auc: 0.5732
# Epoch 68/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5510 - auc: 0.5943 - val_loss: 0.5572 - val_auc: 0.5682
# Epoch 69/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5500 - auc: 0.6011 - val_loss: 0.5600 - val_auc: 0.5694
# Epoch 70/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5500 - auc: 0.5956 - val_loss: 0.5576 - val_auc: 0.5713
# Epoch 71/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5503 - auc: 0.5877 - val_loss: 0.5581 - val_auc: 0.5711
# Epoch 72/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5496 - auc: 0.5902 - val_loss: 0.5582 - val_auc: 0.5725
# Epoch 73/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5502 - auc: 0.5846 - val_loss: 0.5592 - val_auc: 0.5764
# Epoch 74/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5519 - auc: 0.5883 - val_loss: 0.5592 - val_auc: 0.5690
# Epoch 75/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5504 - auc: 0.5936 - val_loss: 0.5646 - val_auc: 0.5665
# Epoch 76/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5525 - auc: 0.5848 - val_loss: 0.5595 - val_auc: 0.5757
# Epoch 77/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5507 - auc: 0.5968 - val_loss: 0.5597 - val_auc: 0.5725
# Epoch 78/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5484 - auc: 0.6045 - val_loss: 0.5587 - val_auc: 0.5702
# Epoch 79/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5494 - auc: 0.5935 - val_loss: 0.5589 - val_auc: 0.5698
# Epoch 80/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5489 - auc: 0.5962 - val_loss: 0.5594 - val_auc: 0.5705
# Epoch 81/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5492 - auc: 0.5966 - val_loss: 0.5581 - val_auc: 0.5712
# Epoch 82/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5491 - auc: 0.6000 - val_loss: 0.5604 - val_auc: 0.5692
# Epoch 83/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5498 - auc: 0.5906 - val_loss: 0.5578 - val_auc: 0.5744
# Epoch 84/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5495 - auc: 0.5893 - val_loss: 0.5578 - val_auc: 0.5737
# Epoch 85/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5498 - auc: 0.5915 - val_loss: 0.5582 - val_auc: 0.5714
# Epoch 86/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5504 - auc: 0.5842 - val_loss: 0.5605 - val_auc: 0.5679
# Epoch 87/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5488 - auc: 0.5871 - val_loss: 0.5588 - val_auc: 0.5735
# Epoch 88/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5501 - auc: 0.5938 - val_loss: 0.5596 - val_auc: 0.5728
# Epoch 89/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5502 - auc: 0.5877 - val_loss: 0.5592 - val_auc: 0.5695
# Epoch 90/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5489 - auc: 0.5886 - val_loss: 0.5588 - val_auc: 0.5665
# Epoch 91/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5485 - auc: 0.5887 - val_loss: 0.5604 - val_auc: 0.5599
# Epoch 92/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5483 - auc: 0.5915 - val_loss: 0.5622 - val_auc: 0.5713
# Epoch 93/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5506 - auc: 0.6009 - val_loss: 0.5604 - val_auc: 0.5726
# Epoch 94/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5490 - auc: 0.6008 - val_loss: 0.5601 - val_auc: 0.5615
# Epoch 95/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5478 - auc: 0.5971 - val_loss: 0.5593 - val_auc: 0.5696
# Epoch 96/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5478 - auc: 0.6006 - val_loss: 0.5605 - val_auc: 0.5721
# Epoch 97/150
# 49/49 [==============================] - 0s 8ms/step - loss: 0.5494 - auc: 0.5956 - val_loss: 0.5588 - val_auc: 0.5686
# Epoch 98/150
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5477 - auc: 0.5960 - val_loss: 0.5594 - val_auc: 0.5661
# Epoch 99/150
# 47/49 [===========================>..] - ETA: 0s - loss: 0.5475 - auc: 0.5935

# %% [markdown]
# # Conclusion
#
# Neural networks are a powerful algorithm to approximate functions, including non-linear classifiers.
# In this notebook we have discussed some basics of the statistics that should lead the design of a classification algorithm.
# We discussed the logistic regression as a special case of a neural network without layers, then we added one layer to design a shallow neural network and then another two layers to get a deep neural network.
#
# Depth is not enough, however. With a refinement of the initialization of the weights defining the two layers we have seen that we can improve the performance of the classifier.
#
# Finally we have seen an example of overtraining. Overtraining is generally a bad thing, but it makes it evident that the learning capability of the network is not limited by the choice of the hyperparameters or by its architecture, but rather on the limited amount of data used for the training.
#
# This is usually a good starting point to design and tune a powerful neural network capable of generalization.
