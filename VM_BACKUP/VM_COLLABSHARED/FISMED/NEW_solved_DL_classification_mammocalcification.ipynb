# %% [markdown]
# # Classification of lesions in Medical Physics
#
# The aim of this exercise is to create and train a simple Convolutional Neural Network (CNN) for deep-learning based classification of normal tissue vs. tissue cointaining microcalcification clusters in mammograms.
#
# Microcalcifications are tiny bright spots with diameter of few hundred microns, that are common findings in mammography. They appearance may be masked by the highly heterogenous breast tissue. While isolated microcalcifications are benign, when they occur grouped in clusters with suspicious morphology and distribution patterns, they are associated with the risk of malignancy.

# %% [markdown]
# Mammography (see the figure below) is a diagnostic imaging modality based on X-rays, with extremely high resolution. Typical pixel size nowadays is 50 microns or less.

# %% [markdown]
# ![cluster.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# We will build a CNN classifier capable to distinguish images containing small potions of normal tissue, form images containing micorcacification clusters. The image portions we will examine are slightly smaller than the rightmost picture in the figure above.
#
# If we set this classifier to scan sistematically  the whole mammogram, we would obtain an automated system for the detection and localization of microcalcification clusters.

# %% [markdown]
# ## Exercise objectives
#
# In this exercise you will learn how to:
#
#
# *   Load and visualize image data
# *   Define the CNN model
# *   Compile and train the CNN model on the training data
# *   Predict the labels of the validation/test data samples
# *   Calculate the classification accuracy
# *   Create the ROC curve and calculate the AUC
# *   Compare the performance of different models
#
#
# Additionally, if you have extra time now or when you get home, you will learn how to perform data augmentation.
#
# ## Remark
# The architecture of the CNN you will develop in this exercise can be trained on different kind of 2D images (with 1 color channel) even outside the medical imaging domain.

# %% [markdown]
# ## Description of the dataset
#
# The dataset we will use contains many image portions (60x60 pixels, corresponding to 5.1 mm x 5.1 mm) extracted from real mammograms, with radiological annotations, and converted into 8-bit grayscale images. These images may contain microcalcification clusters (label = 1) or normal breast tissue (label = 0).
#
# The available images are already partitioned in a train set and a test set, containing, respectively:
# - Train set (70% of the whole sample): 289 images with normal tissue and 267 images with microcalcification clusters;
# - Test set (30% of the whole sample): 125 images with normal tissue and 116 images with microcalcification clusters.
#
# The test set should always be left apart from the training procedure and used as an independent set to evaluate the classifier performance.

# %% [markdown]
# Examples of images containing microcalcalfication clusters:

# %% [markdown]
# ![micro.png](data:image/png;base64,...)

# %% [markdown]
# Examples of images representing normal breast tissue:

# %% [markdown]
# ![no_micro.png](data:image/png;base64,...)

# %% [markdown]
# #Importing the dataset

# %% [markdown]
# We download the zipped data archive from a webserver.

# %%
import os
if os.path.isfile('DL_class_data.tar.gz'):
    print ("File already exists... skipping download")
else:
    print ("Downloading File")
    # !wget https://www.pi.infn.it/~boccali/DL_class_data.tar.gz
# Out:
# File already exists... skipping download

# %% [markdown]
# Now let's extract the archive.
#
# NB: Using the special ```!``` charcter we can execute shell commands.

# %%
# !tar -xvf DL_class_data.tar.gz
# Out:
# README_micro.rtf
# Test/
# Test/0/
# Test/0/0036t1_4_0_1.png
# Test/0/0035p1_3_0_3.png
# Test/0/0035t1_2_0_4.png
# Test/0/0039n1_2_0_4.png
# Test/0/0038t1_1_0_3.png
# Test/0/0032t1_4_0_1.png
# Test/0/0033f1_4_0_4.png
# Test/0/0039p1_3_0_3.png
# Test/0/0032f1_4_0_1.png
# Test/0/0032p1_1_0_4.png
# Train/1/0289u1_6_1_1_5.png
# Train/1/0046u1_2_2_1_5.png
# Train/1/0078b1_1_1_1_1.png
# Train/1/0067b1_3_1_1_5.png
# Train/1/0091u1_1_2_1_5.png
# Train/1/0273n1_2_1_1_1.png
# Train/1/0077b1_3_1_1_5.png
# Train/1/0077b1_1_1_1_2.png
# Train/1/0041t1_2_1_1_1.png
# Train/1/0162p1_1_1_1_4.png
# Train/1/0116u1_3_1_1_5.png
# Train/1/0222u1_2_1_1_5.png
# Train/1/0042t1_1_1_1_5.png
# Train/1/0101u1_4_1_1_4.png
# Train/1/0088u1_1_1_1_3.png

# %% [markdown]
# We can show all files and folders in a certain path using ```ls```.

# %%
# !ls
# Out:
# DL_class_data.tar.gz	     model_augmented-42-0.87.h5
# model-01-0.43.h5	     model_augmented-43-0.78.h5
# model-01-0.51.h5	     model_augmented-43-0.79.h5
# model-01-0.58.h5	     model_augmented-43-0.85.h5
# model-01-0.59.h5	     model_augmented-43-0.87.h5
# model-01-0.86.h5	     model_augmented-44-0.79.h5
# model-02-0.66.h5	     model_augmented-44-0.80.h5
# model-02-0.67.h5	     model_augmented-44-0.85.h5
# model-02-0.72.h5	     model_augmented-44-0.86.h5
# model-02-0.73.h5	     model_augmented-45-0.80.h5
# model-03-0.70.h5	     model_augmented-45-0.84.h5
# model-03-0.73.h5	     model_augmented-45-0.85.h5
# model-03-0.88.h5	     model_augmented-45-0.86.h5
# model-04-0.73.h5	     model_augmented-46-0.80.h5
# model-106-0.80.h5	     model_augmented-46-0.84.h5
# model-118-0.81.h5	     model_augmented-46-0.85.h5
# model-129-0.82.h5	     model_augmented-46-0.87.h5
# model-14-0.76.h5	     model_augmented-47-0.81.h5
# model-16-0.77.h5	     model_augmented-47-0.82.h5
# model-21-0.78.h5	     model_augmented-47-0.84.h5
# model-23-0.79.h5	     model_augmented-47-0.87.h5
# model-24-0.81.h5	     model_augmented-48-0.79.h5
# model-33-0.81.h5	     model_augmented-48-0.81.h5
# model-35-0.82.h5	     model_augmented-48-0.84.h5
# model-36-0.84.h5	     model_augmented-48-0.86.h5
# model-46-0.85.h5	     model_augmented-49-0.82.h5
# model-54-0.71.h5	     model_augmented-49-0.84.h5
# model-54-0.83.h5	     model_augmented-49-0.85.h5
# model-54-0.86.h5	     model_augmented-50-0.79.h5
# model-55-0.71.h5	     model_augmented-50-0.80.h5
# model-56-0.72.h5	     model_augmented-50-0.82.h5
# model-57-0.73.h5	     model_augmented-50-0.85.h5
# model-59-0.74.h5	     model_augmented-51-0.79.h5
# model-60-0.86.h5	     model_augmented-51-0.83.h5
# model-61-0.74.h5	     model_augmented-51-0.85.h5
# model-61-0.76.h5	     model_augmented-52-0.80.h5
# model-61-0.89.h5	     model_augmented-52-0.84.h5
# model-62-0.77.h5	     model_augmented-52-0.86.h5
# model-64-0.75.h5	     model_augmented-52-0.87.h5
# model-64-0.78.h5	     model_augmented-53-0.80.h5
# model-66-0.79.h5	     model_augmented-53-0.84.h5
# model-67-0.80.h5	     model_augmented-53-0.85.h5
# model_augmented-11-0.53.h5   model_augmented-67-0.86.h5
# model_augmented-11-0.74.h5   model_augmented-68-0.82.h5
# model_augmented-11-0.75.h5   model_augmented-68-0.86.h5
# model_augmented-11-0.77.h5   model_augmented-68-0.87.h5
# model_augmented-12-0.47.h5   model_augmented-69-0.74.h5
# model_augmented-12-0.75.h5   model_augmented-69-0.83.h5
# model_augmented-12-0.78.h5   model_augmented-69-0.86.h5
# model_augmented-13-0.53.h5   model_augmented-69-0.87.h5
# model_augmented-13-0.76.h5   model_augmented-70-0.81.h5
# model_augmented-13-0.78.h5   model_augmented-70-0.82.h5
# model_augmented-14-0.73.h5   model_augmented-70-0.86.h5
# model_augmented-14-0.75.h5   model_augmented-70-0.87.h5
# model_augmented-14-0.76.h5   model_augmented-71-0.78.h5
# model_augmented-15-0.53.h5   model_augmented-71-0.82.h5
# model_augmented-15-0.66.h5   model_augmented-71-0.86.h5
# model_augmented-15-0.78.h5   model_augmented-71-0.87.h5
# model_augmented-15-0.81.h5   model_augmented-72-0.81.h5
# model_augmented-16-0.70.h5   model_augmented-72-0.82.h5
# model_augmented-16-0.71.h5   model_augmented-72-0.86.h5
# model_augmented-16-0.79.h5   model_augmented-72-0.87.h5
# model_augmented-16-0.82.h5   model_augmented-73-0.81.h5
# model_augmented-17-0.74.h5   model_augmented-73-0.82.h5
# model_augmented-17-0.76.h5   model_augmented-73-0.86.h5
# model_augmented-18-0.53.h5   model_augmented-73-0.87.h5
# model_augmented-18-0.71.h5   model_augmented-74-0.82.h5
# model_augmented-18-0.77.h5   model_augmented-74-0.83.h5
# model_augmented-18-0.80.h5   model_augmented-74-0.86.h5
# model_augmented-19-0.56.h5   model_augmented-74-0.87.h5
# model_augmented-19-0.64.h5   model_augmented-75-0.82.h5
# model_augmented-19-0.70.h5   model_augmented-75-0.83.h5
# model_augmented-19-0.72.h5   model_augmented-75-0.86.h5
# model_augmented-20-0.45.h5   model_augmented-75-0.87.h5
# model_augmented-20-0.73.h5   model_augmented-76-0.82.h5
# model_augmented-20-0.80.h5   model_augmented-76-0.86.h5
# model_augmented-20-0.81.h5   model_augmented-76-0.87.h5
# model_augmented-21-0.66.h5   model_augmented-77-0.82.h5
# model_augmented-21-0.73.h5   model_augmented-77-0.86.h5
# model_augmented-21-0.74.h5   model_augmented-77-0.87.h5
# model_augmented-21-0.84.h5   model_augmented-77-0.88.h5
# model_augmented-22-0.64.h5   model_augmented-78-0.82.h5
# model_augmented-22-0.69.h5   model_augmented-78-0.86.h5
# model_augmented-22-0.70.h5   model_augmented-78-0.87.h5
# model_augmented-22-0.76.h5   model_augmented-78-0.88.h5
# model_augmented-23-0.69.h5   model_augmented-79-0.82.h5
# model_augmented-23-0.73.h5   model_augmented-79-0.86.h5
# model_augmented-23-0.80.h5   model_augmented-79-0.87.h5
# model_augmented-23-0.81.h5   model_augmented-79-0.88.h5
# model_augmented-24-0.66.h5   model_augmented-80-0.82.h5
# model_augmented-24-0.68.h5   model_augmented-80-0.86.h5
# model_augmented-24-0.71.h5   model_augmented-80-0.87.h5
# model_augmented-24-0.78.h5   model_augmented-81-0.82.h5
# model_augmented-25-0.54.h5   model_augmented-81-0.86.h5
# model_augmented-25-0.80.h5   model_augmented-81-0.87.h5
# model_augmented-25-0.82.h5   model_augmented-81-0.88.h5
# model_augmented-25-0.83.h5   model_augmented-82-0.82.h5
# model_augmented-26-0.66.h5   model_augmented-82-0.86.h5
# model_augmented-26-0.68.h5   model_augmented-82-0.87.h5
# model_augmented-26-0.76.h5   model_augmented-83-0.82.h5
# model_augmented-26-0.81.h5   model_augmented-83-0.86.h5
# model_augmented-27-0.47.h5   model_augmented-83-0.87.h5
# model_augmented-27-0.76.h5   model_augmented-84-0.82.h5
# model_augmented-27-0.77.h5   model_augmented-84-0.86.h5
# model_augmented-27-0.86.h5   model_augmented-84-0.87.h5
# model_augmented-28-0.66.h5   model_augmented-85-0.83.h5
# model_augmented-28-0.75.h5   model_augmented-85-0.86.h5
# model_augmented-28-0.76.h5   model_augmented-85-0.87.h5
# model_augmented-28-0.80.h5   model_augmented-86-0.82.h5
# model_augmented-29-0.59.h5   model_augmented-86-0.86.h5
# model_augmented-29-0.65.h5   model_augmented-86-0.87.h5
# model_augmented-29-0.72.h5   model_augmented-87-0.82.h5
# model_augmented-29-0.78.h5   model_augmented-87-0.86.h5
# model_augmented-30-0.47.h5   model_augmented-87-0.87.h5
# model_augmented-30-0.60.h5   model_augmented-88-0.83.h5
# model_augmented-30-0.79.h5   model_augmented-88-0.85.h5
# model_augmented-30-0.87.h5   model_augmented-88-0.86.h5
# model_augmented-31-0.47.h5   model_augmented-88-0.87.h5
# model_augmented-31-0.76.h5   model_augmented-89-0.82.h5
# model_augmented-31-0.80.h5   model_augmented-89-0.86.h5
# model_augmented-31-0.84.h5   model_augmented-89-0.87.h5
# model_augmented-32-0.53.h5   model_augmented-90-0.83.h5
# model_augmented-32-0.76.h5   model_augmented-90-0.86.h5
# model_augmented-32-0.84.h5   model_augmented-90-0.87.h5
# model_augmented-32-0.87.h5   model_augmented-91-0.82.h5
# model_augmented-33-0.76.h5   model_augmented-91-0.86.h5
# model_augmented-33-0.78.h5   model_augmented-91-0.87.h5
# model_augmented-33-0.81.h5   model_augmented-92-0.82.h5
# model_augmented-33-0.84.h5   model_augmented-92-0.86.h5
# model_augmented-34-0.77.h5   model_augmented-92-0.87.h5
# model_augmented-34-0.80.h5   model_augmented-93-0.82.h5
# model_augmented-34-0.84.h5   model_augmented-93-0.86.h5
# model_augmented-35-0.67.h5   model_augmented-93-0.87.h5
# model_augmented-35-0.68.h5   model_augmented-94-0.82.h5
# model_augmented-35-0.80.h5   model_augmented-94-0.86.h5
# model_augmented-35-0.81.h5   model_augmented-94-0.87.h5
# model_augmented-36-0.75.h5   model_augmented-95-0.83.h5
# model_augmented-36-0.79.h5   model_augmented-95-0.86.h5
# model_augmented-36-0.80.h5   model_augmented-95-0.87.h5
# model_augmented-37-0.68.h5   model_augmented-96-0.82.h5
# model_augmented-37-0.77.h5   model_augmented-96-0.86.h5
# model_augmented-37-0.80.h5   model_augmented-96-0.87.h5
# model_augmented-38-0.71.h5   model_augmented-97-0.83.h5
# model_augmented-38-0.79.h5   model_augmented-97-0.86.h5
# model_augmented-38-0.80.h5   model_augmented-97-0.87.h5
# model_augmented-38-0.84.h5   model_augmented-98-0.83.h5
# model_augmented-39-0.77.h5   model_augmented-98-0.86.h5
# model_augmented-39-0.80.h5   model_augmented-98-0.87.h5
# model_augmented-39-0.84.h5   model_augmented-98-0.88.h5
# model_augmented-39-0.86.h5   model_augmented-99-0.82.h5
# model_augmented-40-0.76.h5   model_augmented-99-0.86.h5
# model_augmented-40-0.77.h5   model_augmented-99-0.87.h5
# model_augmented-40-0.86.h5   model_augmented-99-0.88.h5
# model_augmented-40-0.88.h5   model_augmented.h5
# model_augmented-41-0.78.h5   model.h5
# model_augmented-41-0.83.h5   model.png
# model_augmented-41-0.87.h5   README_micro.rtf
# model_augmented-42-0.79.h5   sample_data
# model_augmented-42-0.84.h5   Test
# model_augmented-42-0.85.h5   Train

# %%
# !ls Train/
# Out:
# 0  1

# %% [markdown]
# Each folder should have mammogram images containing microcalcifications (label=1) or normal breast tissue (label=0) put in different subfolders.

# %%
# !ls {Test,Train}
# Out:
# Test:
# 0  1
#
# Train:
# 0  1

# %% [markdown]
# Remember that microcalcification clusters have label=1 and  normal breast tissue label=0. \\
# The number of images for each folder should be as it follows:
# ```
# Train 0 files: 289
# Train 1 files: 267
# Test 0 files: 125
# Test 1 files: 116
# ```

# %% [markdown]
# You can check it with the following commands:

# %%
# !echo -n "Train 0 files: "; ls Train/0 | wc -l;
# !echo -n "Train 1 files: "; ls Train/1 | wc -l;
# !echo -n "Test 0 files: "; ls Test/0 | wc -l;
# !echo -n "Test 1 files: "; ls Test/1 | wc -l;
# Out:
# Train 0 files: 289
# Train 1 files: 267
# Test 0 files: 125
# Test 1 files: 116

# %% [markdown]
# You can print, for example, the filenames of the last three file  inside a folder, with the following instruction:

# %%
# !ls Train/1/ | tail -n 3
# Out:
# 0312u1_1_1_1_5.png
# 0313u1_1_1_1_5.png
# 0313u1_1_2_1_5.png

# %% [markdown]
# # Reading the images

# %% [markdown]
# We need to import some python packages (matplotlib, os, glob, numpy) and to install and import scikit-image to read and visualize images.

# %%
# !pip install scikit-image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.22.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.10.1)

# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import os
import glob
import numpy as np

# %% [markdown]
# Let us try to read an image with ```imread``` [[doc](https://scikit-image.org/docs/dev/api/skimage.io.html#skimage.io.imread)]. The output is a 2D array (since the image is in grayscale).
# We can view the image through the package ```imshow``` of matplotlib [[doc](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html)].

# %%
# !ls Train/1
# Out:
# 0006s1_1_1_1_1.png  0068b1_1_1_1_3.png	0085t1_4_1_1_4.png  0165u1_2_1_1_2.png
# 0006s1_1_1_1_3.png  0068b1_1_1_1_5.png	0085t1_4_1_1_5.png  0165u1_4_1_1_1.png
# 0006s1_1_1_1_4.png  0068b1_2_1_1_3.png	0085t1_4_2_1_2.png  0175u1_1_1_1_2.png
# 0006s1_1_1_1_5.png  0068b1_2_1_1_5.png	0085t1_4_2_1_3.png  0175u1_1_1_1_5.png
# 0046u1_3_2_1_2.png  0085n1_1_1_1_4.png	0161p1_3_1_1_4.png  0273u1_4_1_1_5.png
# 0046u1_3_3_1_5.png  0085n1_1_1_1_5.png	0161p1_3_2_1_3.png  0273u1_6_1_1_3.png
# 0046u1_4_1_1_5.png  0085n1_1_2_1_1.png	0161p1_3_2_1_5.png  0273u1_6_1_1_5.png
# 0046u1_4_2_1_1.png  0085n1_1_2_1_2.png	0161p1_3_3_1_4.png  0276n1_2_1_1_2.png
# 0067b1_2_1_1_1.png  0085n1_1_2_1_3.png	0161p1_3_3_1_5.png  0276n1_2_1_1_5.png
# 0067b1_2_1_1_2.png  0085n1_1_2_1_5.png	0161p1_4_1_1_1.png  0276n1_2_2_1_4.png
# 0067b1_2_1_1_4.png  0085n1_3_1_1_4.png	0161p1_4_1_1_3.png  0289u1_6_1_1_3.png
# 0067b1_2_1_1_5.png  0085n1_3_2_1_3.png	0161p1_4_1_1_5.png  0289u1_6_1_1_5.png
# 0067b1_3_1_1_3.png  0085n1_3_2_1_5.png	0162p1_1_1_1_4.png  0310u1_6_1_1_3.png
# 0067b1_3_1_1_5.png  0085n1_3_3_1_2.png	0162p1_2_1_1_1.png  0310u1_6_1_1_5.png
# 0067t1_1_2_1_4.png  0085t1_3_1_1_2.png	0162p1_2_1_1_2.png  0312u1_1_1_1_5.png
# 0067t1_2_1_1_4.png  0085t1_3_1_1_4.png	0162p1_2_1_1_3.png  0313u1_1_1_1_5.png
# 0068b1_1_1_1_1.png  0085t1_4_1_1_1.png	0162p1_2_1_1_4.png  0313u1_1_2_1_5.png
# 0068b1_1_1_1_2.png  0085t1_4_1_1_2.png	0162p1_2_1_1_5.png

# %%
#FILL HERE# Select an image from the list above and read it with imread
#sample_img = ...
sample_img = imread('Train/1/0162p1_2_1_1_1.png')

#FILL HERE# Print the shape of the numpy array
#print("Shape of array:",...)
print("Shape of array:", np.shape(sample_img))

#FILL HERE# Show the sample_img using plt.imshow. You can select an appropriate color map (cmap) fro radiological images.
#plt...
plt.imshow(sample_img, cmap='gray')
plt.colorbar()
# Out:
# Shape of array: (60, 60)

# %% [markdown]
# We can define a function to read images from a certain ```dataset_path``` and ```classes``` that matches the subfolders containing labeled images.
#
# The function uses the ```glob``` functions that finds all the pathnames that match a given pattern [[doc](https://docs.python.org/3/library/glob.html)].
# The images are read though the package ```imread``` [[doc](https://scikit-image.org/docs/dev/api/skimage.io.html#skimage.io.imread)]. This list of read images is populated with list comprehensions [[doc](https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions)].
#
# The last line converts the ```tmp``` list into a numpy array storing float32 data, adding an extra dimension with ```np.newaxis``` [[doc](https://numpy.org/doc/stable/reference/constants.html#numpy.newaxis)] (the three dots ```...``` are a special indexing symbol called ellipsis [[doc](https://docs.python.org/dev/library/constants.html#Ellipsis)])

# %%
def read_imgs(dataset_path, classes):
  tmp = []
  labels = []
  for cls in classes:
    # Returns all the images filenames contained in a certain folder
    fnames = glob.glob(os.path.join(dataset_path, str(cls), '*.png'))
    # Read, with a list comprehension, all the images listed before
    tmp += [ imread(fname) for fname in fnames ]
    # Populate the labels list with the label of the read image
    labels += len(fnames)*[cls]

  return np.array(tmp, dtype='float32')[..., np.newaxis]/255, np.array(labels)

# %% [markdown]
# We can use the ```read_imgs```
# function to read all images in the dataset and store them in a numpy array, and to generate the appropriate numpy arrays with the labels corresponding to each instance.

# %%
train_dataset_path = 'Train'
x_train, y_train = read_imgs(train_dataset_path, [0, 1])

test_dataset_path = 'Test'
x_test, y_test = read_imgs(test_dataset_path, [0, 1])

# %% [markdown]
# It is always a good idea to print the shape of the array in use to check it. \
# *x_train* is the array of the images, in our case the first dimension is the number of read images, the second and the third are the dimensions of each image, and the last one represents the color channel: (sample_dimension, image_width, image_height, color_channel).
# While *y_train* is the array containing the label of each image (0 or 1).

# %%
#FILL HERE# Print the shape of the train and test arrays and their labels
#print(...)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (556, 60, 60, 1) (556,)
# (241, 60, 60, 1) (241,)

# %% [markdown]
# Plot the first image in the dataset using the *imshow* function of *matplotlib.pyplot*

# %%
#We select the first image of the array (you can choose a different one)
img_1 = x_train[10].reshape(60,60)

#FILL HERE#-> Display the image using imshow.
#You can also choose an appropriate colormap (cmap)
#plt...
plt.imshow(img_1, cmap='gray')
plt.colorbar()

# %% [markdown]
# # Defining a CNN model

# %% [markdown]
# Convolutional neural networks (CNN) are a class of neural networks usually used to classify images.
# [[Ref1](https://www.asimovinstitute.org/neural-network-zoo/) ,
# [Ref2](https://www.freecodecamp.org/news/an-intuitive-guide-to-convolutional-neural-networks-260c2de0a050/)]
#
# ![dobVrh3SGyqQraM2ogi-P3VK2K-LFsBm7RLO.png](data:image/png;base64,...)
#
# [Ref3](https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5)

# %% [markdown]
# - In CNN, the nodes of the convolutional layers  are not connected to all nodes of previous layer. This is due to the high dimesionality of image data. For this reason we connect each node only to a local region of the input.
#
# - The nodes are called neurons or filter or kernel. The nodes/filters are convolved to the network layers and they slide through the whole image in order to cover all pixels.

# %% [markdown]
# ![1*0R11RGqX9mM-YdxNgZ0V6A.jpeg](data:image/jpeg;base64,...)
#
# - Pooling layers. Pooling is a way to downsample the image: a common pooling technique is the "max pooling". A max pooling layer takes, for example, a 2x2 submatrix and returns the pixel with the maximum value
# [[doc](https://keras.io/api/layers/pooling_layers/max_pooling2d/)].

# %% [markdown]
# The Keras library in Python makes it pretty simple to build a CNN.
#
# - Models on Keras can be defined in two ways: sequential and functional. In the Sequential model, you define the model using a plain stack of layers and each layer has exactly one input and one output. In the functional one, each layer is defined as a function which can take as input the output of the previous layer. It allows also to merge, add and concatenate more than input.
#
#
# - Convolution layer
# > - The first layer takes in an input shape. This is the shape of each input image.
# > - Number of nodes in each layer `(8,16,32) `
# > - Kernel size is the size of the filter matrix for our convolution. So a kernel size of 3 means we will have a 3x3 filter matrix.
# > - What is the effect of using "padding = same"?
#
#
# > - Activation is the activation function for the layer. (ReLU or Rectified Linear Activation has been proven to work well in neural networks)
#
# - 'Batch normalization' adds a ‘normalization layer’ after each convolutional layer. This allows the model to converge much faster in training and to generalize better.
#
# - ‘Dense’ is the layer we will use just before the output layer. It is a fully connected layer typical of a Multi Layer Perceptrons model.
#
# - The last layer contains 1 node and a different activation function called "sigmoid". The sigmoid returns a probability distribution in the range of 0 to 1 (it is not the only possible activation!!!). The "sigmoid" is a good choice for the last layer for several reasons: 1) it is differentiable and monotonic, 2) it is a "smooth" function, 3) it simply exists between 0 and 1. However, it has also three main drowbacks: it returns predictions that are not zero-centered and it is computationally expensive; the third disadvantage, which is the reason why it is used only in the last layer, is that it may cause the "vanishing gradient". Why it may cause the vanishing gradient? Why is there just 1 node in the last layer? Is it possible to use another number of nodes for this specific problem?
#
# \\
#
#
# To prevent over-fitting we will use dropout layers.
# Overfitting happens when your model fits too well to the training set. It then becomes difficult for the model to generalize.
# Dropout works by stochastically removing, or “dropping out,” some nodes.

# %% [markdown]
# You can built your the CNN model using either the [sequential](https://keras.io/guides/sequential_model/) or the [functional](https://keras.io/guides/functional_api/) Keras API
# ([Keras Sequential and Functional Models example](https://machinelearningmastery.com/keras-functional-api-deep-learning/))

# %%
#FILL HERE# Import the keras.models according to the API you prefer
#from keras.models import ...
from tensorflow.keras.models import Sequential


#FILL HERE# Import all layers which are needed to build your CNN
#from keras.layers import ...
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dense, Flatten, InputLayer, Activation, Dropout

# %% [markdown]
# Create a CNN with approximately the following structure:

# %%
#_________________________________________________________________
#Layer (type)                 Output Shape
#=================================================================
#conv2d (Conv2D)              (None, 60, 60, num_filters)
#_________________________________________________________________
#batch_normalization (BatchNo (None, 60, 60, num_filters)
#_________________________________________________________________
#activation (Activation)      (None, 60, 60, num_filters)
#_________________________________________________________________
#max_pooling2d (MaxPooling2D) (None, xxx, xxx, num_filters)

# …. ADD 3-4 BLOCKS AT MOST CONTAINING conv2d, batch_normalization, activation, max_pooling2d LAYERS

#flatten (Flatten)            (None, xxx)
#_________________________________________________________________
#dense (Dense)                (None, num_nodes)
#_________________________________________________________________
#dropout (Dropout)            (None, xxx)
#_________________________________________________________________
#dense_1 (Dense)              (None, num_nodes)
#=================================================================

# %% [markdown]
# You have to arbitrarily choose a number of free parameters to build your model. Check the Keras documentation for each type of [layer](https://keras.io/api/layers/).

# %%
#FILL HERE# Build you CNN

#Solution for sequential model (the best performing so far)
def make_model(shape=(60, 60, 1)):
  model = Sequential([

      Conv2D(8, (3,3), padding='same', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Conv2D(16, (3,3), padding='same'),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Conv2D(32, (3,3), padding='same'),
      BatchNormalization(),
      Activation('relu'),

      MaxPool2D((2,2), strides=2),
      #Dropout(0.4),

      Flatten(),    #Flatten serves as a connection between the convolution and dense layers.

      Dense(10, activation='relu'),
      Dropout(0.2),
      Dense(1, activation='sigmoid')

  ])
  return model

model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 8)         80
#
#  batch_normalization (BatchN  (None, 60, 60, 8)        32
#  ormalization)
#
#  activation (Activation)     (None, 60, 60, 8)         0
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 16)        1168
#
#  batch_normalization_1 (Batc  (None, 30, 30, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 30, 30, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 32)        4640
#
#  batch_normalization_2 (Batc  (None, 15, 15, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 15, 15, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 10)                15690
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21,813
# Trainable params: 21,701
# Non-trainable params: 112
# _________________________________________________________________

# %% [markdown]
# You can plot your model also with the [*plot_model*](https://keras.io/api/utils/model_plotting_utils/) function

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Next, we need to compile our model. Compiling the model takes three parameters: optimizer, loss and metrics.
# - The loss function ‘binary_crossentropy’ is the most common choice for classification and represents the function we want to minimize.
# - The optimizer is the algorithm procedure for minimizing the loss. A pivotal parameter of the optimizer is the learning rate which is the step size made by the loss function towards its minimum.\
# Several optimizers are available in keras, for example SGD and ADAM [[doc](https://keras.io/api/optimizers/)]. You can try to compare them.
#
# - We will use the ‘accuracy’ metric to measure the model classification performance on both the validation set (during training) and the test set.

# %%
#FILL HERE# You have to choose the optimizer, loss function and evaluation metrics, and to compile the model
#from keras.optimizers import ...
#model.compile(...)
from tensorflow.keras.optimizers import SGD #stochastic gradient descent
learning_rate = 0.001
model.compile(optimizer=SGD(learning_rate, momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Defining the Training, Validation and Independent Test sets
#
# When we load the data, we defined the *Train* and *Test* sets as a fixed split of our entire sample.
# We will leave the *Test* apart form the model training and use it at the end of the exercise to provide our *best classification result* on this *Independent Test set*. We can compare this result for example with those achieved by the other Hackathon groups.
#
# We will use only the *Train* set during the model training. However, before we start to train our CNN model, we have to define a further split of the *Train* set into a *train* (again!) and a *validation* set. \
# During the model training phase, the model parameters are estimated on the *train* set and the model is evaluated on the *validation* set.\
# By comparing the performance that different models obtain on the *validation* set, we can select the best model to finally evaluate on the *Independent Test* set.
#
# We can for example assign the 90% of the sample to the *train* and the 10% to the *validation* set.
#
#
# To split the *Train* set into the *train* and *validation* sets we can use the *train_test_split* function of *sklearn.model_selection* to carry out this task. *train_test_split* splits data arrays into two subsets. By default,it will make random partitions for the two subsets [[doc](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)].

# %% [markdown]
# Rndom state :

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=5)
# we can specify a random_state to mantain the train_test_split fixed in order to compare different model we bouild on the same validation set
#FILL HERE# Print the shape of train and validation arrays
#print(...)
#print(...)
print(np.shape(X_train), np.shape(Y_train))
print(np.shape(X_val), np.shape(Y_val))
# Out:
# (444, 60, 60, 1) (444,)
# (112, 60, 60, 1) (112,)

# %% [markdown]
# #Training the model

# %% [markdown]
# During the model training we can use a callback.\
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
# [[doc](https://keras.io/api/callbacks/)]. \
# In this exercise, we will use the *ReduceLROnPlateau* to reduce the learning rate during the training. In general, in fact, training a neural network means to search for the minimum of the loss functions changing a high number of parameters. It may happen that, after a certain number of epochs, the loss function can not decrease anymore since it has reached a local minumum. The loss function (as well as the metric/accuracy) hence reaches a plateau. In order to let the loss function further decrease, we can decrease the learning rate: the step made by the loss function is, then, smaller and it is possibile to find a minimum, improving the network performance.\
# One of the most used callbacks is the "ModelCheckpoint" one. It allows to save the model during the training and you can choose the conditions under which it works. To make this exercise simpler, you will not use it but we want to underline that often it is mandatory.

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
checkpoint = ModelCheckpoint(
    "model-{epoch:02d}-{val_accuracy:.2f}.h5",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='auto', save_freq='epoch')

reduce_on_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=10,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0)

# %% [markdown]
# To train the model, we will use the ‘fit()’ function with the following parameters: training data (x_tain), target data (y_train), validation data, and the number of epochs.\
# "fit()" will train the model by dividing the data into "batch", and repeatedly iterating over the entire data set for a given number of epochs [[doc](https://keras.io/api/models/model_training_apis/)]. A batch is a small subsample of data and its introduction allows a better generalization. It also reduces the training time because the network parameters are updatated for each batch instead of updating them for each image.

# %%
#FILL HERE#
#epochs= #FILL HERE# # You can start from 50-100, then try to augment
#batch_size = 32 #32 is a good starting point, if you want, try other numbers: 64, 128
#history = model.fit( ...
#                    batch_size=...
#                    epochs=...
#                    step_per_epoch=...
#                    validation_data=(X_val, Y_val),
#                    validation_steps=np.shape(X_val)[0]/batch_size,
#                    callbacks=[checkpoint,reduce_on_plateau]
#                    )
epochs= 150 # 300 is ok
batch_size = 64
history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    #steps_per_epoch = np.shape(X_train)[0]/batch_size,
                    verbose=1,
                    validation_data=(X_val, Y_val),
                    #validation_steps=np.shape(X_val)[0]/batch_size,
                    callbacks=[checkpoint, reduce_on_plateau]
                    )
# Out:
# Epoch 1/150
# 7/7 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 0.5721
# Epoch 1: val_accuracy improved from -inf to 0.58929, saving model to model-01-0.59.h5
# 7/7 [==============================] - 5s 122ms/step - loss: 0.6747 - accuracy: 0.5721 - val_loss: 0.6908 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 2/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.6517 - accuracy: 0.5938
# Epoch 2: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6133 - accuracy: 0.6577 - val_loss: 0.6853 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 3/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5311 - accuracy: 0.6875
# Epoch 3: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5770 - accuracy: 0.6869 - val_loss: 0.6825 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 4/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.6388 - accuracy: 0.5938
# Epoch 4: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5693 - accuracy: 0.7072 - val_loss: 0.6824 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 5/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5999 - accuracy: 0.6562
# Epoch 5: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5393 - accuracy: 0.7027 - val_loss: 0.6813 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 6/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.6214 - accuracy: 0.5312
# Epoch 6: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5415 - accuracy: 0.7162 - val_loss: 0.6808 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 7/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5504 - accuracy: 0.7188
# Epoch 7: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5268 - accuracy: 0.7275 - val_loss: 0.6814 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 8/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5737 - accuracy: 0.6875
# Epoch 8: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5149 - accuracy: 0.7252 - val_loss: 0.6816 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 9/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4755 - accuracy: 0.8125
# Epoch 9: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.5271 - accuracy: 0.7432 - val_loss: 0.6813 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 10/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4627 - accuracy: 0.7812
# Epoch 10: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5162 - accuracy: 0.7410 - val_loss: 0.6809 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 11/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4991 - accuracy: 0.7656
# Epoch 11: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.5235 - accuracy: 0.7342 - val_loss: 0.6811 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 12/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5232 - accuracy: 0.6875
# Epoch 12: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4936 - accuracy: 0.7658 - val_loss: 0.6805 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 13/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5147 - accuracy: 0.7812
# Epoch 13: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5013 - accuracy: 0.7410 - val_loss: 0.6790 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 14/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4121 - accuracy: 0.8594
# Epoch 14: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4731 - accuracy: 0.7568 - val_loss: 0.6786 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 15/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4697 - accuracy: 0.7656
# Epoch 15: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4797 - accuracy: 0.7793 - val_loss: 0.6777 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 16/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4253 - accuracy: 0.7500
# Epoch 16: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4753 - accuracy: 0.7658 - val_loss: 0.6769 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 17/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4962 - accuracy: 0.6875
# Epoch 17: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4837 - accuracy: 0.7883 - val_loss: 0.6767 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 18/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4922 - accuracy: 0.7969
# Epoch 18: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4633 - accuracy: 0.7770 - val_loss: 0.6758 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 19/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.4592 - accuracy: 0.7969
# Epoch 19: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4413 - accuracy: 0.7973 - val_loss: 0.6753 - val_accuracy: 0.5893 - lr: 0.0010
# Epoch 20/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.5185 - accuracy: 0.7656
# Epoch 20: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 12ms/step - loss: 0.
[==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8941
# Epoch 46: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 19ms/step - loss: 0.3011 - accuracy: 0.8941 - val_loss: 0.6626 - val_accuracy: 0.5804 - lr: 1.0000e-04
# Epoch 47/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2445 - accuracy: 0.8906
# Epoch 47: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 19ms/step - loss: 0.3005 - accuracy: 0.8941 - val_loss: 0.6627 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 48/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2933 - accuracy: 0.8784
# Epoch 48: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2933 - accuracy: 0.8784 - val_loss: 0.6616 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 49/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.8806
# Epoch 49: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2871 - accuracy: 0.8806 - val_loss: 0.6621 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 50/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8941
# Epoch 50: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 23ms/step - loss: 0.2889 - accuracy: 0.8941 - val_loss: 0.6635 - val_accuracy: 0.5536 - lr: 1.0000e-04
# Epoch 51/150
# 7/7 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8649
# Epoch 51: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3155 - accuracy: 0.8649 - val_loss: 0.6651 - val_accuracy: 0.5446 - lr: 1.0000e-04
# Epoch 52/150
# 7/7 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 0.8896
# Epoch 52: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3045 - accuracy: 0.8896 - val_loss: 0.6683 - val_accuracy: 0.5268 - lr: 1.0000e-04
# Epoch 53/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2598 - accuracy: 0.9193
# Epoch 53: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 25ms/step - loss: 0.2712 - accuracy: 0.9054 - val_loss: 0.6675 - val_accuracy: 0.5268 - lr: 1.0000e-04
# Epoch 54/150
# 4/7 [================>.............] - ETA: 0s - loss: 0.2839 - accuracy: 0.8984
# Epoch 54: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2803 - accuracy: 0.9009 - val_loss: 0.6658 - val_accuracy: 0.5446 - lr: 1.0000e-04
# Epoch 55/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2741 - accuracy: 0.8969
# Epoch 55: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 34ms/step - loss: 0.2759 - accuracy: 0.8874 - val_loss: 0.6690 - val_accuracy: 0.5446 - lr: 1.0000e-04
# Epoch 56/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.3131 - accuracy: 0.8594
# Epoch 56: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 34ms/step - loss: 0.2993 - accuracy: 0.8761 - val_loss: 0.6772 - val_accuracy: 0.5446 - lr: 1.0000e-04
# Epoch 57/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3056 - accuracy: 0.8750
# Epoch 57: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 24ms/step - loss: 0.3000 - accuracy: 0.8784 - val_loss: 0.6773 - val_accuracy: 0.5357 - lr: 1.0000e-04
# Epoch 58/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.8964
# Epoch 58: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2894 - accuracy: 0.8964 - val_loss: 0.6658 - val_accuracy: 0.5268 - lr: 1.0000e-04
# Epoch 59/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2803 - accuracy: 0.8854
# Epoch 59: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2851 - accuracy: 0.8806 - val_loss: 0.6648 - val_accuracy: 0.5268 - lr: 1.0000e-05
# Epoch 60/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.8874
# Epoch 60: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2983 - accuracy: 0.8874 - val_loss: 0.6655 - val_accuracy: 0.5357 - lr: 1.0000e-05
# Epoch 61/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2757 - accuracy: 0.9062
# Epoch 61: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2822 - accuracy: 0.9009 - val_loss: 0.6670 - val_accuracy: 0.5357 - lr: 1.0000e-05
# Epoch 62/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2723 - accuracy: 0.9375
# Epoch 62: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2761 - accuracy: 0.9032 - val_loss: 0.6667 - val_accuracy: 0.5446 - lr: 1.0000e-05
# Epoch 63/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2951 - accuracy: 0.8906
# Epoch 63: val_accuracy did not improve from 0.58929
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2591 - accuracy: 0.9077 - val_loss: 0.6635 - val_accuracy: 0.5804 - lr: 1.0000e-05
# Epoch 64/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2363 - accuracy: 0.9062
# Epoch 64: val_accuracy improved from 0.58929 to 0.59821, saving model to model-64-0.60.h5
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2635 - accuracy: 0.9167 - val_loss: 0.6595 - val_accuracy: 0.5982 - lr: 1.0000e-05
# Epoch 65/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2570 - accuracy: 0.8906
# Epoch 65: val_accuracy improved from 0.59821 to 0.62500, saving model to model-65-0.62.h5
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2757 - accuracy: 0.9032 - val_loss: 0.6544 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 66/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.3388 - accuracy: 0.8438
# Epoch 66: val_accuracy improved from 0.62500 to 0.66071, saving model to model-66-0.66.h5
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2652 - accuracy: 0.9144 - val_loss: 0.6476 - val_accuracy: 0.6607 - lr: 1.0000e-05
# Epoch 67/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.3004 - accuracy: 0.9062
# Epoch 67: val_accuracy improved from 0.66071 to 0.66964, saving model to model-67-0.67.h5
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2900 - accuracy: 0.9122 - val_loss: 0.6434 - val_accuracy: 0.6696 - lr: 1.0000e-05
# Epoch 68/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2154 - accuracy: 0.9688
# Epoch 68: val_accuracy did not improve from 0.66964
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2779 - accuracy: 0.9054 - val_loss: 0.6365 - val_accuracy: 0.6696 - lr: 1.0000e-05
# Epoch 69/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2852 - accuracy: 0.9219
# Epoch 69: val_accuracy did not improve from 0.66964
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2707 - accuracy: 0.9099 - val_loss: 0.6317 - val_accuracy: 0.6607 - lr: 1.0000e-05
# Epoch 70/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.3677 - accuracy: 0.8438
# Epoch 70: val_accuracy did not improve from 0.66964
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2963 - accuracy: 0.8851 - val_loss: 0.6253 - val_accuracy: 0.6607 - lr: 1.0000e-05
# Epoch 71/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.9099
# Epoch 71: val_accuracy did not improve from 0.66964
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2728 - accuracy: 0.9099 - val_loss: 0.6208 - val_accuracy: 0.6607 - lr: 1.0000e-05
# Epoch 72/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2407 - accuracy: 0.9219
# Epoch 72: val_accuracy did not improve from 0.66964
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2870 - accuracy: 0.8739 - val_loss: 0.6141 - val_accuracy: 0.6607 - lr: 1.0000e-05
# Epoch 73/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2109 - accuracy: 0.9062
# Epoch 73: val_accuracy improved from 0.66964 to 0.67857, saving model to model-73-0.68.h5
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2743 - accuracy: 0.9099 - val_loss: 0.6036 - val_accuracy: 0.6786 - lr: 1.0000e-05
# Epoch 74/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2916 - accuracy: 0.8958
# Epoch 74: val_accuracy improved from 0.67857 to 0.69643, saving model to model-74-0.70.h5
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2803 - accuracy: 0.9077 - val_loss: 0.5941 - val_accuracy: 0.6964 - lr: 1.0000e-05
# Epoch 75/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8896
# Epoch 75: val_accuracy improved from 0.69643 to 0.70536, saving model to model-75-0.71.h5
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2946 - accuracy: 0.8896 - val_loss: 0.5869 - val_accuracy: 0.7054 - lr: 1.0000e-05
# Epoch 76/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2952 - accuracy: 0.8844
# Epoch 76: val_accuracy did not improve from 0.70536
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2860 - accuracy: 0.8896 - val_loss: 0.5775 - val_accuracy: 0.7054 - lr: 1.0000e-05
# Epoch 77/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.3059 - accuracy: 0.8938
# Epoch 77: val_accuracy improved from 0.70536 to 0.72321, saving model to model-77-0.72.h5
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2982 - accuracy: 0.8919 - val_loss: 0.5700 - val_accuracy: 0.7232 - lr: 1.0000e-05
# Epoch 78/150
# 4/7 [================>.............] - ETA: 0s - loss: 0.2589 - accuracy: 0.9180
# Epoch 78: val_accuracy improved from 0.72321 to 0.73214, saving model to model-78-0.73.h5
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2728 - accuracy: 0.9032 - val_loss: 0.5629 - val_accuracy: 0.7321 - lr: 1.0000e-05
# Epoch 79/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2759 - accuracy: 0.8984
# Epoch 79: val_accuracy did not improve from 0.73214
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2883 - accuracy: 0.8874 - val_loss: 0.5553 - val_accuracy: 0.7321 - lr: 1.0000e-05
# Epoch 80/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2843 - accuracy: 0.9062
# Epoch 80: val_accuracy improved from 0.73214 to 0.74107, saving model to model-80-0.74.h5
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2862 - accuracy: 0.9054 - val_loss: 0.5424 - val_accuracy: 0.7411 - lr: 1.0000e-05
# Epoch 81/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.8986
# Epoch 81: val_accuracy did not improve from 0.74107
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2850 - accuracy: 0.8986 - val_loss: 0.5268 - val_accuracy: 0.7321 - lr: 1.0000e-05
# Epoch 82/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.3280 - accuracy: 0.8656
# Epoch 82: val_accuracy improved from 0.74107 to 0.75000, saving model to model-82-0.75.h5
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3194 - accuracy: 0.8716 - val_loss: 0.5090 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 83/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9099
# Epoch 83: val_accuracy did not improve from 0.75000
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2762 - accuracy: 0.9099 - val_loss: 0.4950 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 84/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2879 - accuracy: 0.9125
# Epoch 84: val_accuracy improved from 0.75000 to 0.76786, saving model to model-84-0.77.h5
# 7/7 [==============================] - 0s 36ms/step - loss: 0.2770 - accuracy: 0.9189 - val_loss: 0.4778 - val_accuracy: 0.7679 - lr: 1.0000e-05
# Epoch 85/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.9032
# Epoch 85: val_accuracy improved from 0.76786 to 0.79464, saving model to model-85-0.79.h5
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2838 - accuracy: 0.9032 - val_loss: 0.4627 - val_accuracy: 0.7946 - lr: 1.0000e-05
# Epoch 86/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2762 - accuracy: 0.8844
# Epoch 86: val_accuracy improved from 0.79464 to 0.80357, saving model to model-86-0.80.h5
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2803 - accuracy: 0.8851 - val_loss: 0.4530 - val_accuracy: 0.8036 - lr: 1.0000e-05
# Epoch 87/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2666 - accuracy: 0.8984
# Epoch 87: val_accuracy did not improve from 0.80357
# 7/7 [==============================] - 0s 23ms/step - loss: 0.2656 - accuracy: 0.9032 - val_loss: 0.4480 - val_accuracy: 0.8036 - lr: 1.0000e-05
# Epoch 88/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.3188 - accuracy: 0.8687
# Epoch 88: val_accuracy did not improve from 0.80357
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2957 - accuracy: 0.8784 - val_loss: 0.4371 - val_accuracy: 0.7946 - lr: 1.0000e-05
# Epoch 89/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2745 - accuracy: 0.9094
# Epoch 89: val_accuracy did not improve from 0.80357
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2883 - accuracy: 0.9054 - val_loss: 0.4273 - val_accuracy: 0.7946 - lr: 1.0000e-05
# Epoch 90/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2884 - accuracy: 0.8969
# Epoch 90: val_accuracy did not improve from 0.80357
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2840 - accuracy: 0.8851 - val_loss: 0.4124 - val_accuracy: 0.7946 - lr: 1.0000e-05
# Epoch 91/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9099
# Epoch 91: val_accuracy did not improve from 0.80357
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2628 - accuracy: 0.9099 - val_loss: 0.4018 - val_accuracy: 0.8036 - lr: 1.0000e-05
# Epoch 92/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8851
# Epoch 92: val_accuracy improved from 0.80357 to 0.81250, saving model to model-92-0.81.h5
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2856 - accuracy: 0.8851 - val_loss: 0.3972 - val_accuracy: 0.8125 - lr: 1.0000e-05
# Epoch 93/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2769 - accuracy: 0.8969
# Epoch 93: val_accuracy did not improve from 0.81250
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2752 - accuracy: 0.8964 - val_loss: 0.3968 - val_accuracy: 0.7946 - lr: 1.0000e-05
# Epoch 94/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2915 - accuracy: 0.8906
# Epoch 94: val_accuracy did not improve from 0.81250
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2881 - accuracy: 0.8919 - val_loss: 0.3960 - val_accuracy: 0.7946 - lr: 1.0000e-05
# Epoch 95/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2616 - accuracy: 0.9062
# Epoch 95: val_accuracy did not improve from 0.81250
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2625 - accuracy: 0.9054 - val_loss: 0.3924 - val_accuracy: 0.8036 - lr: 1.0000e-05
# Epoch 96/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.9054
# Epoch 96: val_accuracy improved from 0.81250 to 0.82143, saving model to model-96-0.82.h5
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2636 - accuracy: 0.9054 - val_loss: 0.3824 - val_accuracy: 0.8214 - lr: 1.0000e-05
# Epoch 97/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2948 - accuracy: 0.9010
# Epoch 97: val_accuracy improved from 0.82143 to 0.83036, saving model to model-97-0.83.h5
# 7/7 [==============================] - 0s 42ms/step - loss: 0.2886 - accuracy: 0.9054 - val_loss: 0.3730 - val_accuracy: 0.8304 - lr: 1.0000e-05
# Epoch 98/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2850 - accuracy: 0.8958
# Epoch 98: val_accuracy did not improve from 0.83036
# 7/7 [==============================] - 0s 25ms/step - loss: 0.2942 - accuracy: 0.8896 - val_loss: 0.3681 - val_accuracy: 0.8304 - lr: 1.0000e-05
# Epoch 99/150
# 7/7 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9167
# Epoch 99: val_accuracy improved from 0.83036 to 0.83929, saving model to model-99-0.84.h5
# 7/7 [==============================] - 0s 49ms/step - loss: 0.2611 - accuracy: 0.9167 - val_loss: 0.3595 - val_accuracy: 0.8393 - lr: 1.0000e-05
# Epoch 100/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2783 - accuracy: 0.8932
# Epoch 100: val_accuracy did not improve from 0.83929
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2820 - accuracy: 0.8964 - val_loss: 0.3545 - val_accuracy: 0.8304 - lr: 1.0000e-05
# Epoch 101/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2626 - accuracy: 0.8958
# Epoch 101: val_accuracy improved from 0.83929 to 0.84821, saving model to model-101-0.85.h5
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2609 - accuracy: 0.8964 - val_loss: 0.3495 - val_accuracy: 0.8482 - lr: 1.0000e-05
# Epoch 102/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2770 - accuracy: 0.9062
# Epoch 102: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2770 - accuracy: 0.9099 - val_loss: 0.3474 - val_accuracy: 0.8482 - lr: 1.0000e-05
# Epoch 103/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2608 - accuracy: 0.9062
# Epoch 103: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2635 - accuracy: 0.9032 - val_loss: 0.3445 - val_accuracy: 0.8393 - lr: 1.0000e-05
# Epoch 104/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2885 - accuracy: 0.8828
# Epoch 104: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 23ms/step - loss: 0.2858 - accuracy: 0.8829 - val_loss: 0.3399 - val_accuracy: 0.8393 - lr: 1.0000e-05
# Epoch 105/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2516 - accuracy: 0.9167
# Epoch 105: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 23ms/step - loss: 0.2602 - accuracy: 0.9054 - val_loss: 0.3380 - val_accuracy: 0.8393 - lr: 1.0000e-05
# Epoch 106/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2962 - accuracy: 0.8969
# Epoch 106: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2938 - accuracy: 0.8896 - val_loss: 0.3380 - val_accuracy: 0.8304 - lr: 1.0000e-05
# Epoch 107/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2766 - accuracy: 0.9036
# Epoch 107: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2782 - accuracy: 0.9009 - val_loss: 0.3367 - val_accuracy: 0.8393 - lr: 1.0000e-05
# Epoch 108/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2459 - accuracy: 0.9250
# Epoch 108: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 43ms/step - loss: 0.2666 - accuracy: 0.9077 - val_loss: 0.3300 - val_accuracy: 0.8393 - lr: 1.0000e-05
# Epoch 109/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2538 - accuracy: 0.9167
# Epoch 109: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 34ms/step - loss: 0.
val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2842 - accuracy: 0.9032 - val_loss: 0.3225 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 133/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2924 - accuracy: 0.8813
# Epoch 133: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2718 - accuracy: 0.9009 - val_loss: 0.3222 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 134/150
# 4/7 [================>.............] - ETA: 0s - loss: 0.2421 - accuracy: 0.9297
# Epoch 134: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2657 - accuracy: 0.9122 - val_loss: 0.3217 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 135/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2805 - accuracy: 0.8844
# Epoch 135: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2696 - accuracy: 0.9009 - val_loss: 0.3214 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 136/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2697 - accuracy: 0.8932
# Epoch 136: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2689 - accuracy: 0.8964 - val_loss: 0.3208 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 137/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2782 - accuracy: 0.8781
# Epoch 137: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2744 - accuracy: 0.8851 - val_loss: 0.3206 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 138/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2778 - accuracy: 0.9089
# Epoch 138: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2685 - accuracy: 0.9167 - val_loss: 0.3205 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 139/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2868 - accuracy: 0.8906
# Epoch 139: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2794 - accuracy: 0.8941 - val_loss: 0.3203 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 140/150
# 4/7 [================>.............] - ETA: 0s - loss: 0.2775 - accuracy: 0.9062
# Epoch 140: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2742 - accuracy: 0.9077 - val_loss: 0.3201 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 141/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2922 - accuracy: 0.8969
# Epoch 141: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3079 - accuracy: 0.8829 - val_loss: 0.3201 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 142/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2765 - accuracy: 0.9115
# Epoch 142: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2711 - accuracy: 0.9144 - val_loss: 0.3200 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 143/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2896 - accuracy: 0.8906
# Epoch 143: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2821 - accuracy: 0.8919 - val_loss: 0.3199 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 144/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2928 - accuracy: 0.8750
# Epoch 144: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2938 - accuracy: 0.8761 - val_loss: 0.3199 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 145/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2719 - accuracy: 0.8938
# Epoch 145: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2811 - accuracy: 0.8919 - val_loss: 0.3199 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 146/150
# 5/7 [====================>.........] - ETA: 0s - loss: 0.2908 - accuracy: 0.8813
# Epoch 146: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 21ms/step - loss: 0.2901 - accuracy: 0.8829 - val_loss: 0.3200 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 147/150
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2812 - accuracy: 0.9115
# Epoch 147: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2802 - accuracy: 0.9099 - val_loss: 0.3199 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 148/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2318 - accuracy: 0.9219
# Epoch 148: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2782 - accuracy: 0.8941 - val_loss: 0.3200 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 149/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2586 - accuracy: 0.9062
# Epoch 149: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2829 - accuracy: 0.8896 - val_loss: 0.3198 - val_accuracy: 0.8304 - lr: 1.0000e-06
# Epoch 150/150
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2328 - accuracy: 0.9219
# Epoch 150: val_accuracy did not improve from 0.84821
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2650 - accuracy: 0.9032 - val_loss: 0.3197 - val_accuracy: 0.8304 - lr: 1.0000e-06

# %% [markdown]
# # Visualize the model training history

# %% [markdown]
# Plot accuracy and loss curves on the *train* and *validation* sets over the training epochs [docs](https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/).

# %%
#FILL HERE#
#acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']
#loss = history.history['loss']
#val_loss = history.history['val_loss']

#epochs_range = range(1, len(acc)+1)
#Train and validation accuracy
#plt.figure(figsize=(15, 15))
#plt.subplot(2, 2, 1)
#plt.plot(..
#plt.plot(..
#Train and validation loss
#plt.subplot(2, 2, 2)
#plt.plot(..
#plt.plot(..


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Evaluate the network performance on **validation** data.
# Keras model provides a function that evaluate the model on new datasets. It has three main arguments: data, data label, verbose (true or false)[[doc](https://keras.io/api/models/model_training_apis/)].

# %%
#FILL HERE# Evaluate the model on the validation set and print the accuracy value achieved
#_, val_acc = model.evaluate(...
#print(...
_, val_acc = model.evaluate(X_val, Y_val, verbose=0)
print('Validation accuracy: %.3f' % (val_acc))
# Out:
# Validation accuracy: 0.830

# %% [markdown]
# # ROC curve
# Create the ROC curve [[doc](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)] and compute the Area Under the Curve AUC (the false-positive rate and the true-positive rate) [[doc](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.auc.html)]. \\
# [Receiver Operating Characteristic (ROC)](https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py). \
# ROC curve is typically used in binary classification to depict the trade-off between the system sensitivity and the rate of false-positive detections of the output of a classifier obtained by varing the decision threshold. The AUC value is a useful global number to compare the performance of different classifiers.

# %%
from sklearn.metrics import roc_curve, auc
preds = model.predict(X_val, verbose=1)

#Compute Receiver operating characteristic (ROC)
fpr, tpr, _ = roc_curve(Y_val, preds)

roc_auc = auc(fpr, tpr)
#Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %% [markdown]
# Now that you have evaluated the classification performance in terms of AUC on the *validation* set you could:
# *   Try and evaluate different CNN architectures or different setting of free parameters and compare the performance achieved on the same validation set (the same validation set is obtained by explicitating a specific random_state in the *train_test_split* function)
# *   Otherwise, if you have already obtained quite stisfactory performance (e.g. AUC > 90%), you could run the training al least 5 times to evaluate the average and standard deviation on AUC induced by the sample variability (i.e. once the fixed random_state option is removed from the *train_test_split* function).
# *   When you are satisfied with your classification performance, you can choose your best model and move to next section and to evaluate it on the independent *Test* set.

# %% [markdown]
# #Saving the model

# %% [markdown]
# You can save a model you like to reuse it later on:

# %%
model.save('model.h5') # it just saves the model at the last epoch
#You can rename it by using shell command, e.g. !cp model.h5 model-random_state-24.h5

# %%
# !ls
# Out:
# DL_class_data.tar.gz	     model_augmented-40-0.77.h5
# model-01-0.43.h5	     model_augmented-40-0.86.h5
# model-01-0.51.h5	     model_augmented-40-0.88.h5
# model-01-0.58.h5	     model_augmented-41-0.78.h5
# model-01-0.59.h5	     model_augmented-41-0.83.h5
# model-01-0.86.h5	     model_augmented-41-0.87.h5
# model-02-0.66.h5	     model_augmented-42-0.79.h5
# model-02-0.67.h5	     model_augmented-42-0.84.h5
# model-02-0.72.h5	     model_augmented-42-0.85.h5
# model-02-0.73.h5	     model_augmented-42-0.87.h5
# model-03-0.70.h5	     model_augmented-43-0.78.h5
# model-03-0.73.h5	     model_augmented-43-0.79.h5
# model-03-0.88.h5	     model_augmented-43-0.85.h5
# model-04-0.73.h5	     model_augmented-43-0.87.h5
# model-101-0.85.h5	     model_augmented-44-0.79.h5
# model-106-0.80.h5	     model_augmented-44-0.80.h5
# model-118-0.81.h5	     model_augmented-44-0.85.h5
# model-129-0.82.h5	     model_augmented-44-0.86.h5
# model-14-0.76.h5	     model_augmented-45-0.80.h5
# model-16-0.77.h5	     model_augmented-45-0.84.h5
# model-21-0.78.h5	     model_augmented-45-0.85.h5
# model-23-0.79.h5	     model_augmented-45-0.86.h5
# model-24-0.81.h5	     model_augmented-46-0.80.h5
# model-33-0.81.h5	     model_augmented-46-0.84.h5
# model-35-0.82.h5	     model_augmented-46-0.85.h5
# model-36-0.84.h5	     model_augmented-46-0.87.h5
# model-46-0.85.h5	     model_augmented-47-0.81.h5
# model-54-0.71.h5	     model_augmented-47-0.82.h5
# model-54-0.83.h5	     model_augmented-47-0.84.h5
# model-54-0.86.h5	     model_augmented-47-0.87.h5
# model-55-0.71.h5	     model_augmented-48-0.79.h5
# model-56-0.72.h5	     model_augmented-48-0.81.h5
# model-57-0.73.h5	     model_augmented-48-0.84.h5
# model-59-0.74.h5	     model_augmented-48-0.86.h5
# model-60-0.86.h5	     model_augmented-49-0.82.h5
# model-61-0.74.h5	     model_augmented-49-0.84.h5
# model-61-0.76.h5	     model_augmented-49-0.85.h5
# model-61-0.89.h5	     model_augmented-50-0.79.h5
# model-62-0.77.h5	     model_augmented-50-0.80.h5
# model-64-0.60.h5	     model_augmented-50-0.82.h5
# model-64-0.75.h5	     model_augmented-50-0.85.h5
# model-64-0.78.h5	     model_augmented-51-0.79.h5
# model-65-0.62.h5	     model_augmented-51-0.83.h5
# model-66-0.66.h5	     model_augmented-51-0.85.h5
# model-66-0.79.h5	     model_augmented-52-0.80.h5
# model-67-0.67.h5	     model_augmented-52-0.84.h5
# model-67-0.80.h5	     model_augmented-52-0.86.h5
# model-68-0.76.h5	     model_augmented-52-0.87.h5
# model-68-0.89.h5	     model_augmented-53-0.80.h5
# model-70-0.82.h5	     model_augmented-53-0.84.h5
# model-72-0.83.h5	     model_augmented-53-0.85.h5
# model-73-0.68.h5	     model_augmented-54-0.83.h5
# model-74-0.70.h5	     model_augmented-54-0.84.h5
# model-75-0.71.h5	     model_augmented-54-0.86.h5
# model-76-0.77.h5	     model_augmented-54-0.87.h5
# model-77-0.72.h5	     model_augmented-55-0.76.h5
# model-78-0.73.h5	     model_augmented-55-0.83.h5
# model-79-0.83.h5	     model_augmented-55-0.86.h5
# model-80-0.74.h5	     model_augmented-56-0.79.h5
# model-80-0.78.h5	     model_augmented-56-0.83.h5
# model-82-0.75.h5	     model_augmented-56-0.86.h5
# model-84-0.77.h5	     model_augmented-56-0.87.h5
# model-85-0.79.h5	     model_augmented-57-0.81.h5
# model-86-0.80.h5	     model_augmented-57-0.83.h5
# model-87-0.79.h5	     model_augmented-57-0.86.h5
# model-92-0.81.h5	     model_augmented-57-0.87.h5
# model-96-0.82.h5	     model_augmented-58-0.76.h5
# model-97-0.83.h5	     model_augmented-58-0.82.h5
# model-99-0.84.h5	     model_augmented-58-0.85.h5
# model_augmented-01-0.53.h5   model_augmented-58-0.86.h5
# model_augmented-01-0.58.h5   model_augmented-59-0.77.h5
# model_augmented-01-0.69.h5   model_augmented-59-0.82.h5
# model_augmented-02-0.53.h5   model_augmented-59-0.86.h5
# model_augmented-02-0.68.h5   model_augmented-59-0.87.h5
# model_augmented-02-0.69.h5   model_augmented-60-0.79.h5
# model_augmented-02-0.70.h5   model_augmented-60-0.82.h5
# model_augmented-03-0.47.h5   model_augmented-60-0.86.h5
# model_augmented-03-0.66.h5   model_augmented-61-0.81.h5
# model_augmented-03-0.69.h5   model_augmented-61-0.83.h5
# model_augmented-03-0.71.h5   model_augmented-61-0.86.h5
# model_augmented-04-0.47.h5   model_augmented-61-0.87.h5
# model_augmented-04-0.61.h5   model_augmented-62-0.82.h5
# model_augmented-04-0.65.h5   model_augmented-62-0.86.h5
# model_augmented-04-0.69.h5   model_augmented-62-0.87.h5
# model_augmented-05-0.47.h5   model_augmented-63-0.82.h5
# model_augmented-05-0.67.h5   model_augmented-63-0.83.h5
# model_augmented-05-0.70.h5   model_augmented-63-0.86.h5
# model_augmented-05-0.72.h5   model_augmented-63-0.87.h5
# model_augmented-06-0.54.h5   model_augmented-64-0.82.h5
# model_augmented-06-0.65.h5   model_augmented-64-0.85.h5
# model_augmented-06-0.68.h5   model_augmented-64-0.86.h5
# model_augmented-06-0.72.h5   model_augmented-64-0.87.h5
# model_augmented-07-0.53.h5   model_augmented-65-0.82.h5
# model_augmented-07-0.66.h5   model_augmented-65-0.85.h5
# model_augmented-07-0.72.h5   model_augmented-65-0.86.h5
# model_augmented-08-0.47.h5   model_augmented-66-0.80.h5
# model_augmented-08-0.67.h5   model_augmented-66-0.82.h5
# model_augmented-08-0.71.h5   model_augmented-66-0.86.h5
# model_augmented-08-0.75.h5   model_augmented-66-0.87.h5
# model_augmented-09-0.61.h5   model_augmented-67-0.71.h5
# model_augmented-09-0.73.h5   model_augmented-67-0.82.h5
# model_augmented-09-0.74.h5   model_augmented-67-0.86.h5
# model_augmented-09-0.76.h5   model_augmented-68-0.82.h5
# model_augmented-100-0.83.h5  model_augmented-68-0.86.h5
# model_augmented-100-0.86.h5  model_augmented-68-0.87.h5
# model_augmented-100-0.87.h5  model_augmented-69-0.74.h5
# model_augmented-100-0.88.h5  model_augmented-69-0.83.h5
# model_augmented-10-0.63.h5   model_augmented-69-0.86.h5
# model_augmented-10-0.71.h5   model_augmented-69-0.87.h5
# model_augmented-10-0.74.h5   model_augmented-70-0.81.h5
# model_augmented-11-0.53.h5   model_augmented-70-0.82.h5
# model_augmented-11-0.74.h5   model_augmented-70-0.86.h5
# model_augmented-11-0.75.h5   model_augmented-70-0.87.h5
# model_augmented-11-0.77.h5   model_augmented-71-0.78.h5
# model_augmented-12-0.47.h5   model_augmented-71-0.82.h5
# model_augmented-12-0.75.h5   model_augmented-71-0.86.h5
# model_augmented-12-0.78.h5   model_augmented-71-0.87.h5
# model_augmented-13-0.53.h5   model_augmented-72-0.81.h5
# model_augmented-13-0.76.h5   model_augmented-72-0.82.h5
# model_augmented-13-0.78.h5   model_augmented-72-0.86.h5
# model_augmented-14-0.73.h5   model_augmented-72-0.87.h5
# model_augmented-14-0.75.h5   model_augmented-73-0.81.h5
# model_augmented-14-0.76.h5   model_augmented-73-0.82.h5
# model_augmented-15-0.53.h5   model_augmented-73-0.86.h5
# model_augmented-15-0.66.h5   model_augmented-73-0.87.h5
# model_augmented-15-0.78.h5   model_augmented-74-0.82.h5
# model_augmented-15-0.81.h5   model_augmented-74-0.83.h5
# model_augmented-16-0.70.h5   model_augmented-74-0.86.h5
# model_augmented-16-0.71.h5   model_augmented-74-0.87.h5
# model_augmented-16-0.79.h5   model_augmented-75-0.82.h5
# model_augmented-16-0.82.h5   model_augmented-75-0.83.h5
# model_augmented-17-0.74.h5   model_augmented-75-0.86.h5
# model_augmented-17-0.76.h5   model_augmented-75-0.87.h5
# model_augmented-18-0.53.h5   model_augmented-76-0.82.h5
# model_augmented-18-0.71.h5   model_augmented-76-0.86.h5
# model_augmented-18-0.77.h5   model_augmented-76-0.87.h5
# model_augmented-18-0.80.h5   model_augmented-77-0.82.h5
# model_augmented-19-0.56.h5   model_augmented-77-0.86.h5
# model_augmented-19-0.64.h5   model_augmented-77-0.87.h5
# model_augmented-19-0.70.h5   model_augmented-77-0.88.h5
# model_augmented-19-0.72.h5   model_augmented-78-0.82.h5
# model_augmented-20-0.45.h5   model_augmented-78-0.86.h5
# model_augmented-20-0.73.h5   model_augmented-78-0.87.h5
# model_augmented-20-0.80.h5   model_augmented-78-0.88.h5
# model_augmented-20-0.81.h5   model_augmented-79-0.82.h5
# model_augmented-21-0.66.h5   model_augmented-79-0.86.h5
# model_augmented-21-0.73.h5   model_augmented-79-0.87.h5
# model_augmented-21-0.74.h5   model_augmented-79-0.88.h5
# model_augmented-21-0.84.h5   model_augmented-80-0.82.h5
# model_augmented-22-0.64.h5   model_augmented-80-0.86.h5
# model_augmented-22-0.69.h5   model_augmented-80-0.87.h5
# model_augmented-22-0.70.h5   model_augmented-81-0.82.h5
# model_augmented-22-0.76.h5   model_augmented-81-0.86.h5
# model_augmented-23-0.69.h5   model_augmented-81-0.87.h5
# model_augmented-23-0.73.h5   model_augmented-81-0.88.h5
# model_augmented-23-0.80.h5   model_augmented-82-0.82.h5
# model_augmented-23-0.81.h5   model_augmented-82-0.86.h5
# model_augmented-24-0.66.h5   model_augmented-82-0.87.h5
# model_augmented-24-0.68.h5   model_augmented-83-0.82.h5
# model_augmented-24-0.71.h5   model_augmented-83-0.86.h5
# model_augmented-24-0.78.h5   model_augmented-83-0.87.h5
# model_augmented-25-0.54.h5   model_augmented-84-0.82.h5
# model_augmented-25-0.80.h5   model_augmented-84-0.86.h5
# model_augmented-25-0.82.h5   model_augmented-84-0.87.h5
# model_augmented-25-0.83.h5   model_augmented-85-0.83.h5
# model_augmented-26-0.66.h5   model_augmented-85-0.86.h5
# model_augmented-26-0.68.h5   model_augmented-85-0.87.h5
# model_augmented-26-0.76.h5   model_augmented-86-0.82.h5
# model_augmented-26-0.81.h5   model_augmented-86-0.86.h5
# model_augmented-27-0.47.h5   model_augmented-86-0.87.h5
# model_augmented-27-0.76.h5   model_augmented-87-0.82.h5
# model_augmented-27-0.77.h5   model_augmented-87-0.86.h5
# model_augmented-27-0.86.h5   model_augmented-87-0.87.h5
# model_augmented-28-0.66.h5   model_augmented-88-0.83.h5
# model_augmented-28-0.75.h5   model_augmented-88-0.85.h5
# model_augmented-28-0.76.h5   model_augmented-88-0.86.h5
# model_augmented-28-0.80.h5   model_augmented-88-0.87.h5
# model_augmented-29-0.59.h5   model_augmented-89-0.82.h5
# model_augmented-29-0.65.h5   model_augmented-89-0.86.h5
# model_augmented-29-0.72.h5   model_augmented-89-0.87.h5
# model_augmented-29-0.78.h5   model_augmented-90-0.83.h5
# model_augmented-30-0.47.h5   model_augmented-90-0.86.h5
# model_augmented-30-0.60.h5   model_augmented-90-0.87.h5
# model_augmented-30-0.79.h5   model_augmented-91-0.82.h5
# model_augmented-30-0.87.h5   model_augmented-91-0.86.h5
# model_augmented-31-0.47.h5   model_augmented-91-0.87.h5
# model_augmented-31-0.76.h5   model_augmented-92-0.82.h5
# model_augmented-31-0.80.h5   model_augmented-92-0.86.h5
# model_augmented-31-0.84.h5   model_augmented-92-0.87.h5
# model_augmented-32-0.53.h5   model_augmented-93-0.82.h5
# model_augmented-32-0.76.h5   model_augmented-93-0.86.h5
# model_augmented-32-0.84.h5   model_augmented-93-0.87.h5
# model_augmented-32-0.87.h5   model_augmented-94-0.82.h5
# model_augmented-33-0.76.h5   model_augmented-94-0.86.h5
# model_augmented-33-0.78.h5   model_augmented-94-0.87.h5
# model_augmented-33-0.81.h5   model_augmented-95-0.83.h5
# model_augmented-33-0.84.h5   model_augmented-95-0.86.h5
# model_augmented-34-0.77.h5   model_augmented-95-0.87.h5
# model_augmented-34-0.80.h5   model_augmented-96-0.82.h5
# model_augmented-34-0.84.h5   model_augmented-96-0.86.h5
# model_augmented-35-0.67.h5   model_augmented-96-0.87.h5
# model_augmented-35-0.68.h5   model_augmented-97-0.83.h5
# model_augmented-35-0.80.h5   model_augmented-97-0.86.h5
# model_augmented-35-0.81.h5   model_augmented-97-0.87.h5
# model_augmented-36-0.75.h5   model_augmented-98-0.83.h5
# model_augmented-36-0.79.h5   model_augmented-98-0.86.h5
# model_augmented-36-0.80.h5   model_augmented-98-0.87.h5
# model_augmented-37-0.68.h5   model_augmented-98-0.88.h5
# model_augmented-37-0.77.h5   model_augmented-99-0.82.h5
# model_augmented-37-0.80.h5   model_augmented-99-0.86.h5
# model_augmented-38-0.71.h5   model_augmented-99-0.87.h5
# model_augmented-38-0.79.h5   model_augmented-99-0.88.h5
# model_augmented-38-0.80.h5   model_augmented.h5
# model_augmented-38-0.84.h5   model.h5
# model_augmented-39-0.77.h5   model.png
# model_augmented-39-0.80.h5   README_micro.rtf
# model_augmented-39-0.84.h5   sample_data
# model_augmented-39-0.86.h5   Test
# model_augmented-40-0.76.h5   Train

# %% [markdown]
# # Evaluate network performance on the independent **Test** set in term of accuracy and AUC.

# %%
#FILL HERE# Evaluate the model on the independent Test set (x_test, y_test)
# ....
# print(...)
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy: %.3f' % (test_acc))
# Out:
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3998 - accuracy: 0.8216
#
# Test accuracy: 0.822

# %%
preds_test = model.predict(x_test, verbose=1)
fpr, tpr, _ = roc_curve(y_test, preds_test)
roc_auc = auc(fpr, tpr)
print('AUC = %.3f'% (roc_auc))
# Out:
# 8/8 [==============================] - 0s 2ms/step
# AUC = 0.924

# %%
#Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Data augmentation [extra]
#
# For those of you that are very skilled and/or very fast we briefly treat the topic of data augmentation.
#
# Data augmentation is a technique used to increase the size of the training dataset images by artficially creating new images applying appropriate transformations.
#
# Data augmentation is particularly useful in the context of medical physics since data is usually scarce.
#
# We can then improve the overall performance of our CNN providing a greater number of images, even if they are generated from our starting dataset.
#
# N.B. we do not use the existing images to train the network: we use them only as a starting point to generate extra images.
#
#
# > In order to perform the said modifications we use the module skimage.trasform [[doc](https://scikit-image.org/docs/stable/api/skimage.transform.html)] of scikit-image. This function can implement several geometric transformations in the context of image processing (e.g. scale, shear, rotation and translation).

# %%
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util
from skimage import io
import random

def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree, mode='reflect',  preserve_range=True)

def random_noise(image_array: ndarray):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array: ndarray):
    return image_array[:, ::-1]

def augment(image_list, Steps=[random_rotation, random_noise, horizontal_flip]):
   #image augmentation by doing a sereis of transfomations on the image.
   aug_list = []
   for image in image_list:
    img_list = []
    for step in Steps:
      img_aug = step(image)
      img_list.append(img_aug)
    aug_list += img_list
   return np.array(aug_list, dtype='float32')

# %% [markdown]
# Let's apply the **augment** function to both the training and validation sets and then print the new obtained shapes (the number of the sample is 3 times the original one)

# %%
X_train_aug = augment(X_train)
Y_train_aug = np.array(Y_train).repeat(3)

X_val_aug = augment(X_val)
Y_val_aug = np.array(Y_val).repeat(3)

print(np.shape(X_train_aug), np.shape(Y_train_aug))
print(np.shape(X_val_aug), np.shape(Y_val_aug))
# Out:
# (1332, 60, 60, 1) (1332,)
# (336, 60, 60, 1) (336,)

# %%
i = 1
plt.figure()
plt.imshow(X_train[i], cmap='gray')
plt.colorbar()
plt.title('original image')
plt.figure()
plt.imshow(X_train_aug[3+i-1], cmap='gray')
plt.colorbar()
plt.title('trasformed (rotated) image')
print(Y_train_aug[i])
# Out:
# 0

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    "model_augmented-{epoch:02d}-{val_accuracy:.2f}.h5",
    monitor='val_accuracy',
    verbose=1,
    save_best_only=False,
    save_weights_only=False,
    mode='auto', save_freq='epoch')

# %%
model = make_model()
learning_rate = 0.001
model.compile(optimizer=SGD(learning_rate, momentum=0.9), loss='binary_crossentropy', metrics=['accuracy'])

# %%
epochs= 150 # 300 is ok
batch_size = 32
history = model.fit(X_train_aug, Y_train_aug,
                    batch_size=batch_size,
                    epochs=epochs,
                    #steps_per_epoch = np.shape(X_train_aug)[0]/batch_size,
                    verbose=1,
                    validation_data=(X_val_aug, Y_val_aug),
                    #validation_steps=np.shape(X_val_aug)[0]/batch_size,
                    callbacks=[checkpoint,reduce_on_plateau]
                    )
# Out:
# Epoch 1/150
# 42/42 [==============================] - ETA: 0s - loss: 0.6458 - accuracy: 0.6749
# Epoch 1: saving model to model_augmented-01-0.68.h5
# 42/42 [==============================] - 3s 23ms/step - loss: 0.6458 - accuracy: 0.6749 - val_loss: 0.6764 - val_accuracy: 0.6815 - lr: 0.0010
# Epoch 2/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.5277 - accuracy: 0.6993
# Epoch 2: saving model to model_augmented-02-0.69.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.5293 - accuracy: 0.7012 - val_loss: 0.6679 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 3/150
# 42/42 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.7327
# Epoch 3: saving model to model_augmented-03-0.66.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5272 - accuracy: 0.7327 - val_loss: 0.6554 - val_accuracy: 0.6637 - lr: 0.0010
# Epoch 4/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5095 - accuracy: 0.7325
# Epoch 4: saving model to model_augmented-04-0.68.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.5120 - accuracy: 0.7305 - val_loss: 0.6471 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 5/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.4976 - accuracy: 0.7364
# Epoch 5: saving model to model_augmented-05-0.68.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5038 - accuracy: 0.7312 - val_loss: 0.6395 - val_accuracy: 0.6756 - lr: 0.0010
# Epoch 6/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.4875 - accuracy: 0.7437
# Epoch 6: saving model to model_augmented-06-0.68.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.4956 - accuracy: 0.7402 - val_loss: 0.6241 - val_accuracy: 0.6815 - lr: 0.0010
# Epoch 7/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.4900 - accuracy: 0.7416
# Epoch 7: saving model to model_augmented-07-0.69.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.4892 - accuracy: 0.7417 - val_loss: 0.6027 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 8/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.4919 - accuracy: 0.7475
# Epoch 8: saving model to model_augmented-08-0.71.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4870 - accuracy: 0.7530 - val_loss: 0.5308 - val_accuracy: 0.7054 - lr: 0.0010
# Epoch 9/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.4626 - accuracy: 0.7576
# Epoch 9: saving model to model_augmented-09-0.71.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4583 - accuracy: 0.7613 - val_loss: 0.5159 - val_accuracy: 0.7113 - lr: 0.0010
# Epoch 10/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.4332 - accuracy: 0.8133
# Epoch 10: saving model to model_augmented-10-0.74.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4309 - accuracy: 0.8146 - val_loss: 0.5096 - val_accuracy: 0.7440 - lr: 0.0010
# Epoch 11/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.4099 - accuracy: 0.8101
# Epoch 11: saving model to model_augmented-11-0.75.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.4098 - accuracy: 0.8108 - val_loss: 0.4690 - val_accuracy: 0.7470 - lr: 0.0010
# Epoch 12/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.4380 - accuracy: 0.8018
# Epoch 12: saving model to model_augmented-12-0.75.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4366 - accuracy: 0.8018 - val_loss: 0.4899 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.4127 - accuracy: 0.8049
# Epoch 13: saving model to model_augmented-13-0.80.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.4122 - accuracy: 0.8048 - val_loss: 0.4283 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 14/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.3864 - accuracy: 0.8243
# Epoch 14: saving model to model_augmented-14-0.80.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3864 - accuracy: 0.8236 - val_loss: 0.4586 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 15/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.3862 - accuracy: 0.8285
# Epoch 15: saving model to model_augmented-15-0.79.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3825 - accuracy: 0.8273 - val_loss: 0.4766 - val_accuracy: 0.7887 - lr: 0.0010
# Epoch 16/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.3854 - accuracy: 0.8297
# Epoch 16: saving model to model_augmented-16-0.83.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3836 - accuracy: 0.8303 - val_loss: 0.3737 - val_accuracy: 0.8274 - lr: 0.0010
# Epoch 17/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.3569 - accuracy: 0.8421
# Epoch 17: saving model to model_augmented-17-0.77.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3578 - accuracy: 0.8438 - val_loss: 0.4850 - val_accuracy: 0.7679 - lr: 0.0010
# Epoch 18/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.3656 - accuracy: 0.8293
# Epoch 18: saving model to model_augmented-18-0.68.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.3719 - accuracy: 0.8258 - val_loss: 0.6774 - val_accuracy: 0.6815 - lr: 0.0010
# Epoch 19/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.3561 - accuracy: 0.8468
# Epoch 19: saving model to model_augmented-19-0.77.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3560 - accuracy: 0.8468 - val_loss: 0.4251 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 20/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.3377 - accuracy: 0.8438
# Epoch 20: saving model to model_augmented-20-0.83.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3370 - accuracy: 0.8438 - val_loss: 0.3733 - val_accuracy: 0.8274 - lr: 0.0010
# Epoch 21/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.3321 - accuracy: 0.8529
# Epoch 21: saving model to model_augmented-21-0.79.h5
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3336 - accuracy: 0.8506 - val_loss: 0.5080 - val_accuracy: 0.7946 - lr: 0.0010
# Epoch 22/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.3067 - accuracy: 0.8687
# Epoch 22: saving model to model_augmented-22-0.82.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3077 - accuracy: 0.8679 - val_loss: 0.3924 - val_accuracy: 0.8214 - lr: 0.0010
# Epoch 23/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.3015 - accuracy: 0.8797
# Epoch 23: saving model to model_augmented-23-0.80.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3008 - accuracy: 0.8791 - val_loss: 0.4360 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 24/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.3328 - accuracy: 0.8520
# Epoch 24: saving model to model_augmented-24-0.80.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3332 - accuracy: 0.8514 - val_loss: 0.4432 - val_accuracy: 0.8006 - lr: 0.0010
# Epoch 25/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.3032 - accuracy: 0.8654
# Epoch 25: saving model to model_augmented-25-0.78.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2974 - accuracy: 0.8701 - val_loss: 1.1475 - val_accuracy: 0.7798 - lr: 0.0010
# Epoch 26/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.3157 - accuracy: 0.8641
# Epoch 26: saving model to model_augmented-26-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.3160 - accuracy: 0.8641 - val_loss: 0.3417 - val_accuracy: 0.8482 - lr: 0.0010
# Epoch 27/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.3198 - accuracy: 0.8622
# Epoch 27: saving model to model_augmented-27-0.81.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.3229 - accuracy: 0.8604 - val_loss: 0.4041 - val_accuracy: 0.8065 - lr: 0.0010
# Epoch 28/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.2881 - accuracy: 0.8796
# Epoch 28: saving model to model_augmented-28-0.80.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2871 - accuracy: 0.8799 - val_loss: 0.4693 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 29/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.2824 - accuracy: 0.8789
# Epoch 29: saving model to model_augmented-29-0.78.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.2801 - accuracy: 0.8814 - val_loss: 0.5141 - val_accuracy: 0.7827 - lr: 0.0010
# Epoch 30/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.2629 - accuracy: 0.8977
# Epoch 30: saving model to model_augmented-30-0.64.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2586 - accuracy: 0.9002 - val_loss: 0.7858 - val_accuracy: 0.6399 - lr: 0.0010
# Epoch 31/150
# 42/42 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8874
# Epoch 31: saving model to model_augmented-31-0.67.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.2683 - accuracy: 0.8874 - val_loss: 0.7076 - val_accuracy: 0.6696 - lr: 0.0010
# Epoch 32/150
# 42/42 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.8941
# Epoch 32: saving model to model_augmented-32-0.84.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2670 - accuracy: 0.8941 - val_loss: 0.3653 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 33/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.2662 - accuracy: 0.8865
# Epoch 33: saving model to model_augmented-33-0.82.h5
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2659 - accuracy: 0.8874 - val_loss: 0.4047 - val_accuracy: 0.8185 - lr: 0.0010
# Epoch 34/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.2670 - accuracy: 0.8877
# Epoch 34: saving model to model_augmented-34-0.71.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2747 - accuracy: 0.8829 - val_loss: 0.5764 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 35/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.2540 - accuracy: 0.8969
# Epoch 35: saving model to model_augmented-35-0.85.h5
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2602 - accuracy: 0.8941 - val_loss: 0.3628 - val_accuracy: 0.8482 - lr: 0.0010
# Epoch 36/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.2397 - accuracy: 0.9036
# Epoch 36: saving model to model_augmented-36-0.85.h5
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2291 - accuracy: 0.9107 - val_loss: 0.3381 - val_accuracy: 0.8452 - lr: 0.0010
# Epoch 37/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.2384 - accuracy: 0.9107
# Epoch 37: saving model to model_augmented-37-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2351 - accuracy: 0.9114 - val_loss: 0.2969 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 38/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.2269 - accuracy: 0.9103
# Epoch 38: saving model to model_augmented-38-0.84.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2310 - accuracy: 0.9084 - val_loss: 0.3807 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 39/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.2446 - accuracy: 0.9013
# Epoch 39: saving model to model_augmented-39-0.79.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2397 - accuracy: 0.9032 - val_loss: 0.4443 - val_accuracy: 0.7946 - lr: 0.0010
# Epoch 40/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.2139 - accuracy: 0.9139
# Epoch 40: saving model to model_augmented-40-0.85.h5
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2135 - accuracy: 0.9137 - val_loss: 0.3897 - val_accuracy: 0.8512 - lr: 0.0010
# Epoch 41/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.2173 - accuracy: 0.9143
# Epoch 41: saving model to model_augmented-41-0.84.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.2163 - accuracy: 0.9152 - val_loss: 0.4399 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 42/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.2057 - accuracy: 0.9268
# Epoch 42: saving model to model_augmented-42-0.76.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.2064 - accuracy: 0.9264 - val_loss: 0.5325 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 43/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.2042 - accuracy: 0.9180
# Epoch 43: saving model to model_augmented-43-0.78.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2101 - accuracy: 0.9182 - val_loss: 0.5793 - val_accuracy: 0.7798 - lr: 0.0010
# Epoch 44/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.2234 - accuracy: 0.9032
# Epoch 44: saving model to model_augmented-44-0.81.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2238 - accuracy: 0.9024 - val_loss: 0.6057 - val_accuracy: 0.8095 - lr: 0.0010
# Epoch 45/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.2143 - accuracy: 0.9151
# Epoch 45: saving model to model_augmented-45-0.84.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2182 - accuracy: 0.9122 - val_loss: 0.3902 - val_accuracy: 0.8393 - lr: 0.0010
# Epoch 46/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1817 - accuracy: 0.9359
# Epoch 46: saving model to model_augmented-46-0.72.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1841 - accuracy: 0.9354 - val_loss: 0.6652 - val_accuracy: 0.7173 - lr: 0.0010
# Epoch 47/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1942 - accuracy: 0.9263
# Epoch 47: saving model to model_augmented-47-0.77.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1970 - accuracy: 0.9249 - val_loss: 0.5448 - val_accuracy: 0.7738 - lr: 0.0010
# Epoch 48/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.2498 - accuracy: 0.8961
# Epoch 48: saving model to model_augmented-48-0.84.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2396 - accuracy: 0.9017 - val_loss: 0.3538 - val_accuracy: 0.8423 - lr: 1.0000e-04
# Epoch 49/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1677 - accuracy: 0.9367
# Epoch 49: saving model to model_augmented-49-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1687 - accuracy: 0.9354 - val_loss: 0.3378 - val_accuracy: 0.8482 - lr: 1.0000e-04
# Epoch 50/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1640 - accuracy: 0.9383
# Epoch 50: saving model to model_augmented-50-0.87.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1650 - accuracy: 0.9384 - val_loss: 0.3498 - val_accuracy: 0.8690 - lr: 1.0000e-04
# Epoch 51/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1567 - accuracy: 0.9416
# Epoch 51: saving model to model_augmented-51-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1595 - accuracy: 0.9407 - val_loss: 0.3354 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 52/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1561 - accuracy: 0.9430
# Epoch 52: saving model to model_augmented-52-0.86.h5
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1528 - accuracy: 0.9444 - val_loss: 0.3480 - val_accuracy: 0.8631 - lr: 1.0000e-04
# Epoch 53/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1497 - accuracy: 0.9461
# Epoch 53: saving model to model_augmented-53-0.86.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1500 - accuracy: 0.9459 - val_loss: 0.3421 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 54/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1541 - accuracy: 0.9438
# Epoch 54: saving model to model_augmented-54-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1542 - accuracy: 0.9444 - val_loss: 0.4140 - val_accuracy: 0.8452 - lr: 1.0000e-04
# Epoch 55/150
# 33/42 [======================>.......] - ETA: 0s - loss: 0.1577 - accuracy: 0.9394
# Epoch 55: saving model to model_augmented-55-0.86.h5
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1555 - accuracy: 0.9437 - val_loss: 0.3414 - val_accuracy: 0.8601 - lr: 1.0000e-04
# Epoch 56/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1376 - accuracy: 0.9575
# Epoch 56: saving model to model_augmented-56-0.86.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9565 - val_loss: 0.3430 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 57/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1568 - accuracy: 0.9383
# Epoch 57: saving model to model_augmented-57-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1534 - accuracy: 0.9414 - val_loss: 0.4039 - val_accuracy: 0.8452 - lr: 1.0000e-04
# Epoch 58/150
# 32/42 [=====================>........] - ETA: 0s - loss: 0.1457 - accuracy: 0.9482
# Epoch 58: saving model to model_augmented-58-0.86.h5
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1530 - accuracy: 0.9474 - val_loss: 0.3667 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 59/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1440 - accuracy: 0.9567
# Epoch 59: saving model to model_augmented-59-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1405 - accuracy: 0.9580 - val_loss: 0.3438 - val_accuracy: 0.8512 - lr: 1.0000e-05
# Epoch 60/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1585 - accuracy: 0.9451
# Epoch 60: saving model to model_augmented-60-0.86.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1553 - accuracy: 0.9482 - val_loss: 0.3447 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 61/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1386 - accuracy: 0.9573
# Epoch 61: saving model to model_augmented-61-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1386 - accuracy: 0.9580 - val_loss: 0.3424 - val_accuracy: 0.8542 - lr: 1.0000e-05
# Epoch 62/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1437 - accuracy: 0.9438
# Epoch 62: saving model to model_augmented-62-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1419 - accuracy: 0.9452 - val_loss: 0.3459 - val_accuracy: 0.8542 - lr: 1.0000e-05
# Epoch 63/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1459 - accuracy: 0.9527
# Epoch 63: saving model to model_augmented-63-0.85.h5
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1453 - accuracy: 0.9527 - val_loss: 0.3462 - val_accuracy: 0.8542 - lr: 1.0000e-05
# Epoch 64/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1377 - accuracy: 0.9503
# Epoch 64: saving model to model_augmented-64-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1368 - accuracy: 0.9505 - val_loss: 0.3495 - val_accuracy: 0.8512 - lr: 1.0000e-05
# Epoch 65/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9413
# Epoch 65: saving model to model_augmented-65-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1483 - accuracy: 0.9414 - val_loss: 0.3488 - val_accuracy: 0.8512 - lr: 1.0000e-05
# Epoch 66/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1493 - accuracy: 0.9453
# Epoch 66: saving model to model_augmented-66-0.86.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1417 - accuracy: 0.9497 - val_loss: 0.3539 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 67/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1441 - accuracy: 0.9439
# Epoch 67: saving model to model_augmented-67-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1465 - accuracy: 0.9437 - val_loss: 0.3506 - val_accuracy: 0.8512 - lr: 1.0000e-05
# Epoch 68/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9497
# Epoch 68: saving model to model_augmented-68-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1510 - accuracy: 0.9497 - val_loss: 0.3491 - val_accuracy: 0.8542 - lr: 1.0000e-06
# Epoch 69/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1327 - accuracy: 0.9485
# Epoch 69: saving model to model_augmented-69-0.85.h5
# 42/42 [==============================] - 0s 10ms/step - loss: 0.1318 - accuracy: 0.9497 - val_loss: 0.3499 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 70/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9474
# Epoch 70: saving model to model_augmented-70-0.85.h5
# 42/42 [==============================] - 1s 12ms/step - loss: 0.1507 - accuracy: 0.9474 - val_loss: 0.3509 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 71/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1518 - accuracy: 0.9457
# Epoch 71: saving model to model_augmented-71-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1542 - accuracy: 0.9444 - val_loss: 0.3506 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 72/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1405 - accuracy: 0.9516
# Epoch 72: saving model to model_augmented-72-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1407 - accuracy: 0.9512 - val_loss: 0.3506 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 73/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1633 - accuracy: 0.9398
# Epoch 73: saving model to model_augmented-73-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1628 - accuracy: 0.9392 - val_loss: 0.3504 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 74/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1421 - accuracy: 0.9489
# Epoch 74: saving model to model_augmented-74-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1416 - accuracy: 0.9489 - val_loss: 0.3504 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 75/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9347
# Epoch 75: saving model to model_augmented-75-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1611 - accuracy: 0.9347 - val_loss: 0.3504 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 76/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1487 - accuracy: 0.9474
# Epoch 76: saving model to model_augmented-76-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1488 - accuracy: 0.9467 - val_loss: 0.3508 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 77/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9466
# Epoch 77: saving model to model_augmented-77-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1469 - accuracy: 0.9467 - val_loss: 0.3513 - val_accuracy: 0.8512 - lr: 1.0000e-06
# Epoch 78/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1437 - accuracy: 0.9531
# Epoch 78: saving model to model_augmented-78-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1456 - accuracy: 0.9520 - val_loss: 0.3498 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 79/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1476 - accuracy: 0.9443
# Epoch 79: saving model to model_augmented-79-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1471 - accuracy: 0.9437 - val_loss: 0.3491 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 80/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1498 - accuracy: 0.9498
# Epoch 80: saving model to model_augmented-80-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1508 - accuracy: 0.9489 - val_loss: 0.3493 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 81/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1433 - accuracy: 0.9466
# Epoch 81: saving model to model_augmented-81-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1430 - accuracy: 0.9467 - val_loss: 0.3484 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 82/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1466 - accuracy: 0.9507
# Epoch 82: saving model to model_augmented-82-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1443 - accuracy: 0.9520 - val_loss: 0.3492 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 83/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1568 - accuracy: 0.9453
# Epoch 83: saving model to model_augmented-83-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1561 - accuracy: 0.9452 - val_loss: 0.3489 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 84/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9482
# Epoch 84: saving model to model_augmented-84-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1468 - accuracy: 0.9474 - val_loss: 0.3488 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 85/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1599 - accuracy: 0.9422
# Epoch 85: saving model to model_augmented-85-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1588 - accuracy: 0.9422 - val_loss: 0.3472 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 86/150
# 34/42 [=======================>......] - ETA: 0s - loss: 0.1457 - accuracy: 0.9439
# Epoch 86: saving model to model_augmented-86-0.85.h5
# 42/42 [==============================] - 0s 10ms/step - loss: 0.1469 - accuracy: 0.9437 - val_loss: 0.3488 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 87/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9550
# Epoch 87: saving model to model_augmented-87-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1352 - accuracy: 0.9542 - val_loss: 0.3502 - val_accuracy: 0.8512 - lr: 1.0000e-07
# Epoch 88/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.9360
# Epoch 88: saving model to model_augmented-88-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1521 - accuracy: 0.9369 - val_loss: 0.3498 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 89/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1461 - accuracy: 0.9423
# Epoch 89: saving model to model_augmented-89-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1462 - accuracy: 0.9422 - val_loss: 0.3496 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 90/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1491 - accuracy: 0.9441
# Epoch 90: saving model to model_augmented-90-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1448 - accuracy: 0.9459 - val_loss: 0.3484 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 91/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1587 - accuracy: 0.9457
# Epoch 91: saving model to model_augmented-91-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1566 - accuracy: 0.9467 - val_loss: 0.3477 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 92/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1416 - accuracy: 0.9540
# Epoch 92: saving model to model_augmented-92-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1510 - accuracy: 0.9512 - val_loss: 0.3483 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 93/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.1383 - accuracy: 0.9554
# Epoch 93: saving model to model_augmented-93-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1413 - accuracy: 0.9527 - val_loss: 0.3477 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 94/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1405 - accuracy: 0.9527
# Epoch 94: saving model to model_augmented-94-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1389 - accuracy: 0.9535 - val_loss: 0.3476 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 95/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.9436
# Epoch 95: saving model to model_augmented-95-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1511 - accuracy: 0.9444 - val_loss: 0.3484 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 96/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1362 - accuracy: 0.9474
# Epoch 96: saving model to model_augmented-96-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1357 - accuracy: 0.9482 - val_loss: 0.3487 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 97/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1469 - accuracy: 0.9423
# Epoch 97: saving model to model_augmented-97-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1446 - accuracy: 0.9444 - val_loss: 0.3482 - val_accuracy: 0.8512 - lr: 1.0000e-08
# Epoch 98/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1443 - accuracy: 0.9516
# Epoch 98: saving model to model_augmented-98-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1435 - accuracy: 0.9512 - val_loss: 0.3472 - val_accuracy: 0.8542 - lr: 1.0000e-09
# Epoch 99/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1518 - accuracy: 0.9408
# Epoch 99: saving model to model_augmented-99-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1547 - accuracy: 0.9407 - val_loss: 0.3475 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 100/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1503 - accuracy: 0.9479
# Epoch 100: saving model to model_augmented-100-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1534 - accuracy: 0.9459 - val_loss: 0.3465 - val_accuracy: 0.8542 - lr: 1.0000e-09
# Epoch 101/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 0.9452
# Epoch 101: saving model to model_augmented-101-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1515 - accuracy: 0.9452 - val_loss: 0.3483 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 102/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1543 - accuracy: 0.9449
# Epoch 102: saving model to model_augmented-102-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1524 - accuracy: 0.9459 - val_loss: 0.3481 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 103/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1413 - accuracy: 0.9485
# Epoch 103: saving model to model_augmented-103-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1493 - accuracy: 0.9467 - val_loss: 0.3502 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 104/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1620 - accuracy: 0.9350
# Epoch 104: saving model to model_augmented-104-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1582 - accuracy: 0.9384 - val_loss: 0.3505 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 105/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1543 - accuracy: 0.9444
# Epoch 105: saving model to model_augmented-105-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1509 - accuracy: 0.9459 - val_loss: 0.3502 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 106/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1534 - accuracy: 0.9384
# Epoch 106: saving model to model_augmented-106-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1507 - accuracy: 0.9407 - val_loss: 0.3506 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 107/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1433 - accuracy: 0.9439
# Epoch 107: saving model to model_augmented-107-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1453 - accuracy: 0.9429 - val_loss: 0.3502 - val_accuracy: 0.8512 - lr: 1.0000e-09
# Epoch 108/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1407 - accuracy: 0.9523
# Epoch 108: saving model to model_augmented-108-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1360 - accuracy: 0.9550 - val_loss: 0.3503 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 109/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1342 - accuracy: 0.9498
# Epoch 109: saving model to model_augmented-109-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1313 - accuracy: 0.9535 - val_loss: 0.3497 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 110/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1589 - accuracy: 0.9392
# Epoch 110: saving model to model_augmented-110-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1565 - accuracy: 0.9407 - val_loss: 0.3491 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 111/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1434 - accuracy: 0.9474
# Epoch 111: saving model to model_augmented-111-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1416 - accuracy: 0.9489 - val_loss: 0.3497 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 112/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1508 - accuracy: 0.9515
# Epoch 112: saving model to model_augmented-112-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1511 - accuracy: 0.9497 - val_loss: 0.3498 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 113/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1618 - accuracy: 0.9350
# Epoch 113: saving model to model_augmented-113-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1627 - accuracy: 0.9354 - val_loss: 0.3491 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 114/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1544 - accuracy: 0.9479
# Epoch 114: saving model to model_augmented-114-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1514 - accuracy: 0.9497 - val_loss: 0.3485 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 115/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.1338 - accuracy: 0.9554
# Epoch 115: saving model to model_augmented-115-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1377 - accuracy: 0.9535 - val_loss: 0.3499 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 116/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1410 - accuracy: 0.9493
# Epoch 116: saving model to model_augmented-116-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1399 - accuracy: 0.9505 - val_loss: 0.3501 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 117/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1460 - accuracy: 0.9498
# Epoch 117: saving model to model_augmented-117-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1492 - accuracy: 0.9489 - val_loss: 0.3498 - val_accuracy: 0.8512 - lr: 1.0000e-10
# Epoch 118/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1510 - accuracy: 0.9457
# Epoch 118: saving model to model_augmented-118-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1527 - accuracy: 0.9467 - val_loss: 0.3496 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 119/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1571 - accuracy: 0.9391
# Epoch 119: saving model to model_augmented-119-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1517 - accuracy: 0.9422 - val_loss: 0.3480 - val_accuracy: 0.8542 - lr: 1.0000e-11
# Epoch 120/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1550 - accuracy: 0.9436
# Epoch 120: saving model to model_augmented-120-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1570 - accuracy: 0.9399 - val_loss: 0.3500 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 121/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1361 - accuracy: 0.9557
# Epoch 121: saving model to model_augmented-121-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1460 - accuracy: 0.9512 - val_loss: 0.3499 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 122/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1436 - accuracy: 0.9485
# Epoch 122: saving model to model_augmented-122-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1397 - accuracy: 0.9512 - val_loss: 0.3491 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 123/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.1399 - accuracy: 0.9527
# Epoch 123: saving model to model_augmented-123-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1413 - accuracy: 0.9505 - val_loss: 0.3503 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 124/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1554 - accuracy: 0.9468
# Epoch 124: saving model to model_augmented-124-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1573 - accuracy: 0.9444 - val_loss: 0.3496 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 125/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1553 - accuracy: 0.9406
# Epoch 125: saving model to model_augmented-125-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1586 - accuracy: 0.9399 - val_loss: 0.3506 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 126/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1456 - accuracy: 0.9455
# Epoch 126: saving model to model_augmented-126-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1482 - accuracy: 0.9437 - val_loss: 0.3497 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 127/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1545 - accuracy: 0.9455
# Epoch 127: saving model to model_augmented-127-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1528 - accuracy: 0.9459 - val_loss: 0.3499 - val_accuracy: 0.8512 - lr: 1.0000e-11
# Epoch 128/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1603 - accuracy: 0.9383
# Epoch 128: saving model to model_augmented-128-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1571 - accuracy: 0.9377 - val_loss: 0.3487 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 129/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1565 - accuracy: 0.9408
# Epoch 129: saving model to model_augmented-129-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1557 - accuracy: 0.9422 - val_loss: 0.3492 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 130/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1365 - accuracy: 0.9583
# Epoch 130: saving model to model_augmented-130-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1384 - accuracy: 0.9572 - val_loss: 0.3487 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 131/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1360 - accuracy: 0.9540
# Epoch 131: saving model to model_augmented-131-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1438 - accuracy: 0.9497 - val_loss: 0.3485 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 132/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9505
# Epoch 132: saving model to model_augmented-132-0.85.h5
# 42/42 [==============================] - 0s 10ms/step - loss: 0.1383 - accuracy: 0.9505 - val_loss: 0.3493 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 133/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9520
# Epoch 133: saving model to model_augmented-133-0.85.h5
# 42/42 [==============================] - 0s 12ms/step - loss: 0.1456 - accuracy: 0.9520 - val_loss: 0.3493 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 134/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1488 - accuracy: 0.9434
# Epoch 134: saving model to model_augmented-134-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1456 - accuracy: 0.9444 - val_loss: 0.3489 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 135/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1422 - accuracy: 0.9492
# Epoch 135: saving model to model_augmented-135-0.85.h5
# 42/42 [==============================] - 1s 12ms/step - loss: 0.1472 - accuracy: 0.9459 - val_loss: 0.3489 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 136/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1406 - accuracy: 0.9515
# Epoch 136: saving model to model_augmented-136-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1425 - accuracy: 0.9497 - val_loss: 0.3507 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 137/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9497
# Epoch 137: saving model to model_augmented-137-0.85.h5
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1384 - accuracy: 0.9497 - val_loss: 0.3496 - val_accuracy: 0.8512 - lr: 1.0000e-12
# Epoch 138/150
# 34/42 [=======================>......] - ETA: 0s - loss: 0.1416 - accuracy: 0.9458
# Epoch 138: saving model to model_augmented-138-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1468 - accuracy: 0.9459 - val_loss: 0.3491 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 139/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.1547 - accuracy: 0.9473
# Epoch 139: saving model to model_augmented-139-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1453 - accuracy: 0.9527 - val_loss: 0.3483 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 140/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.1567 - accuracy: 0.9375
# Epoch 140: saving model to model_augmented-140-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1575 - accuracy: 0.9399 - val_loss: 0.3491 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 141/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1592 - accuracy: 0.9392
# Epoch 141: saving model to model_augmented-141-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1539 - accuracy: 0.9414 - val_loss: 0.3488 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 142/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1419 - accuracy: 0.9523
# Epoch 142: saving model to model_augmented-142-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1433 - accuracy: 0.9512 - val_loss: 0.3494 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 143/150
# 37/42 [=========================>....] - ETA: 0s - loss: 0.1543 - accuracy: 0.9409
# Epoch 143: saving model to model_augmented-143-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1500 - accuracy: 0.9437 - val_loss: 0.3495 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 144/150
# 34/42 [=======================>......] - ETA: 0s - loss: 0.1572 - accuracy: 0.9347
# Epoch 144: saving model to model_augmented-144-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1520 - accuracy: 0.9407 - val_loss: 0.3495 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 145/150
# 36/42 [========================>.....] - ETA: 0s - loss: 0.1517 - accuracy: 0.9444
# Epoch 145: saving model to model_augmented-145-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1492 - accuracy: 0.9452 - val_loss: 0.3479 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 146/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1471 - accuracy: 0.9447
# Epoch 146: saving model to model_augmented-146-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1450 - accuracy: 0.9452 - val_loss: 0.3477 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 147/150
# 35/42 [========================>.....] - ETA: 0s - loss: 0.1501 - accuracy: 0.9429
# Epoch 147: saving model to model_augmented-147-0.85.h5
# 42/42 [==============================] - 0s 8ms/step - loss: 0.1472 - accuracy: 0.9452 - val_loss: 0.3478 - val_accuracy: 0.8512 - lr: 1.0000e-13
# Epoch 148/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1602 - accuracy: 0.9367
# Epoch 148: saving model to model_augmented-148-0.85.h5
# 42/42 [==============================] - 1s 15ms/step - loss: 0.1588 - accuracy: 0.9377 - val_loss: 0.3478 - val_accuracy: 0.8512 - lr: 1.0000e-14
# Epoch 149/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.9428
# Epoch 149: saving model to model_augmented-149-0.85.h5
# 42/42 [==============================] - 0s 9ms/step - loss: 0.1439 - accuracy: 0.9429 - val_loss: 0.3482 - val_accuracy: 0.8512 - lr: 1.0000e-14
# Epoch 150/150
# 39/42 [==========================>...] - ETA: 0s - loss: 0.1359 - accuracy: 0.9591
# Epoch 150: saving model to model_augmented-150-0.85.h5
# 42/42 [==============================] - 1s 15ms/step - loss: 0.1414 - accuracy: 0.9550 - val_loss: 0.3478 - val_accuracy: 0.8512 - lr: 1.0000e-14

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Saving the model

# %%
# !ls

# %%
model.save('model_augmented.h5') # it just saves the model at the last epoch

# %%
from keras.models import load_model

# %% [markdown]
# Load the model with the best validation accuracy. To select the best model have a look at the names of the saved models (the last number is the accuracy on validation)

# %%
imported_model = load_model('model_augmented.h5')

# %%
imported_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 60, 60, 8)         80
#
#  batch_normalization_3 (Batc  (None, 60, 60, 8)        32
#  hNormalization)
#
#  activation_3 (Activation)   (None, 60, 60, 8)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 30, 30, 8)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 16)        1168
#
#  batch_normalization_4 (Batc  (None, 30, 30, 16)       64
#  hNormalization)
#
#  activation_4 (Activation)   (None, 30, 30, 16)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 15, 15, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 15, 15, 32)        4640
#
#  batch_normalization_5 (Batc  (None, 15, 15, 32)       128
#  hNormalization)
#
#  activation_5 (Activation)   (None, 15, 15, 32)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1568)              0
#
#  dense_2 (Dense)             (None, 10)                15690
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21,813
# Trainable params: 21,701
# Non-trainable params: 112
# _________________________________________________________________

# %% [markdown]
# # Evaluate the performance of the two models

# %% [markdown]
# Load the models with and without augmentation which realized the best accuracy on validation

# %%
model = load_model('model.h5')
model_aug = load_model('model_augmented.h5')
#to select the best models have a look at the names of the saved models
#(the last number is the accuracy on validation)

# %%
x_test, y_test = read_imgs('Test', [0,1])

# %%
test_loss_noaug, test_acc_noaug = model.evaluate(x_test, y_test)
preds_test = model.predict(x_test, verbose=1)
fpr, tpr, _ = roc_curve(y_test, preds_test)
roc_auc = auc(fpr, tpr)

print('\n Test accuracy model no aug = %.3f'% (test_acc_noaug))
print('\n AUC = %.3f'% (roc_auc))
# Out:
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3998 - accuracy: 0.8216
# 8/8 [==============================] - 0s 3ms/step
#
#  Test accuracy model no aug = 0.822
#
#  AUC = 0.924

# %%
test_loss_aug, test_acc_aug = model_aug.evaluate(x_test, y_test) # both model should be evaluated on the Test set
preds_test_aug = model_aug.predict(x_test, verbose=1)
fpr_aug, tpr_aug, _ = roc_curve(y_test, preds_test_aug)
roc_auc_aug = auc(fpr_aug, tpr_aug)

print('\n Test accuracy aug model = %.3f'% (test_acc_aug))
print('\n AUC = %.3f'% (roc_auc_aug))
# Out:
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2190 - accuracy: 0.9170
# 8/8 [==============================] - 0s 2ms/step
#
#  Test accuracy aug model = 0.917
#
#  AUC = 0.973

# %%
#Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label=f'ROC curve (area = {roc_auc:0.2f})')
plt.plot(fpr_aug, tpr_aug, color='red', lw=lw, label=f'ROC curve aug (area = {roc_auc_aug:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Did you obtain an improvement of the performance on the *Test* set by using a data augmentation strategy?
