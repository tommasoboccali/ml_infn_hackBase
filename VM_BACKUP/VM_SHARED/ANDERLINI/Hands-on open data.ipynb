# %%
import numpy as np
import pandas as pd

df = pd.read_csv("https://opendata.cern.ch/record/5202/files/Dimuon_SingleMu.csv")

# %%
df
# Out:
#           Run      Event type1  Q1      pt1    eta1    phi1        E1  \
# 0      166699  835716681     G   1   4.2116  2.2366 -0.4849   19.9382
# 1      166699  836133459     G  -1   2.1479 -2.0159 -2.7753    8.2066
# 2      166699  836165498     G   1  21.0732  1.5948 -1.1137   54.0560
# 3      166699  836249706     G   1  18.5889  1.6422  1.1923   49.8180
# 4      166699  835608783     G  -1  11.8194  0.8711 -1.5811   16.5947
# ...       ...        ...   ...  ..      ...     ...     ...       ...
# 83756  171880  168748742     G  -1   1.8023  2.3706 -0.9321    9.7302
# 83757  171880  168741216     G   1  36.9262  2.2307  2.8742  173.8090
# 83758  171880  169006248     G   1  17.1378 -0.2433  0.2400   17.8220
# 83759  171880  168784352     G   1   4.5931 -1.1897  1.5863    8.2465
# 83760  171880  167984926     G  -1  17.7634  0.3614  2.1100   18.9365
#
#            px1      py1  ...  type2 Q2      pt2    eta2    phi2       E2  \
# 0       3.7261  -1.9631  ...      T -1   1.2556  2.2683 -1.4488   6.1319
# 1      -2.0055  -0.7692  ...      G  1  19.5453 -1.0826 -0.3408  32.1613
# 2       9.2997 -18.9102  ...      T -1   2.3864  1.5352 -1.7388   5.7968
# 3       6.8688  17.2734  ...      G -1   1.8721  1.9704  1.6393   6.8459
# 4      -0.1214 -11.8187  ...      T  1   0.9408  2.0107 -1.6559   3.5779
# ...        ...      ...  ...    ... ..      ...     ...     ...      ...
# 83756   1.0744  -1.4470  ...      T  1   1.7895  1.4432  0.4109   4.0011
# 83757 -35.6137   9.7576  ...      T -1   6.1773  2.2084  2.7668  28.4510
# 83758  16.8113   4.1122  ...      T -1   1.0959  1.7140 -0.3812   3.1424
# 83759  -0.0712   4.5926  ...      G -1  23.9671 -1.2769  1.6562  46.3079
# 83760  -9.1205  15.2432  ...      T  1   1.0945 -2.2008  2.8140   5.0047
#
#            px2      py2      pz2        M
# 0       0.1528  -1.2463   6.0011   2.1330
# 1      18.4210  -6.5332 -25.5406  13.6786
# 2      -0.3991  -2.3528   5.2818   4.3813
# 3      -0.1281   1.8678   6.5841   3.2587
# 4      -0.0799  -0.9374   3.4504   4.0171
# ...        ...      ...      ...      ...
# 83756   1.6405   0.7147   3.5770   2.8234
# 83757  -5.7485   2.2615  27.7721   1.6556
# 83758   1.0173  -0.4077   2.9432  10.2510
# 83759  -2.0451  23.8797 -39.6231   1.1724
# 83760  -1.0363   0.3522  -4.8825  14.9641
#
# [83761 rows x 21 columns]

# %%
type(df['Run'].values)
# Out:
# numpy.ndarray

# %%
px1 = df['px1']
py1 = df['py1']
pz1 = df['pz1']

p1 = np.sqrt ( px1**2 + py1**2 + pz1**2 )

# %%
type (p1)
px1.dtype
# Out:
# dtype('float64')

# %%
df['p1'] = p1

# %%
df
# Out:
#           Run      Event type1  Q1      pt1    eta1    phi1        E1  \
# 0      166699  835716681     G   1   4.2116  2.2366 -0.4849   19.9382
# 1      166699  836133459     G  -1   2.1479 -2.0159 -2.7753    8.2066
# 2      166699  836165498     G   1  21.0732  1.5948 -1.1137   54.0560
# 3      166699  836249706     G   1  18.5889  1.6422  1.1923   49.8180
# 4      166699  835608783     G  -1  11.8194  0.8711 -1.5811   16.5947
# ...       ...        ...   ...  ..      ...     ...     ...       ...
# 83756  171880  168748742     G  -1   1.8023  2.3706 -0.9321    9.7302
# 83757  171880  168741216     G   1  36.9262  2.2307  2.8742  173.8090
# 83758  171880  169006248     G   1  17.1378 -0.2433  0.2400   17.8220
# 83759  171880  168784352     G   1   4.5931 -1.1897  1.5863    8.2465
# 83760  171880  167984926     G  -1  17.7634  0.3614  2.1100   18.9365
#
#            px1      py1  ...  Q2      pt2    eta2    phi2       E2      px2  \
# 0       3.7261  -1.9631  ...  -1   1.2556  2.2683 -1.4488   6.1319   0.1528
# 1      -2.0055  -0.7692  ...   1  19.5453 -1.0826 -0.3408  32.1613  18.4210
# 2       9.2997 -18.9102  ...  -1   2.3864  1.5352 -1.7388   5.7968  -0.3991
# 3       6.8688  17.2734  ...  -1   1.8721  1.9704  1.6393   6.8459  -0.1281
# 4      -0.1214 -11.8187  ...   1   0.9408  2.0107 -1.6559   3.5779  -0.0799
# ...        ...      ...  ...  ..      ...     ...     ...      ...      ...
# 83756   1.0744  -1.4470  ...   1   1.7895  1.4432  0.4109   4.0011   1.6405
# 83757 -35.6137   9.7576  ...  -1   6.1773  2.2084  2.7668  28.4510  -5.7485
# 83758  16.8113   4.1122  ...  -1   1.0959  1.7140 -0.3812   3.1424   1.0173
# 83759  -0.0712   4.5926  ...  -1  23.9671 -1.2769  1.6562  46.3079  -2.0451
# 83760  -9.1205  15.2432  ...   1   1.0945 -2.2008  2.8140   5.0047  -1.0363
#
#            py2      pz2        M          p1
# 0      -1.2463   6.0011   2.1330   19.937994
# 1      -6.5332 -25.5406  13.6786    8.206005
# 2      -2.3528   5.2818   4.3813   54.055887
# 3       1.8678   6.5841   3.2587   49.817968
# 4      -0.9374   3.4504   4.0171   16.594276
# ...        ...      ...      ...         ...
# 83756   0.7147   3.5770   2.8234    9.729578
# 83757   2.2615  27.7721   1.6556  173.808837
# 83758  -0.4077   2.9432  10.2510   17.821745
# 83759  23.8797 -39.6231   1.1724    8.245818
# 83760   0.3522  -4.8825  14.9641   18.936212
#
# [83761 rows x 22 columns]

# %%
mask = p1 > 10

# %%
print (type(mask))
mask
# Out:
# <class 'pandas.core.series.Series'>
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 83756    False
# 83757     True
# 83758     True
# 83759    False
# 83760     True
# Length: 83761, dtype: bool

# %%
df[mask]
# Out:
#           Run      Event type1  Q1      pt1    eta1    phi1        E1  \
# 0      166699  835716681     G   1   4.2116  2.2366 -0.4849   19.9382
# 2      166699  836165498     G   1  21.0732  1.5948 -1.1137   54.0560
# 3      166699  836249706     G   1  18.5889  1.6422  1.1923   49.8180
# 4      166699  835608783     G  -1  11.8194  0.8711 -1.5811   16.5947
# 5      166699  836183239     G   1  44.0991  1.9020  2.6466  151.0120
# ...       ...        ...   ...  ..      ...     ...     ...       ...
# 83754  171880  168782047     G  -1  14.9900  1.4155  0.9575   32.6892
# 83755  171880  168994546     G  -1   7.0827  2.1294  0.7919   30.2026
# 83757  171880  168741216     G   1  36.9262  2.2307  2.8742  173.8090
# 83758  171880  169006248     G   1  17.1378 -0.2433  0.2400   17.8220
# 83760  171880  167984926     G  -1  17.7634  0.3614  2.1100   18.9365
#
#            px1      py1  ...  Q2      pt2    eta2    phi2       E2      px2  \
# 0       3.7261  -1.9631  ...  -1   1.2556  2.2683 -1.4488   6.1319   0.1528
# 2       9.2997 -18.9102  ...  -1   2.3864  1.5352 -1.7388   5.7968  -0.3991
# 3       6.8688  17.2734  ...  -1   1.8721  1.9704  1.6393   6.8459  -0.1281
# 4      -0.1214 -11.8187  ...   1   0.9408  2.0107 -1.6559   3.5779  -0.0799
# 5     -38.8053  20.9495  ...  -1  37.1837  0.9808 -0.5664  56.5483  31.3765
# ...        ...      ...  ...  ..      ...     ...     ...      ...      ...
# 83754   8.6277  12.2581  ...   1   1.0647  1.9742  1.6188   3.9088  -0.0511
# 83755   4.9757   5.0406  ...   1   2.1141  2.1228  1.3040   8.9584   0.5573
# 83757 -35.6137   9.7576  ...  -1   6.1773  2.2084  2.7668  28.4510  -5.7485
# 83758  16.8113   4.1122  ...  -1   1.0959  1.7140 -0.3812   3.1424   1.0173
# 83760  -9.1205  15.2432  ...   1   1.0945 -2.2008  2.8140   5.0047  -1.0363
#
#            py2      pz2        M          p1
# 0      -1.2463   6.0011   2.1330   19.937994
# 2      -2.3528   5.2818   4.3813   54.055887
# 3       1.8678   6.5841   3.2587   49.817968
# 4      -0.9374   3.4504   4.0171   16.594276
# 5     -19.9535  42.6037  89.6863  151.012442
# ...        ...      ...      ...         ...
# 83754   1.0635   3.7595   3.4410   32.689015
# 83755   2.0394   8.7047   1.9605   30.202427
# 83757   2.2615  27.7721   1.6556  173.808837
# 83758  -0.4077   2.9432  10.2510   17.821745
# 83760   0.3522  -4.8825  14.9641   18.936212
#
# [70205 rows x 22 columns]

# %%
p2 = np.sqrt(df[mask]['px2']**2 + df[mask]['py2']**2 + df[mask]['pz2']**2)

# %%
 df['p2'] = p2

# %%
df[]
# Out:
#           Run      Event type1  Q1      pt1    eta1    phi1        E1  \
# 0      166699  835716681     G   1   4.2116  2.2366 -0.4849   19.9382
# 1      166699  836133459     G  -1   2.1479 -2.0159 -2.7753    8.2066
# 2      166699  836165498     G   1  21.0732  1.5948 -1.1137   54.0560
# 3      166699  836249706     G   1  18.5889  1.6422  1.1923   49.8180
# 4      166699  835608783     G  -1  11.8194  0.8711 -1.5811   16.5947
# ...       ...        ...   ...  ..      ...     ...     ...       ...
# 83756  171880  168748742     G  -1   1.8023  2.3706 -0.9321    9.7302
# 83757  171880  168741216     G   1  36.9262  2.2307  2.8742  173.8090
# 83758  171880  169006248     G   1  17.1378 -0.2433  0.2400   17.8220
# 83759  171880  168784352     G   1   4.5931 -1.1897  1.5863    8.2465
# 83760  171880  167984926     G  -1  17.7634  0.3614  2.1100   18.9365
#
#            px1      py1  ...      pt2    eta2    phi2       E2      px2  \
# 0       3.7261  -1.9631  ...   1.2556  2.2683 -1.4488   6.1319   0.1528
# 1      -2.0055  -0.7692  ...  19.5453 -1.0826 -0.3408  32.1613  18.4210
# 2       9.2997 -18.9102  ...   2.3864  1.5352 -1.7388   5.7968  -0.3991
# 3       6.8688  17.2734  ...   1.8721  1.9704  1.6393   6.8459  -0.1281
# 4      -0.1214 -11.8187  ...   0.9408  2.0107 -1.6559   3.5779  -0.0799
# ...        ...      ...  ...      ...     ...     ...      ...      ...
# 83756   1.0744  -1.4470  ...   1.7895  1.4432  0.4109   4.0011   1.6405
# 83757 -35.6137   9.7576  ...   6.1773  2.2084  2.7668  28.4510  -5.7485
# 83758  16.8113   4.1122  ...   1.0959  1.7140 -0.3812   3.1424   1.0173
# 83759  -0.0712   4.5926  ...  23.9671 -1.2769  1.6562  46.3079  -2.0451
# 83760  -9.1205  15.2432  ...   1.0945 -2.2008  2.8140   5.0047  -1.0363
#
#            py2      pz2        M          p1         p2
# 0      -1.2463   6.0011   2.1330   19.937994   6.131053
# 1      -6.5332 -25.5406  13.6786    8.206005        NaN
# 2      -2.3528   5.2818   4.3813   54.055887   5.795892
# 3       1.8678   6.5841   3.2587   49.817968   6.845105
# 4      -0.9374   3.4504   4.0171   16.594276   3.576362
# ...        ...      ...      ...         ...        ...
# 83756   0.7147   3.5770   2.8234    9.729578        NaN
# 83757   2.2615  27.7721   1.6556  173.808837  28.450820
# 83758  -0.4077   2.9432  10.2510   17.821745   3.140628
# 83759  23.8797 -39.6231   1.1724    8.245818        NaN
# 83760   0.3522  -4.8825  14.9641   18.936212   5.003676
#
# [83761 rows x 23 columns]

# %%
df.query ("p1 > p2")
# Out:
#           Run      Event type1  Q1      pt1    eta1    phi1        E1  \
# 0      166699  835716681     G   1   4.2116  2.2366 -0.4849   19.9382
# 2      166699  836165498     G   1  21.0732  1.5948 -1.1137   54.0560
# 3      166699  836249706     G   1  18.5889  1.6422  1.1923   49.8180
# 4      166699  835608783     G  -1  11.8194  0.8711 -1.5811   16.5947
# 5      166699  836183239     G   1  44.0991  1.9020  2.6466  151.0120
# ...       ...        ...   ...  ..      ...     ...     ...       ...
# 83754  171880  168782047     G  -1  14.9900  1.4155  0.9575   32.6892
# 83755  171880  168994546     G  -1   7.0827  2.1294  0.7919   30.2026
# 83757  171880  168741216     G   1  36.9262  2.2307  2.8742  173.8090
# 83758  171880  169006248     G   1  17.1378 -0.2433  0.2400   17.8220
# 83760  171880  167984926     G  -1  17.7634  0.3614  2.1100   18.9365
#
#            px1      py1  ...      pt2    eta2    phi2       E2      px2  \
# 0       3.7261  -1.9631  ...   1.2556  2.2683 -1.4488   6.1319   0.1528
# 2       9.2997 -18.9102  ...   2.3864  1.5352 -1.7388   5.7968  -0.3991
# 3       6.8688  17.2734  ...   1.8721  1.9704  1.6393   6.8459  -0.1281
# 4      -0.1214 -11.8187  ...   0.9408  2.0107 -1.6559   3.5779  -0.0799
# 5     -38.8053  20.9495  ...  37.1837  0.9808 -0.5664  56.5483  31.3765
# ...        ...      ...  ...      ...     ...     ...      ...      ...
# 83754   8.6277  12.2581  ...   1.0647  1.9742  1.6188   3.9088  -0.0511
# 83755   4.9757   5.0406  ...   2.1141  2.1228  1.3040   8.9584   0.5573
# 83757 -35.6137   9.7576  ...   6.1773  2.2084  2.7668  28.4510  -5.7485
# 83758  16.8113   4.1122  ...   1.0959  1.7140 -0.3812   3.1424   1.0173
# 83760  -9.1205  15.2432  ...   1.0945 -2.2008  2.8140   5.0047  -1.0363
#
#            py2      pz2        M          p1         p2
# 0      -1.2463   6.0011   2.1330   19.937994   6.131053
# 2      -2.3528   5.2818   4.3813   54.055887   5.795892
# 3       1.8678   6.5841   3.2587   49.817968   6.845105
# 4      -0.9374   3.4504   4.0171   16.594276   3.576362
# 5     -19.9535  42.6037  89.6863  151.012442  56.548229
# ...        ...      ...      ...         ...        ...
# 83754   1.0635   3.7595   3.4410   32.689015   3.907363
# 83755   2.0394   8.7047   1.9605   30.202427   8.957764
# 83757   2.2615  27.7721   1.6556  173.808837  28.450820
# 83758  -0.4077   2.9432  10.2510   17.821745   3.140628
# 83760   0.3522  -4.8825  14.9641   18.936212   5.003676
#
# [60995 rows x 23 columns]

# %%
mask1 = df['pt1'] > 10
mask2 = df['pt2'] > 10 


df [(df['pt1'] > 10) & (df['pt2'] > 10)] == df.query ("pt1 > 10 and pt2 > 10")
# Out:
#         Run  Event  type1    Q1   pt1  eta1  phi1    E1   px1   py1  ...  \
# 5      True   True   True  True  True  True  True  True  True  True  ...
# 9      True   True   True  True  True  True  True  True  True  True  ...
# 14     True   True   True  True  True  True  True  True  True  True  ...
# 15     True   True   True  True  True  True  True  True  True  True  ...
# 36     True   True   True  True  True  True  True  True  True  True  ...
# ...     ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ...
# 83731  True   True   True  True  True  True  True  True  True  True  ...
# 83738  True   True   True  True  True  True  True  True  True  True  ...
# 83739  True   True   True  True  True  True  True  True  True  True  ...
# 83744  True   True   True  True  True  True  True  True  True  True  ...
# 83748  True   True   True  True  True  True  True  True  True  True  ...
#
#         pt2  eta2  phi2    E2   px2   py2   pz2     M    p1    p2
# 5      True  True  True  True  True  True  True  True  True  True
# 9      True  True  True  True  True  True  True  True  True  True
# 14     True  True  True  True  True  True  True  True  True  True
# 15     True  True  True  True  True  True  True  True  True  True
# 36     True  True  True  True  True  True  True  True  True  True
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 83731  True  True  True  True  True  True  True  True  True  True
# 83738  True  True  True  True  True  True  True  True  True  True
# 83739  True  True  True  True  True  True  True  True  True  True
# 83744  True  True  True  True  True  True  True  True  True  True
# 83748  True  True  True  True  True  True  True  True  True  True
#
# [18159 rows x 23 columns]

# %%
df.eval("pT1 = sqrt(px1**2 + px2**2)")
# Out:
#           Run      Event type1  Q1      pt1    eta1    phi1        E1  \
# 0      166699  835716681     G   1   4.2116  2.2366 -0.4849   19.9382
# 1      166699  836133459     G  -1   2.1479 -2.0159 -2.7753    8.2066
# 2      166699  836165498     G   1  21.0732  1.5948 -1.1137   54.0560
# 3      166699  836249706     G   1  18.5889  1.6422  1.1923   49.8180
# 4      166699  835608783     G  -1  11.8194  0.8711 -1.5811   16.5947
# ...       ...        ...   ...  ..      ...     ...     ...       ...
# 83756  171880  168748742     G  -1   1.8023  2.3706 -0.9321    9.7302
# 83757  171880  168741216     G   1  36.9262  2.2307  2.8742  173.8090
# 83758  171880  169006248     G   1  17.1378 -0.2433  0.2400   17.8220
# 83759  171880  168784352     G   1   4.5931 -1.1897  1.5863    8.2465
# 83760  171880  167984926     G  -1  17.7634  0.3614  2.1100   18.9365
#
#            px1      py1  ...    eta2    phi2       E2      px2      py2  \
# 0       3.7261  -1.9631  ...  2.2683 -1.4488   6.1319   0.1528  -1.2463
# 1      -2.0055  -0.7692  ... -1.0826 -0.3408  32.1613  18.4210  -6.5332
# 2       9.2997 -18.9102  ...  1.5352 -1.7388   5.7968  -0.3991  -2.3528
# 3       6.8688  17.2734  ...  1.9704  1.6393   6.8459  -0.1281   1.8678
# 4      -0.1214 -11.8187  ...  2.0107 -1.6559   3.5779  -0.0799  -0.9374
# ...        ...      ...  ...     ...     ...      ...      ...      ...
# 83756   1.0744  -1.4470  ...  1.4432  0.4109   4.0011   1.6405   0.7147
# 83757 -35.6137   9.7576  ...  2.2084  2.7668  28.4510  -5.7485   2.2615
# 83758  16.8113   4.1122  ...  1.7140 -0.3812   3.1424   1.0173  -0.4077
# 83759  -0.0712   4.5926  ... -1.2769  1.6562  46.3079  -2.0451  23.8797
# 83760  -9.1205  15.2432  ... -2.2008  2.8140   5.0047  -1.0363   0.3522
#
#            pz2        M          p1         p2        pT1
# 0       6.0011   2.1330   19.937994   6.131053   3.729232
# 1     -25.5406  13.6786    8.206005        NaN  18.529848
# 2       5.2818   4.3813   54.055887   5.795892   9.308260
# 3       6.5841   3.2587   49.817968   6.845105   6.869994
# 4       3.4504   4.0171   16.594276   3.576362   0.145334
# ...        ...      ...         ...        ...        ...
# 83756   3.5770   2.8234    9.729578        NaN   1.961014
# 83757  27.7721   1.6556  173.808837  28.450820  36.074657
# 83758   2.9432  10.2510   17.821745   3.140628  16.842052
# 83759 -39.6231   1.1724    8.245818        NaN   2.046339
# 83760  -4.8825  14.9641   18.936212   5.003676   9.179185
#
# [83761 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

contents, boundaries, graphicsthings = plt.hist ( df.query('M < 120')['M'], bins=100 )
plt.xlabel("Mass")
plt.ylabel("Number of dimuons")
plt.show()

# %%
def f():
    return "pippo", "goofy"

first_result, second_result = f()

first_result
# Out:
# 'pippo'

# %%
result = plt.hist ( df.query('M < 120')['M'], bins=100 )

# %%
sdf = df.query ("M < 120")
contents, boundaries, graphicsthings = plt.hist ( sdf['M'], bins=100, density = True )
plt.hist ( sdf['M'], bins=1000, histtype='step', linewidth=1, density=True )
plt.xlabel("Mass")
plt.ylabel("Number of dimuons")
plt.show()

# %%
plt.figure(figsize=(10,6), dpi=120)
plt.plot (df['pt1'], df['pt2'], '.', markersize=0.1, alpha=0.5)
plt.xscale('log')
plt.yscale('log')

# %%
x = []
y = []

for i in range(10):
    x.append (i)
    y.append (i**2)
    
plt.plot (x, y, 'ro-')
plt.xlabel("Some x variable")
plt.ylabel("The variable $y = x^2$")
plt.show()

# %%
mistake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-9dbfb2c79b1c> in <module>
# ----> 1 mistake
#
# NameError: name 'mistake' is not defined

# %%
"pippo"
# Out:
# 'pippo'
